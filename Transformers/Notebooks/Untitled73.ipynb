# %%
# !pip install fasttext
# !pip install fastparquet
# !gdown --id '1QB54qk82PsJBv9AfAjdiq5Bp5Sm0vFna'
# !gdown --id '1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp'
# !unzip MedNLI_dataset.zip
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 1.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.1-py3-none-any.whl (238 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.25.2)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4246762 sha256=03e7ead444b2575c2f685260ae5fb22724e97c9745bc070f132d5330d4d6ad17
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.1
# Collecting fastparquet
#   Downloading fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.25.2)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.8.3 fastparquet-2024.5.0
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1QB54qk82PsJBv9AfAjdiq5Bp5Sm0vFna
# From (redirected): https://drive.google.com/uc?id=1QB54qk82PsJBv9AfAjdiq5Bp5Sm0vFna&confirm=t&uuid=567506bb-16a0-4193-9617-31e1e5109395
# To: /content/modelx.pth
# 100% 516M/516M [00:22<00:00, 22.6MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp
# To: /content/MedNLI_dataset.zip
# 100% 681k/681k [00:00<00:00, 116MB/s]
# Archive:  MedNLI_dataset.zip
#    creating: MedNLI_dataset/
#   inflating: MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet
#   inflating: MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet
#   inflating: MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet

# %%
from transformers import AutoTokenizer, AutoModel, AutoModelForSeq2SeqLM
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset,DataLoader, random_split
from sklearn.metrics import accuracy_score

# %%
test_data = pd.read_parquet('MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet', engine='fastparquet')
train_data = pd.read_parquet('MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet', engine='fastparquet')
valid_data = pd.read_parquet('MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet', engine='fastparquet')
test_data
# Out:
#               id                                              query  \
# 0        MedNLI0  \nTASK: Please classify the relationship betwe...
# 1        MedNLI1  \nTASK: Please classify the relationship betwe...
# 2        MedNLI2  \nTASK: Please classify the relationship betwe...
# 3        MedNLI3  \nTASK: Please classify the relationship betwe...
# 4        MedNLI4  \nTASK: Please classify the relationship betwe...
# ...          ...                                                ...
# 1417  MedNLI1417  \nTASK: Please classify the relationship betwe...
# 1418  MedNLI1418  \nTASK: Please classify the relationship betwe...
# 1419  MedNLI1419  \nTASK: Please classify the relationship betwe...
# 1420  MedNLI1420  \nTASK: Please classify the relationship betwe...
# 1421  MedNLI1421  \nTASK: Please classify the relationship betwe...
#
#              answer                               choices  gold
# 0        entailment  [entailment, contradiction, neutral]     0
# 1     contradiction  [entailment, contradiction, neutral]     1
# 2           neutral  [entailment, contradiction, neutral]     2
# 3        entailment  [entailment, contradiction, neutral]     0
# 4     contradiction  [entailment, contradiction, neutral]     1
# ...             ...                                   ...   ...
# 1417  contradiction  [entailment, contradiction, neutral]     1
# 1418        neutral  [entailment, contradiction, neutral]     2
# 1419     entailment  [entailment, contradiction, neutral]     0
# 1420  contradiction  [entailment, contradiction, neutral]     1
# 1421        neutral  [entailment, contradiction, neutral]     2
#
# [1422 rows x 5 columns]

# %%
def find_pre_and_hyp(query):
    start_pre = query.find("[PRE]") + len("[PRE]")
    end_pre = query.find("[HYP]")
    start_hyp = query.find("[HYP]") + len("[HYP]")
    end_hyp = query.find("OUTPUT:")
    premise = query[start_pre:end_pre].strip()
    hypothesis = query[start_hyp:end_hyp].strip()

    return premise,hypothesis

# %%
class CustomDataset(Dataset):
    def __init__(self, x_list, y_list):
        self.samples = []
        for x,y in zip(x_list,y_list):
            #x_tensor = torch.tensor(x,dtype = torch.float32)
            y_tensor = torch.tensor(y,dtype = torch.float32)
            self.samples.append((x[0],x[1],y_tensor))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("gsarti/biobert-nli")
bert_model = AutoModel.from_pretrained("gsarti/biobert-nli").to(device)
src_pad_idx = 0
src_vocab_size = bert_model.config.vocab_size
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:99: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
def get_lists(data):
    x_list = []
    y_list = []
    i =0
    for query,answer in zip(data['query'],data['answer']):
        i = i + 1
        if answer == 'entailment':
           y = [1,0,0]
        elif answer == 'neutral':
           y = [0,1,0]
        elif answer == 'contradiction':
           y = [0,0,1]
        else:
           print('should not get here')

        premise,hypothesis = find_pre_and_hyp(query)
        x_list.append((premise,hypothesis))
        y_list.append(y)
    return x_list,y_list

# %%
train_x_list,train_y_list = get_lists(train_data)
test_x_list,test_y_list = get_lists(test_data)
val_x_list,val_y_list = get_lists(valid_data)

# %%
print(len(train_x_list))
print(len(train_y_list))
print(len(test_x_list))
print(len(test_y_list))
print(len(val_x_list))
print(len(val_y_list))
# Out:
# 11232
# 11232
# 1422
# 1422
# 1395
# 1395

# %%
train_dataset = CustomDataset(train_x_list,train_y_list)
test_dataset = CustomDataset(test_x_list,test_y_list)
val_dataset = CustomDataset(val_x_list,val_y_list)

# %%
class embedding_layer(nn.Module):
  def __init__(self,bert_model,tokenizer):
    super(embedding_layer, self).__init__()
    self.bert_model = bert_model
    self.tokenizer = tokenizer

  def forward(self, x):
    with torch.no_grad():
         s = tokenizer(x,return_tensors="pt",padding=True).to(device)
         vec = bert_model(**s)['last_hidden_state'].to(device)
    return vec

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, seq_len,embedding_size):
        super().__init__()
        self.dropout = nn.Dropout(0.1)
        self.embedding_size = embedding_size
        self.seq_len = seq_len

    def forward(self, x):
        pe = torch.zeros(x.size(0), x.size(1), self.embedding_size).to(device)
        div_term = torch.zeros(x.size(0), 1, self.embedding_size).to(device)
        ks = torch.arange(self.embedding_size).float().to(device)
        values = torch.exp(-torch.log(torch.tensor(1000.0)) * 2 * ks / self.embedding_size).to(device)
        values = values.view(1, 1, -1).to(device)
        div_term = div_term + values
        x = x.reshape([x.shape[0],x.shape[1],1]).to(device)
        pe[:, :, ::2] = torch.sin(x * div_term)[:, :, ::2].to(device)
        pe[:, :, 1::2] = torch.cos(x * div_term)[:, :, 1::2].to(device)
        return self.dropout(pe)

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, embedding_size, heads):
        super().__init__()
        self.embedding_size = embedding_size
        self.heads = heads
        self.head_dim = embedding_size // heads
        assert(self.heads * self.head_dim == self.embedding_size), "Invalid number of heads"
        self.fc_values = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_keys = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_queries = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_out = nn.Linear(heads * self.head_dim, embedding_size).to(device)

    def forward(self, values, keys, queries, mask):
        N = queries.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], queries.shape[1]
        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = queries.reshape(N, query_len, self.heads, self.head_dim)
        values = self.fc_values(values).to(device)
        keys = self.fc_keys(keys).to(device)
        queries = self.fc_queries(queries).to(device)
        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys]).to(device)
        if mask is not None:
            energy = energy.masked_fill(mask.to(device) == 0, float("-1e20")).to(device)
        energy = torch.softmax(energy / (self.embedding_size ** 0.5), dim=3).to(device)
        attention = torch.einsum("nhql,nlhd->nqhd", [energy, values]).to(device)
        attention = attention.reshape(N, query_len, self.heads * self.head_dim).to(device)
        out = self.fc_out(attention)
        return out

# %%
class TransformerBlock(nn.Module):
    def __init__(self, embedding_size, heads, forward_expansion, p):
        super().__init__()
        self.attention = MultiHeadAttention(embedding_size, heads)
        self.norm1 = nn.LayerNorm(embedding_size)
        self.feed_forward = nn.Sequential(nn.Linear(embedding_size, forward_expansion * embedding_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion * embedding_size, embedding_size))
        self.norm2 = nn.LayerNorm(embedding_size)
        self.dropout = nn.Dropout(p)
    def forward(self, values, keys, queries, mask):
        attention_out = self.attention(values, keys, queries, mask)
        x = self.norm1(attention_out + queries)
        x = self.dropout(x)
        ff_out = self.feed_forward(x)
        out = self.norm2(ff_out + x)
        out = self.dropout(out)
        return out

# %%
class Encoder(nn.Module):
    def __init__(self, src_vocab_size, embedding_size, num_layers, heads,
                 forward_expansion, max_length, p, device):
        super().__init__()
        self.device = device
        self.word_embedding = embedding_layer(bert_model,tokenizer)
        self.positional_embedding = PositionalEncoding(max_length, embedding_size)
        self.layers = nn.ModuleList([TransformerBlock(embedding_size, heads, forward_expansion, p) for _ in range(num_layers)])
        self.dropout = nn.Dropout(p)

    def forward(self, x, mask):
        mask = None
        pe = self.word_embedding(x)
        N = pe.size(0)
        seq_len = pe.size(1)
        positions = torch.arange(0, seq_len).expand(N, seq_len).to(self.device)
        out = self.dropout((pe + self.positional_embedding(positions)))
        for layer in self.layers:
            out = layer(out, out, out ,mask)
        return out

# %%
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, src_pad_idx, embedding_size=768,
                 num_layers=1, forward_expansion=8, heads=8, max_length=100, p=0.1):
        super().__init__()
        self.src_pad_idx = src_pad_idx
        self.encoder = Encoder(src_vocab_size, embedding_size, num_layers, heads,
                               forward_expansion, max_length, p, device)

    def get_src_mask(self, src):
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2).to(device)
        return src_mask

    def forward(self, src):
        src_mask = None
        enc_out = self.encoder(src, src_mask).to(device)
        return enc_out

# %%
class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.transformer1 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.transformer2 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.fc1 = nn.Linear(768*2, 256).to(device)
        self.fc2 = nn.Linear(256, 3).to(device)

    def forward(self, x_pre,x_hyp):
        out1 = self.transformer1(x_pre)
        out2 = self.transformer2(x_hyp)
        out1 = torch.mean(out1,1)
        out2 = torch.mean(out2,1)
        x = torch.cat((out1,out2),1)
        x = F.relu(self.fc1(self.dropout1(x)))
        x = nn.functional.softmax(self.fc2(self.dropout2(x)),dim=1)
        return x

# %%
bsize = 32
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=bsize, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=bsize, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %%
def get_model_acc(model,data_loader):
    model.eval()
    predictions = []
    true_labels = []
    for x_pre, x_hyp, y in data_loader:
        outputs = model(x_pre,x_hyp)
        predicted_labels = torch.argmax(outputs, dim=1).cpu().numpy()
        predictions.extend(predicted_labels)
        l1 = torch.argmax(y, dim=1).cpu().numpy()
        true_labels.extend(l1)
    model.train()
    return accuracy_score(true_labels, predictions)

# %%
model = torch.load('modelx.pth', map_location=device)

# %%
get_model_acc(model.to(device),test_loader)
# Out:
# 0.7215189873417721

# %%
get_model_acc(model,val_loader)

# %%
get_model_acc(model,train_loader)

# %%
for x_pre, x_hyp, y in val_loader:
    outputs = model(x_pre,x_hyp)
    for i in range(bsize):
          print(x_pre[i])
          print(x_hyp[i])
          print(outputs[i])
          print(y[i])
          print('------------------------------------------')
    print('================================================')
# Out:
# Streaming output truncated to the last 5000 lines.
# She was lightheaded and weak.
# She was volume depleted
# tensor([0.9963, 0.0019, 0.0018], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# He was started on IVF and given a total of 25mg of IV Valium.
# The patient has not been given a sedative.
# tensor([1.0549e-03, 1.0418e-06, 9.9894e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  This is a 64 year old female who was having chest pain, pressure and increasing shortness of breath on exertion.
# patient has chest pain
# tensor([9.9748e-01, 2.5104e-03, 4.8559e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# HISTORY:  This is a 35 week male infant [**Year (4 digits) **] by spontaneous vaginal delivery after spontaneous onset of labor to a 24 year old gravida 3, para 2 now 3 woman.
# Infant was delivered via c-section
# tensor([0.6906, 0.3005, 0.0089], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# No CP or fevers.
# Patient has no angina
# tensor([9.8486e-01, 1.4508e-02, 6.3404e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# On review of systems, she reports a history of prior [**Date Range **] in [**2864**] at which time she experienced left facial numnbess/tingling.
# The patient has a history of neurologic deficit.
# tensor([1.1350e-01, 8.8650e-01, 1.1039e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Delivery was by cesarean section for breech positioning.
# The patient had a vaginal delivery.
# tensor([2.6905e-04, 3.3026e-03, 9.9643e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# IDDM Elevated cholesterol s/p ccy
# Patient is on insulin for diabetes
# tensor([1.2068e-03, 9.9879e-01, 1.8498e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Subsequently had cardiac cath which showed no coronary disease.
# Patient has had angina
# tensor([0.0085, 0.9119, 0.0796], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# EF [**2610-11-28**] to 25% 3.
# The patient has congestive heart failure.
# tensor([1.3080e-02, 9.8692e-01, 1.5860e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# It is not associated with jaundice, hematemasis, hematochezia.
# the patient is jaundiced
# tensor([1.2541e-04, 1.5742e-01, 8.4246e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Prior to transfer to [**Hospital1 1499**], the patient had received a total of 17 units of packed red blood cells, 7 units of fresh frozen plasma, one pack of platelets as well as two units of cryo.
# The patient had no blood loss
# tensor([2.3191e-04, 1.7434e-03, 9.9802e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# ================================================
# Diabetes type 2.
# History of type 1 diabetes
# tensor([0.3984, 0.4201, 0.1815], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# 56 yo F with severe asthma presents with difficutly breathing and a prominent wheeze.
# The patient is on inhaled corticosteroids
# tensor([3.4578e-05, 9.9988e-01, 8.6507e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# CT of the abdomen and pelvis on [**3010-4-20**] at [**Location (un) **] revealed a large amount of ascites, along with CBD dilation to 1.25 cm.
# The patient has an obstructing pancreatin lesion.
# tensor([2.6668e-03, 9.9733e-01, 2.3293e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# HISTORY: Not following commands.
# Patient is disorientated
# tensor([3.9568e-02, 9.6041e-01, 2.3671e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Her hematocrit was followed q. six hours and prior to discharge her hematocrit was 33.
# The patient has an unknown hematocrit.
# tensor([0.9494, 0.0018, 0.0488], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Also INR of 2.6 on coumadin.
# Patient has history of atrial fibrillation
# tensor([3.4839e-03, 9.9652e-01, 5.6632e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Patient was brought to the [**Hospital1 **] Emergency Department.
# The patient presented to his primary care physician’s office
# tensor([9.9931e-01, 5.0558e-05, 6.4404e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# No CP or fevers.
# Patient has a negative physical exam
# tensor([8.1363e-04, 9.9447e-01, 4.7158e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# History of [**Male First Name (un) **] mounted spotted fever.
# Patient is febrile
# tensor([7.2331e-01, 2.7656e-01, 1.2907e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Over the past year, the patient had noticed weakness and pain in the right upper extremity while doing her activities of daily living.
# The patient denies weakness in her arms or legs
# tensor([5.0039e-09, 6.9037e-10, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Bleeding from left femoral arteriotomy and venotomy site with hemostasis achieved after Femstop applied.
# The patient has not had a recent procedure.
# tensor([1.3530e-06, 3.4451e-05, 9.9996e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# She denied any recent rashes, CP, SOB or abdominal pain.
# She has no respiratory disease
# tensor([0.8955, 0.1029, 0.0016], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# History of myeloproliferative disorder.
# History of polycythemia vera
# tensor([3.0865e-02, 9.6912e-01, 1.7348e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# This was 42-year-old female with multiple medical co-morbidities.
# The patient has no past medical history.
# tensor([4.9546e-04, 8.8899e-06, 9.9950e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# 33yoF with leukemia AML s/p allo [**First Name3 (LF) 6600**] and recurrence, last chemo [**11-12**], presents with 8hrs of increasing SOB, orthopnea, and right sided chest pain, pleuritic in nature.
# The patient has a pneumonia.
# tensor([2.0407e-03, 9.9796e-01, 5.2225e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Her neurologist mentioned also that she has headaches for which she was taking excessive amounts of Excedrin but which did not improve with Amitriptyline or Topamax.
# The patient has chronic headaches.
# tensor([7.3427e-01, 2.6573e-01, 3.5116e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Repeat Hct stable, but in setting of drop in BP, he was transferred to MICU for closer monitoring.
# There is concern that the patient has an occult hemorrhage.
# tensor([9.9998e-01, 7.5969e-07, 1.6714e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Family reports loss of consciousness.
# the patient had a seizure
# tensor([0.2658, 0.7235, 0.0107], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# A barrium swallow on [**2632-10-27**] was suggestive of partial obstruction at the second portion of the duodenum.
# The patient complains of nausea, vomiting and abdominal pain
# tensor([1.2224e-02, 9.8778e-01, 6.9156e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# HCT 22 from 29 on admission (27 at OSH).
# Hematocrit is within normal limits
# tensor([8.2641e-06, 1.4997e-05, 9.9998e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Status post thyroidectomy.
# The patient has never had surgery.
# tensor([5.0544e-06, 2.4209e-09, 9.9999e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  This is a 63 year old primarily Spanish speaking male with a history of end-stage renal disease secondary to diabetes mellitus on dialysis.
# The patient has an arterial venous fistula.
# tensor([9.9165e-01, 8.3477e-03, 1.6586e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Per report, [**Date Range 17970**] at OSH were negative for DVT, while CTA chest was positive for PE.
# The patient is anti-coagulated.
# tensor([0.2071, 0.7860, 0.0069], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Pulse returned at 7:05.
# The patient has a history of heart disease
# tensor([1.2227e-09, 1.0000e+00, 1.4877e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# In ER, he was found to be febrile and unresponsive.
# The patient is septic.
# tensor([1.9920e-08, 1.0000e+00, 3.5686e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# The patient received IgG treatment in the past from [**3275**] to [**3279**].
# The patient has no history of immunoglobin therapy
# tensor([3.7452e-06, 1.9485e-09, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# He was given lasix 60 IV and started on nitro drip.
# He was given no diuretics
# tensor([5.9624e-06, 1.4051e-10, 9.9999e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# He developed R sided chest discomfort and chills 2 hours after receiving bleomycin, with T 101.8, O2 sat 88% on RA.
# He has lymphoma
# tensor([1.0338e-07, 1.0000e+00, 8.2791e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# IVF dichorionic, diamniotic twin gestation reduced from     triplets.
# The twins shared a placenta
# tensor([0.9515, 0.0280, 0.0204], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# 56 yo F with severe asthma presents with difficutly breathing and a prominent wheeze.
# Pulmonary exam is normal
# tensor([1.4210e-11, 8.6392e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Her only complaint is a rash on her buttocks.
# The patient has a rash.
# tensor([4.1733e-01, 5.8266e-01, 1.1757e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# PAST MEDICAL HISTORY:  Significant for sacral decubitus Stage IV ulcer since [**3436-2-2**], he is a para[** Location **] times nine years which occurred after a thoracotomy procedure, bladder rupture, recurrent urinary tract infections, diabetes mellitus Type 2 with neuropathy, osteomyelitis and history of Clostridium difficile colitis, scrotal fissure/gangrene, congenital nystagmus, depression with suicidal ideations, hypoaldosteronism, hypomania and questionable history of gastrointestinal bleed.
# Patient is on long term antibiotics.
# tensor([1.7163e-04, 9.9983e-01, 3.0933e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# ================================================
# This symptoms were not amenable to TPA, so Mr.
# The patient had a stroke.
# tensor([1.7250e-06, 1.0000e+00, 3.3957e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# [**Known patient lastname 274**] is a 54-year-old woman with a history of coronary artery disease, diabetes mellitus Type 2, idiopathic cirrhosis, ulcerative colitis, chronic pancreatitis, and tracheomalacia, who presents from an outside hospital, [**Location (un) 272**]-[**Hospital3 271**] in [**State 275**] City, for bronchial stenting.
# The patient has a history of hypertension and hyperlipidemia
# tensor([4.1398e-06, 1.0000e+00, 3.3890e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# His sputum was negative for acid fast bacilli and Pneumocystis carinii pneumonia.
# Patient has URI
# tensor([0.0011, 0.9926, 0.0063], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# In transit, she vomited and was subsequently intubated to protect her airway given her mental status.
# Patient is on a ventilator
# tensor([9.9504e-01, 4.8864e-03, 7.8199e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# OTHER PAST MEDICAL HISTORY: AFib - on amiodarone, coumadin stopped in late [**5-19**] LGIB Breast CA -2.7 cm grade I infiltrating lobular cancer, negative lymph nodes, negative LVI,negative margins and ER positive, HER-2/neu negative.
# History of breast cancer
# tensor([0.8842, 0.1087, 0.0071], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# He denies fever, nausea, vomiting, light headedness, syncope, diarrhea, abdominal discomfort. .
# Gastrointestinal function is normal
# tensor([1.7348e-04, 9.9981e-01, 1.7195e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Chest x-ray showed mild congestive heart failure.
# Chest x-ray showed mild abnormalities
# tensor([9.9997e-01, 1.0667e-05, 2.0926e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Aortic insufficiency Aortic valve stenosis Redo, redo sternotomy/Third time aortic valve replacement with a 19-mm onyx mechanical valve, Replacement of ascending aorta and hemi arch with a 26-mm Dacron graft using deep hypothermic circulatory arrest.
# Patient has no past surgical history
# tensor([1.2193e-06, 8.9809e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Well controlled on Lipitor.
# He is on no medication
# tensor([3.1144e-02, 9.3331e-05, 9.6876e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# When she arrived with his jacket he had shaking chills and was conscious and conversive.
# The patient is aphasic.
# tensor([9.9585e-01, 1.8029e-04, 3.9699e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# He was getting his head laceration repaired when he started to seize.
# The patient has no signs of trauma.
# tensor([1.3793e-07, 6.6581e-06, 9.9999e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Left femoral A-V fistula [**3362-3-10**]
# History of lower extremity trauma
# tensor([9.9160e-01, 8.4044e-03, 1.5791e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Bladder CA dx in [**3382**].
# No history of cancer
# tensor([1.4432e-06, 5.5167e-06, 9.9999e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# In the catheterization laboratory, she was found to have mitral regurgitation and a right-dominant coronary system.
# Her heart valves were functioning normally
# tensor([4.3330e-10, 6.0224e-05, 9.9994e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# A CXR showed an infiltrate in the RML c/w pneumonitis.
# Patient has an infection
# tensor([9.9664e-01, 3.3611e-03, 1.6629e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Non-Q wave myocardial infarction in 02/[**2570**].
# History of heart attack
# tensor([9.9524e-01, 4.6225e-03, 1.4089e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# He was responding inappropriately to questions (i.e. saying "no" when he meant to say "yes"), but appeared to understand what was being said to him.
# The patient had a stroke.
# tensor([4.2174e-09, 1.0000e+00, 9.6609e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Estimated blood loss was [**2872**] cc and she received 3 units of packed red blood cells in total and her hematocrit at the postoperative check was at 34.
# the patient was transfused intraoperatively
# tensor([1.1967e-01, 8.8028e-01, 5.2867e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# 89F with multiple medical problems who presented to [**Hospital1 68**] on [**3287-1-7**] d/t hypotension from E. coli urosepsis in setting of poor PO intake, hypovolemia, and poor IV access/fluid administration.
# She has syncope
# tensor([9.9706e-01, 2.9345e-03, 1.0531e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Intervention was deferred at the time and the patient was sent to CCU for TEE.
# The patient has a cardiac murmur
# tensor([0.7025, 0.2905, 0.0070], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Her hematocrit was followed q. six hours and prior to discharge her hematocrit was 33.
# The patient‰Ûªs hematocrit was closely monitored.
# tensor([8.7261e-01, 6.8418e-04, 1.2670e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Angioplasty was performed and a stent was placed.
# the patient has normal coronary arteries
# tensor([7.7371e-10, 2.0949e-06, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# - depression: reports recent worsening with intermittent passive SI and some [** Location **]inary plan formation; denies HI; denies any AH/VH in the past but does report some paranoid delusions - obstructive sleep apnea: on CPAP at home - morbid obesity: has worsened over past year - lymphedema - psoriasis
# The patient is at low risk for suicide.
# tensor([2.9093e-06, 6.1841e-03, 9.9381e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Aorta is mildly tortuous and calcified.
# the aorta is mildly tortous
# tensor([9.9903e-01, 5.7653e-06, 9.6775e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# HISTORY:  Baby [**Name (NI) **] [**Known patient lastname 6048**] is the 3.09 kg product of a 36 and [**4-24**] week gestation born to a 37 year-old, Gravida IV, Para 2 woman.
# The patient has low birth weight.
# tensor([0.9287, 0.0616, 0.0097], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# At her oncologist's office, she was noted to have an irregularly irregular pulse in the 150s.
# The patient has atrial fibrillation.
# tensor([2.3944e-07, 1.0000e+00, 1.5233e-11], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  This 44-year-old male was transferred from [**Hospital6 773**] after a work-up for shortness of breath and had a cardiac catheterization on [**2947-4-11**] which revealed a 90% right coronary artery lesion, 90% left anterior descending lesion, 90% circumflex lesion and an ejection fraction of 25-30%.
# patient will undergo CABG
# tensor([6.3392e-07, 1.0000e+00, 4.1605e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Hx of substance abuse CHF EF 55% Diastolic dysfunction VRE, MRSA Hx of chronic pain Right shoulder pain Anemia of chronic disease Constipation
# Patient has a normal EF
# tensor([1.0964e-11, 9.4916e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# At her oncologist's office, she was noted to have an irregularly irregular pulse in the 150s.
# The patient has a cardiac arrhythmia.
# tensor([3.1573e-01, 6.8427e-01, 9.6372e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# This symptoms were not amenable to TPA, so Mr.
# The patient did not receive a throbolytic.
# tensor([4.1554e-04, 1.5004e-06, 9.9958e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Incision was clean, dry and intact.
# The surgical site is sterile.
# tensor([1.3100e-03, 9.9866e-01, 2.5227e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Status post right femoral endarterectomy.
# The patient has no significant atherosclerotic disease.
# tensor([4.9543e-08, 7.7828e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# ================================================
# HISTORY OF PRESENT ILLNESS:  Patient is an unfortunate 58-year-old male, who is a fire fighter, who sustained an approximately 14 foot fall on a moving fire truck going approximately 5 miles per hour.
# The patient has had a significant trauma.
# tensor([9.9591e-01, 4.0878e-03, 1.0348e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Coombs test was positive, and the serum haptoglobin was less than 0.6.
# patient has a negative coomb's test
# tensor([7.3128e-03, 3.8007e-05, 9.9265e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Given the patient's recent surgery and that the bleeding had stopped a colonoscopy was planned as an outpatient.
# Patient has significant PSH
# tensor([0.1520, 0.1858, 0.6622], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# The pain localizes to her lower abdomen & has been worsening.
# Patient has negative ROS
# tensor([3.8534e-08, 7.3629e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Today she got into an argument with her husband and felt that she "wanted to sleep" and therefore took "handfuls" of dilaudid.
# She had an overdose of Dilaudid
# tensor([6.8004e-01, 3.1992e-01, 4.3161e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# She presented to Dr[**Name (NI) 7823**] office where a mobile ultrasound revealed  - Complex material in the endometrial cavity from the fundus extending to the internal os measuring about 2.5 cm in diameter w/ vascularity -> c/w retained products of conception.   - Additionally, in the region of the anterior fundus, the border of the myometrium and retained products of conception is blurred, likely representing accreta  - There is no free fluid or hydronephrosis * Thus, as her vital signs were stable she was transferred to Gyn Triage for further evaluation & plan for U/S Guided D&C.
# The patient did not have retained fetal material in the uterus.
# tensor([3.6206e-02, 3.1998e-04, 9.6347e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  Baby Girl [**Known patient lastname **] #2 is the 1755 gram product of a 33 and [**1-2**] week triplet gestation by IVF conception, born to a 35 year-old, Gravida 0, now 3 mom.
# the patient is breathing normally
# tensor([1.9109e-06, 7.2900e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# At the rehabilitation she was found to have O2 saturations in the 70's and Arterial blood gases was 7.24/71/58.
# The patient is acidotic.
# tensor([9.9280e-01, 7.1721e-03, 2.5367e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Her exam was unremarkable.
# The patient patient had many important and critical findings on her exam.
# tensor([9.7033e-05, 7.9910e-02, 9.1999e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Pt denies any recent chills, fevers, nausea, vomiting, diarrhea, chest pain, shortness of breath.
# Patient denies dyspnea
# tensor([9.9894e-01, 8.7560e-04, 1.8236e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Cardiac cath was done and Cardiac surgery was consulted for coronary revascularization.
# History of hypertension and obesity
# tensor([5.6871e-07, 1.0000e+00, 3.7489e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# She was given Lasix 20mg IV, Albuterol and Ipratropium nebs, SoluMedrol 125mg.
# She received no inhaled medication
# tensor([4.7700e-06, 7.5051e-10, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  The patient is a 49 year old otherwise healthy female, on only aspirin 81 mg daily, who comes in after a routine physical examination and her primary care physician having heard [**Name Initial (PRE) **] murmur.
# Patient has multiple medical conditions
# tensor([9.9986e-01, 1.4275e-04, 2.2603e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Chronic RLE ulcer, rest non-invasive arterial studies normal on [**3379-1-8**].
# History of diabetes
# tensor([0.0023, 0.9803, 0.0174], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Other additions to his medications included Keppra and metoprolol.
# The patient is on an anti epileptic.
# tensor([9.9998e-01, 2.1806e-05, 1.1943e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# - pAF - C diff - Bipolar - Hx EtOH in past - Hx Hep C - Hx rheumatic heart dz - hx R MCA aneurysm clipping in [**3039**] - hx pernicious anemia - GERD
# the patient has no past medical history
# tensor([2.4848e-08, 1.8351e-06, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# She went to an outside hospital again and evaluated by neurology and admitted and had an MRI scan, which showed a mass lesion consistent with a hematoma inferior level of C3 C4 with cord compression.
# Imaging revealed hematoma at the cervical spine
# tensor([9.8942e-01, 1.0544e-02, 3.5941e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# The ultrasound-guided examination of the mid-esophageal mass demonstrated invasion into the muscularis propria, but no evidence of invasion beyond this, consistent with a T2 tumor.
# The patient has a malignancy.
# tensor([9.9968e-01, 3.2292e-04, 8.4280e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# This is a 59 year old woman with a h/o CAD s/p stenting and DM2 who was admitted from podiatry clinic [**4-1**] with purulent discharge from left foot ulcer, also with erythema of surrounding tissue.
# The patient has cellulitis.
# tensor([9.0648e-01, 9.3524e-02, 6.5021e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Atrioventricular block s/p pacemaker in [**2654**] 8.
# Patient has conduction abnormality
# tensor([8.3296e-01, 1.6704e-01, 2.5018e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Chronic renal failure due to acute tubular nephropathy in [**2700**] s/p renal transplant (second living related renal transplant in [**2691**]) Listeria infection in [**2701**].
# the patient has normal creatinine
# tensor([1.6417e-09, 1.0882e-04, 9.9989e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  The patient is a 64-year-old woman with a history of right parietal occipital hemorrhage in [**3113-9-29**].
# the patient has intracranial hemorrhage
# tensor([9.4734e-01, 5.2655e-02, 2.3693e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Cranial nerves II through XII are intact.
# Patient has normal brain MRI
# tensor([0.9478, 0.0473, 0.0050], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# No CP or fevers.
# Patient is febrile
# tensor([1.2060e-06, 2.0923e-04, 9.9979e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# [**Known patient lastname 274**] is a 54-year-old woman with a history of coronary artery disease, diabetes mellitus Type 2, idiopathic cirrhosis, ulcerative colitis, chronic pancreatitis, and tracheomalacia, who presents from an outside hospital, [**Location (un) 272**]-[**Hospital3 271**] in [**State 275**] City, for bronchial stenting.
# The patient has multiple medical conditions
# tensor([9.9995e-01, 5.3698e-05, 7.6448e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# She initially was treated with a course of Vanc, Zosyn, and Flagyl.
# She received antibiotics
# tensor([9.9997e-01, 2.7767e-05, 4.3754e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# He was given aspirin 300 PR and started on heparin IV out of concern for ACS.
# There are signs and symptoms associated with acute coronary syndrome
# tensor([1.0000e+00, 7.3617e-08, 1.0302e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Denied headache, sinus tenderness, rhinorrhea or congestion.
# Patient has negative exam
# tensor([3.7476e-04, 9.9933e-01, 2.9443e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# The mother was hospitalized for one month until five days prior to delivery.
# mother is IV drug user
# tensor([4.2920e-02, 9.5646e-01, 6.1614e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# The patient's wife reports that the patient had complained of chest pain during exercise over the past few months.
# The patient had no recent chest pain
# tensor([7.2060e-08, 5.1610e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# He underwent stress testing which was abnormal.
# The patient has cardiac ischemia.
# tensor([4.3655e-04, 9.9956e-01, 7.7462e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# On POD#3, pt presented to [**Hospital1 294**] with fevers, abdominal pain, and leukocytosis 14.4, concern for retained stone vs biliary leak.
# The patient has a normal cbc.
# tensor([2.5181e-13, 3.4078e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# ================================================
# In the [**Hospital Unit Name 2**], the patient was stable, speaking in full sentences and 90-93% on 2L by nasal cannula.
# Patient has COPD exacerbation
# tensor([2.0131e-05, 9.9831e-01, 1.6695e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# EKG showed T-wave depression in V3-5, with no prior EKG for comparison.
# The EKG shows signs of cardiac ischemia.
# tensor([9.9985e-01, 1.4805e-04, 5.6591e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Had Apgars of 5, 5 and 8 at 1, 5 and 10 minutes.
# APGARS improved at 10 minutes
# tensor([6.6782e-02, 9.0427e-05, 9.3313e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# In the [**Name (NI) **], pt was noted to have a temp of 100.5, HR 140s-150s, ANC 256.
# The patient is tachycardic
# tensor([9.9958e-01, 3.9188e-04, 2.6628e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Status post tonsillectomy.
# No surgical history
# tensor([2.9389e-05, 1.2015e-08, 9.9997e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# The patient notes that at 11 AM today she developed fevers and chills.
# The patient is febrile.
# tensor([9.9968e-01, 2.7505e-04, 4.8742e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# By report, Pt's family reported right sided weakness at breakfast then again in the bathroom the afternoon of admission.
# The patient has no neurological symptoms.
# tensor([4.1846e-07, 3.5171e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# CAD s/p coronary bypass surgery [**3-16**]- LIMA to LAD, SVG to OM, SVG to Diagonal, and SVG to PDA.
# The patient has a history of myocardial infarction
# tensor([1.6446e-04, 9.9981e-01, 2.5600e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# ESRD: on HD Tues/Th/Sat through L AV fistula, makes some urine 3.
# Patient has normal Cr
# tensor([4.8785e-10, 2.4994e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# His Coumadin has been on hold for eye surgery.
# He is not on anticoagulant therapy
# tensor([1.9842e-04, 4.4135e-06, 9.9980e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# s/p MI cath [**Hospital3 **] 60 % circ and 70% RCA with EF 59% [**3370-12-1**]  [**3373-11-1**] had wheezing, so chest CT was obtained showing mass, right hilar 3 cm mass encasing bronchus, 4 biopsies were non-diagnostic HTN +PPD, treated
# Patient has evidence of CAD
# tensor([8.8577e-02, 9.1142e-01, 1.8823e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# PMHx: DM, HTN, Hyperthyroid, Depression, Loss of hearing, s/p TAH/BSO, s/p L hip
# Hearing is intact
# tensor([6.5130e-10, 1.0724e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  The patient is a 49 year old otherwise healthy female, on only aspirin 81 mg daily, who comes in after a routine physical examination and her primary care physician having heard [**Name Initial (PRE) **] murmur.
# Patient takes only one medication
# tensor([3.0749e-06, 8.8464e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# He took an OTC indigestion remedy, and his pain eventually resolved after a couple of hours.
# The patient has a history of GERD
# tensor([5.7737e-07, 1.0000e+00, 5.5896e-11], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Over the past week PTA he has been more somnolent and difficult to arrouse. .
# Over the past week he has been alert and oriented
# tensor([2.2093e-04, 2.5682e-06, 9.9978e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Of Note, Patients work up for CAD started in [**Month (only) 539**] when she had chest burning across her chest while hospitalized with a urinary tract infection.
# the patient has an STEMI
# tensor([3.0520e-02, 9.6948e-01, 4.5696e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# [**Known patient lastname 10209**] is a very pleasant 60 yo man with a PMH of cirrhosis [**2-24**] a combination of EtOH and chronic Hepatatis C who was transferred from an OSH with extensive HCC and tumor/thrombus extending up his IVC into his RA. .
# The patient has ascites.
# tensor([1.7799e-01, 8.2201e-01, 9.8409e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# The patient is now admitted for elective surgery.
# The patient is undergoing elective surgery.
# tensor([1.1643e-02, 9.8818e-01, 1.7538e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# CVA [**2975**] c/b residual facial droop, dysarthria, dysphagia, right sided paralysis, nonverbal at baseline Vascular dementia Depression Insomnia Urinary incontinence Diverticulosis s/p recent colectomy on [**7-10**] for a lower GI bleed  Repair of several abd wall ventral hernias on [**7-11**] HTN Hyponatremia hx MSSA bacteremia gastritis with anemia Vitamin D deficiency s/p appendectomy
# The patient presents with pallor
# tensor([8.9108e-03, 9.9106e-01, 2.7175e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Bladder CA dx in [**3382**].
# History of smoking
# tensor([3.4050e-06, 1.0000e+00, 1.7504e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# For approximately 1-2 weeks [**Known patient firstname **] has been increasingly agitated, with some tremors and has been dropping things.
# The patient has no tremor.
# tensor([3.8442e-12, 4.6498e-10, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# His pain was fairly constant and crampy in nature.
# the patient denies pain
# tensor([2.8536e-07, 1.6810e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Lactate 3.4 .
# the patient has an elevated lactate
# tensor([8.7344e-01, 1.2656e-01, 1.7715e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# The patient was reportedly in his usual state of health until approximately one week prior to admission when he reports progressive lethargy and fatigue with three to four days of dyspnea on exertion.
# Patient has normal history
# tensor([2.6484e-14, 5.3206e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Reflex Sympathetic Dystrophy s/p fall, on disability, now resolved
# No history of falls or trauma
# tensor([2.3866e-03, 1.5109e-06, 9.9761e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Tuberculosis was the cause of a one-and-a-half year admission to a sanitorium at the age of thirteen, and was treated with rifampin and isoniazid in [**3381**].
# Patient has prior granulomatous infection
# tensor([9.9985e-01, 1.5184e-04, 2.8089e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Left common femoral dorsalis pedis bypass graft.
# Patient has no prior intervention
# tensor([3.5781e-07, 1.8523e-06, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Infusion stopped and she was treated with Benadryl 50 mg x 1, prednisone 40 mg x 1, ativan 1 mg.
# Patient has recently had iodinated contrast
# tensor([9.9936e-01, 6.3930e-04, 2.3168e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Bleeding from left femoral arteriotomy and venotomy site with hemostasis achieved after Femstop applied.
# The patient had a recent intravascular procedure.
# tensor([9.9817e-01, 1.8289e-03, 1.0224e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Hematocrit was 23.1 (baseline 29.6) at presentation, PT: 18.8 PTT: 40.5 INR: 2.4, PLT CT 369.
# The patient is taking Coumadin.
# tensor([1.8367e-04, 9.9790e-01, 1.9115e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Of note, recently hospitalized from 12/20-12-29/06 with NSTEMI s/p stent placed at [**Hospital1 111**] (see below) - in note states pt was d/c'd off lasix, but discharge meds state he was taking lasix.
# the patient is taking the appropiate medications
# tensor([5.8621e-04, 9.9931e-01, 1.0397e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# She initially was treated with a course of Vanc, Zosyn, and Flagyl.
# She had pain and fever
# tensor([5.2336e-05, 9.9986e-01, 8.3864e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# ================================================
# HISTORY OF PRESENT ILLNESS:  The patient is a 49 year old otherwise healthy female, on only aspirin 81 mg daily, who comes in after a routine physical examination and her primary care physician having heard [**Name Initial (PRE) **] murmur.
# Patient has a negative ROS
# tensor([3.4490e-04, 4.8098e-05, 9.9961e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# 2) Status post appendectomy.
# the patient has a cholecystectomy
# tensor([6.5504e-03, 9.9344e-01, 6.3597e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# At the rehabilitation she was found to have O2 saturations in the 70's and Arterial blood gases was 7.24/71/58.
# The patient has a normal blood pH.
# tensor([2.9323e-05, 5.2627e-05, 9.9992e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# During the [** Location **]us 2 days, he also endorses decreased PO intake.
# Patient has normal intake
# tensor([1.8301e-10, 7.8245e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# She progressed to a vaginal delivery.
# The patient had a cesarean section.
# tensor([1.0582e-04, 2.2313e-03, 9.9766e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# No history of blood clots or DVTs, has never had chest pain prior to one week ago.
# Patient has had multiple PEs
# tensor([0.0141, 0.1219, 0.8640], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# He is transferred to the floor to await biopsy results and further plans.
# He is status-post biopsy
# tensor([4.9088e-01, 7.7962e-07, 5.0912e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# History of end-stage renal disease.
# patient is on dialysis
# tensor([8.5192e-01, 1.4808e-01, 1.4718e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Hx of substance abuse CHF EF 55% Diastolic dysfunction VRE, MRSA Hx of chronic pain Right shoulder pain Anemia of chronic disease Constipation
# Patient has low hematocrit
# tensor([3.3960e-01, 6.6030e-01, 9.9813e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# He had one episode of pancreatitis 15 years ago, and another in [**3139**].
# The patient is an alcoholic.
# tensor([4.2212e-05, 9.9996e-01, 6.3413e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# The pain appeared localized mostly to his back without any radiation.
# the patient has a compression fracture
# tensor([9.0085e-04, 9.8901e-01, 1.0087e-02], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# He denies any lightheadedness, dizziness, palpitations, or chest pain.
# The patient
# tensor([5.5704e-04, 1.2052e-01, 8.7893e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# CARDIOVASCULAR: A regular rate and rhythm.
# Patient has normal echo
# tensor([0.7691, 0.1183, 0.1126], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# She had to 2PIVs placed and was started on octreotide and PPI gtt.
# the patient has no history of GI bleed
# tensor([2.2220e-08, 1.3944e-10, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Of note, the patient has been suffering from nausea, vomiting, and diarrhea (unknown if bloody/bilious) over the past week or so with minimal PO intake - occasional soda during the day.
# The patient has gastroenteritis.
# tensor([1.0892e-02, 9.8911e-01, 1.3164e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# He received approximately 3 liters of normal saline with improvement in his blood pressures to the 100s systolic.
# the patient was resuscitated
# tensor([9.9957e-01, 4.2689e-04, 3.0249e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Lung adenocarcinoma with metastases to brain, [**Year (4 digits) 494**], pericardium.
# The patient has stage IV lung cancer.
# tensor([1.6027e-02, 9.8397e-01, 1.9113e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# PAST MEDICAL HISTORY:  Significant for sacral decubitus Stage IV ulcer since [**3436-2-2**], he is a para[** Location **] times nine years which occurred after a thoracotomy procedure, bladder rupture, recurrent urinary tract infections, diabetes mellitus Type 2 with neuropathy, osteomyelitis and history of Clostridium difficile colitis, scrotal fissure/gangrene, congenital nystagmus, depression with suicidal ideations, hypoaldosteronism, hypomania and questionable history of gastrointestinal bleed.
# ...
# tensor([0.0773, 0.0014, 0.9214], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# During hospitalization, patient became progressively more dyspnic requiring BiPAP and then a NRB.
# The patient is on room air.
# tensor([1.8208e-11, 1.7049e-09, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  This is a 63 year old male with chronic obstructive pulmonary disease, status post multiple recent admissions for chronic obstructive pulmonary disease flares, status post recent discharge from [**Hospital3 **] [**Hospital **] [**First Name (Titles) **] [**Last Name (Titles) **] on [**6-26**], when he was intubated in the Medicine Intensive Care Unit for a chronic obstructive pulmonary disease flare.
# Patient has normal PFTs
# tensor([1.2829e-12, 7.7069e-06, 9.9999e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# The clindamycin was discontinued after five days.
# Patient has an infection
# tensor([9.0735e-02, 9.0926e-01, 4.2226e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# - Myelodysplastic syndrome first diagnosed [**3213-7-9**], treated with danazol and aranesp.
# The patient has no cancer
# tensor([1.3124e-08, 3.4052e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Family reports that patient has been undergoing "neuro" eval for progressive memory loss over past year or so.
# Patient has acute cognitive impairment
# tensor([8.0212e-01, 1.9787e-01, 7.6292e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Lasix was also given for "low urine output." while his pressure was 84/41.
# the patient is hypertensive
# tensor([6.5350e-05, 1.4374e-04, 9.9979e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# CHF (EF indeterminate on most recent Echo).
# Patient has chronic medical condition
# tensor([9.3962e-01, 6.0369e-02, 8.2192e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Chronic RLE ulcer, rest non-invasive arterial studies normal on [**3379-1-8**].
# Chronic wound on right lower extremity
# tensor([9.9840e-01, 8.6289e-04, 7.3511e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Right Colon Cancer 14.
# the patient has no cancer history
# tensor([5.8604e-09, 5.3463e-06, 9.9999e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Anxiety 12. h/o Anemia - hemolytic anemia after Keflex 13.
# The patient had an adverse reaction to Keflex
# tensor([2.6467e-02, 9.7353e-01, 3.4365e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# ================================================
# A renal biopsy at this time showed signs of rejection and he received a three day pulse of steroids and subsequently did well.
# The patient is immunocompromised.
# tensor([3.5588e-05, 9.9995e-01, 1.1176e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# She required 100%oxygen.
# patient is intubated
# tensor([9.9913e-01, 5.3797e-04, 3.2855e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# She progressed to a vaginal delivery.
# The patient had an epidural.
# tensor([0.4565, 0.5385, 0.0050], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Diabetes type 2.
# Patient has a chronic medical condition
# tensor([9.9886e-01, 1.1397e-03, 2.7333e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# During admission, patient was noted to have acute renal failure on top of CRI secondary to multiple myeloma.
# the patient has acute renal failure
# tensor([9.9630e-01, 3.7008e-03, 2.1996e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# Repeat Hct stable, but in setting of drop in BP, he was transferred to MICU for closer monitoring.
# The patient has a GI bleed.
# tensor([3.1867e-01, 6.8133e-01, 3.9023e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# HTN 10.sinusitis diagnosed during last admission 11. h/o R PTX last hospitalization requiring CT placement (d/c'd) 12. ?hypoxic brain injury with paresis and cognitive deficit 13.
# The patient has normal neural anatomy.
# tensor([6.0400e-14, 3.5019e-06, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Lactate 3.4 .
# the patient has a normal lactate
# tensor([1.8542e-07, 6.8343e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# He took an OTC indigestion remedy, and his pain eventually resolved after a couple of hours.
# His pain worsened after taking an over the counter medication
# tensor([0.5726, 0.4132, 0.0142], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# He was referred to [**Hospital1 1499**] for cardiac catheterization.
# The patient has symptoms to warrant evaluation of his coronary arteries.
# tensor([9.9997e-01, 3.0141e-05, 1.8886e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# The RCA occlusion was stented.
# patient has heart failure
# tensor([9.0662e-01, 9.3383e-02, 5.0725e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Her respiratory status seems to improve with nebs and diuresis.
# The patient has COPD.
# tensor([6.6516e-10, 1.0000e+00, 3.0298e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# HISTORY OF PRESENT ILLNESS:  The patient is a 53-year-old female with a complicated medical history who presented to [**Hospital6 817**] Emergency Room after 2-3 days of shortness of breath, productive cough, and recent syncopal episodes, four in the past month, with outpatient EEG negative in [**3287-6-22**].
# The patient has pneumonia
# tensor([3.1017e-06, 1.0000e+00, 8.9193e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Estimated blood loss was [**2872**] cc and she received 3 units of packed red blood cells in total and her hematocrit at the postoperative check was at 34.
# the patient did not have blood loss
# tensor([3.1895e-07, 6.0624e-05, 9.9994e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# He was admitted to [**Hospital3 3704**] [**Hospital3 **] for a rather paroxysmal episode of pulmonary edema and during the work up it was noted that his peripheral vascular disease was profound and a bypass in these extremities was planned.
# Patient has PAD
# tensor([2.9807e-07, 1.0000e+00, 7.2093e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# This a.m. the patient was tachypneic with O2 saturations 92% to 94% on room air with respiratory rate in the 40s.
# The patient has a history of pulmonary embolism
# tensor([5.0138e-07, 1.0000e+00, 3.2693e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# An MRA of the neck demonstrated probable stenosis in the right brachiocephalic artery, high grade stenoses in the proximal aspect of both internal carotid arteries, irregularity in the proximal left subclavian artery, and narrowing in the proximal right vertebral artery.
# The patient has normal arterial vascular waveforms on Doppler ultrasound.
# tensor([9.9501e-09, 2.2791e-05, 9.9998e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Mongolian spots on back.
# Patient has no exam findings
# tensor([5.2580e-05, 6.9286e-08, 9.9995e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Pt has hx of MRSA infection in this wound. .
# The patient had a chronically infected wound.
# tensor([9.9818e-01, 1.8181e-03, 1.6583e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# [**Name (NI) 632**] mother reports dark discharge from the J-tube.
# The patient has chronic disease
# tensor([1.9239e-01, 8.0760e-01, 3.2907e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# History of end-stage renal disease.
# The patient is on dialysis.
# tensor([7.8112e-01, 2.1888e-01, 2.2951e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# The pain localizes to her lower abdomen & has been worsening.
# Patient has an aneurysm
# tensor([6.7525e-02, 9.3247e-01, 1.5627e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# DM type II: for 20 years typically under good control unless  she is sick 4.
# Patient has a chronic medical disease
# tensor([7.9376e-01, 2.0624e-01, 3.1345e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# On arrival to the MICU, the pt is resting comfortably, denies lightheadedness.
# The patient requires a high level of care.
# tensor([0.8504, 0.0103, 0.1393], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# [**Known patient lastname 24765**] is an 84 y/o man with PMH notable for CAD, PVD, and chronic atrial fibrillation on coumadin who presents to the ED from [**Hospital **] Rehab due to hypotension in setting of UTI.
# The patient has a chronic indwelling foley.
# tensor([4.1128e-01, 5.8872e-01, 5.2095e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# Mother was treated with magnesium sulfate.
# Mother has eclampsia
# tensor([3.1611e-03, 9.9624e-01, 6.0258e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# He felt this was likely due to fluid overload but did not improve with dialysis.
# The patient has normal functioning kidneys.
# tensor([7.6039e-13, 6.1126e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# Patient admitted to [**Hospital Ward Name **] 3, continued to have abdominal pain, RUQ U/S c/w cholecystitis however no LFT abnormalities on admission.
# Patient has positive imaging findings
# tensor([9.9990e-01, 8.3160e-05, 1.3149e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# In the [**Name (NI) **], pt was febrile to 103 with BP 89/57.
# the patient had normal vital signs
# tensor([6.1173e-13, 4.3508e-07, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 0., 1.])
# ------------------------------------------
# HISTORY:  Baby [**Name (NI) **] [**Known patient lastname 6048**] is the 3.09 kg product of a 36 and [**4-24**] week gestation born to a 37 year-old, Gravida IV, Para 2 woman.
# The patient has normal height.
# tensor([4.8477e-07, 1.5555e-04, 9.9984e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# No known sick contacts.
# No recent exposure to people with illness
# tensor([9.9692e-01, 7.0720e-04, 2.3710e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([1., 0., 0.])
# ------------------------------------------
# On the floor, pt initially unresponsive to command, voice, touch, arouse briefly to sternal rub.
# Patient has sepsis
# tensor([2.3609e-09, 1.0000e+00, 5.0858e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([0., 1., 0.])
# ------------------------------------------
# ================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-c852482d335c> in <cell line: 1>()
#       1 for x_pre, x_hyp, y in val_loader:
# ----> 2     outputs = model(x_pre,x_hyp)
#       3     for i in range(bsize):
#       4           print(x_pre[i])
#       5           print(x_hyp[i])
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# <ipython-input-17-3a88dad0d905> in forward(self, x_pre, x_hyp)
#      10
#      11     def forward(self, x_pre,x_hyp):
# ---> 12         out1 = self.transformer1(x_pre)
#      13         out2 = self.transformer2(x_hyp)
#      14         out1 = torch.mean(out1,1)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# <ipython-input-16-111203c68582> in forward(self, src)
#      13     def forward(self, src):
#      14         src_mask = None
# ---> 15         enc_out = self.encoder(src, src_mask).to(device)
#      16         return enc_out
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# <ipython-input-15-c419acd7639f> in forward(self, x, mask)
#      14         N = pe.size(0)
#      15         seq_len = pe.size(1)
# ---> 16         positions = torch.arange(0, seq_len).expand(N, seq_len).to(self.device)
#      17         out = self.dropout((pe + self.positional_embedding(positions)))
#      18         for layer in self.layers:
#
# KeyboardInterrupt:

# %%
model('bad at math','bad good at physic not in math')
# Out:
# tensor([[9.9929e-01, 5.4514e-05, 6.5749e-04]], device='cuda:0',
#        grad_fn=<SoftmaxBackward0>)

# %%
we = embedding_layer(bert_model,tokenizer)
# Out:
# tensor([[[-0.1001,  0.0229,  0.0996,  ..., -0.7275,  0.5847,  0.0338],
#          [-0.0962,  0.3744,  0.5197,  ...,  0.0758,  0.8064,  0.2582],
#          [ 0.4098, -0.7050, -0.1090,  ..., -0.0779,  1.1593,  0.1215],
#          [ 0.4027, -0.4549,  0.3251,  ..., -0.4525,  0.7223,  0.0644],
#          [ 0.2920, -0.2023,  0.3574,  ..., -0.4897,  0.4772, -0.0054],
#          [-0.1001,  0.0229,  0.0996,  ..., -0.7275,  0.5847,  0.0338]]],
#        device='cuda:0')
