# %%
# !pip install fasttext
# !pip install fastparquet
# !gdown --id '1QB54qk82PsJBv9AfAjdiq5Bp5Sm0vFna'
# !gdown --id '1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp'
# !unzip MedNLI_dataset.zip
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 2.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.1-py3-none-any.whl (238 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.25.2)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4246762 sha256=21ddc4676c9516b683a83c5642a0838faf4be1a6d7b6bf822bafd38b213342d4
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.1
# Collecting fastparquet
#   Downloading fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 25.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.25.2)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 75.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.8.3 fastparquet-2024.5.0
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1QB54qk82PsJBv9AfAjdiq5Bp5Sm0vFna
# From (redirected): https://drive.google.com/uc?id=1QB54qk82PsJBv9AfAjdiq5Bp5Sm0vFna&confirm=t&uuid=0e5932f9-9f77-4cb3-a969-fa6f835a91dc
# To: /content/modelx.pth
# 100% 516M/516M [00:11<00:00, 44.2MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp
# To: /content/MedNLI_dataset.zip
# 100% 681k/681k [00:00<00:00, 160MB/s]
# Archive:  MedNLI_dataset.zip
#    creating: MedNLI_dataset/
#   inflating: MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet
#   inflating: MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet
#   inflating: MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet

# %%
from transformers import AutoTokenizer, AutoModel, AutoModelForSeq2SeqLM
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset,DataLoader, random_split
from sklearn.metrics import accuracy_score

# %%
test_data = pd.read_parquet('MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet', engine='fastparquet')
train_data = pd.read_parquet('MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet', engine='fastparquet')
valid_data = pd.read_parquet('MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet', engine='fastparquet')
test_data
# Out:
#               id                                              query  \
# 0        MedNLI0  \nTASK: Please classify the relationship betwe...
# 1        MedNLI1  \nTASK: Please classify the relationship betwe...
# 2        MedNLI2  \nTASK: Please classify the relationship betwe...
# 3        MedNLI3  \nTASK: Please classify the relationship betwe...
# 4        MedNLI4  \nTASK: Please classify the relationship betwe...
# ...          ...                                                ...
# 1417  MedNLI1417  \nTASK: Please classify the relationship betwe...
# 1418  MedNLI1418  \nTASK: Please classify the relationship betwe...
# 1419  MedNLI1419  \nTASK: Please classify the relationship betwe...
# 1420  MedNLI1420  \nTASK: Please classify the relationship betwe...
# 1421  MedNLI1421  \nTASK: Please classify the relationship betwe...
#
#              answer                               choices  gold
# 0        entailment  [entailment, contradiction, neutral]     0
# 1     contradiction  [entailment, contradiction, neutral]     1
# 2           neutral  [entailment, contradiction, neutral]     2
# 3        entailment  [entailment, contradiction, neutral]     0
# 4     contradiction  [entailment, contradiction, neutral]     1
# ...             ...                                   ...   ...
# 1417  contradiction  [entailment, contradiction, neutral]     1
# 1418        neutral  [entailment, contradiction, neutral]     2
# 1419     entailment  [entailment, contradiction, neutral]     0
# 1420  contradiction  [entailment, contradiction, neutral]     1
# 1421        neutral  [entailment, contradiction, neutral]     2
#
# [1422 rows x 5 columns]

# %%
def find_pre_and_hyp(query):
    start_pre = query.find("[PRE]") + len("[PRE]")
    end_pre = query.find("[HYP]")
    start_hyp = query.find("[HYP]") + len("[HYP]")
    end_hyp = query.find("OUTPUT:")
    premise = query[start_pre:end_pre].strip()
    hypothesis = query[start_hyp:end_hyp].strip()

    return premise,hypothesis

# %%
class CustomDataset(Dataset):
    def __init__(self, x_list, y_list):
        self.samples = []
        for x,y in zip(x_list,y_list):
            #x_tensor = torch.tensor(x,dtype = torch.float32)
            y_tensor = torch.tensor(y,dtype = torch.float32)
            self.samples.append((x[0],x[1],y_tensor))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("gsarti/biobert-nli")
bert_model = AutoModel.from_pretrained("gsarti/biobert-nli").to(device)
src_pad_idx = 0
src_vocab_size = bert_model.config.vocab_size
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
def get_lists(data):
    x_list = []
    y_list = []
    i =0
    for query,answer in zip(data['query'],data['answer']):
        i = i + 1
        if answer == 'entailment':
           y = [1,0,0]
        elif answer == 'neutral':
           y = [0,1,0]
        elif answer == 'contradiction':
           y = [0,0,1]
        else:
           print('should not get here')

        premise,hypothesis = find_pre_and_hyp(query)
        x_list.append((premise,hypothesis))
        y_list.append(y)
    return x_list,y_list

# %%
train_x_list,train_y_list = get_lists(train_data)
test_x_list,test_y_list = get_lists(test_data)
val_x_list,val_y_list = get_lists(valid_data)

# %%
print(len(train_x_list))
print(len(train_y_list))
print(len(test_x_list))
print(len(test_y_list))
print(len(val_x_list))
print(len(val_y_list))
# Out:
# 11232
# 11232
# 1422
# 1422
# 1395
# 1395

# %%
train_dataset = CustomDataset(train_x_list,train_y_list)
test_dataset = CustomDataset(test_x_list,test_y_list)
val_dataset = CustomDataset(val_x_list,val_y_list)

# %%
class embedding_layer(nn.Module):
  def __init__(self,bert_model,tokenizer):
    super(embedding_layer, self).__init__()
    self.bert_model = bert_model
    self.tokenizer = tokenizer

  def forward(self, x):
    with torch.no_grad():
         s = tokenizer(x,return_tensors="pt",padding=True).to(device)
         vec = bert_model(**s)['last_hidden_state'].to(device)
    return vec

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, seq_len,embedding_size):
        super().__init__()
        self.dropout = nn.Dropout(0.1)
        self.embedding_size = embedding_size
        self.seq_len = seq_len

    def forward(self, x):
        pe = torch.zeros(x.size(0), x.size(1), self.embedding_size).to(device)
        div_term = torch.zeros(x.size(0), 1, self.embedding_size).to(device)
        ks = torch.arange(self.embedding_size).float().to(device)
        values = torch.exp(-torch.log(torch.tensor(1000.0)) * 2 * ks / self.embedding_size).to(device)
        values = values.view(1, 1, -1).to(device)
        div_term = div_term + values
        x = x.reshape([x.shape[0],x.shape[1],1]).to(device)
        pe[:, :, ::2] = torch.sin(x * div_term)[:, :, ::2].to(device)
        pe[:, :, 1::2] = torch.cos(x * div_term)[:, :, 1::2].to(device)
        return self.dropout(pe)

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, embedding_size, heads):
        super().__init__()
        self.embedding_size = embedding_size
        self.heads = heads
        self.head_dim = embedding_size // heads
        assert(self.heads * self.head_dim == self.embedding_size), "Invalid number of heads"
        self.fc_values = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_keys = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_queries = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_out = nn.Linear(heads * self.head_dim, embedding_size).to(device)

    def forward(self, values, keys, queries, mask):
        N = queries.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], queries.shape[1]
        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = queries.reshape(N, query_len, self.heads, self.head_dim)
        values = self.fc_values(values).to(device)
        keys = self.fc_keys(keys).to(device)
        queries = self.fc_queries(queries).to(device)
        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys]).to(device)
        if mask is not None:
            energy = energy.masked_fill(mask.to(device) == 0, float("-1e20")).to(device)
        energy = torch.softmax(energy / (self.embedding_size ** 0.5), dim=3).to(device)
        attention = torch.einsum("nhql,nlhd->nqhd", [energy, values]).to(device)
        attention = attention.reshape(N, query_len, self.heads * self.head_dim).to(device)
        out = self.fc_out(attention)
        return out

# %%
class TransformerBlock(nn.Module):
    def __init__(self, embedding_size, heads, forward_expansion, p):
        super().__init__()
        self.attention = MultiHeadAttention(embedding_size, heads)
        self.norm1 = nn.LayerNorm(embedding_size)
        self.feed_forward = nn.Sequential(nn.Linear(embedding_size, forward_expansion * embedding_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion * embedding_size, embedding_size))
        self.norm2 = nn.LayerNorm(embedding_size)
        self.dropout = nn.Dropout(p)
    def forward(self, values, keys, queries, mask):
        attention_out = self.attention(values, keys, queries, mask)
        x = self.norm1(attention_out + queries)
        x = self.dropout(x)
        ff_out = self.feed_forward(x)
        out = self.norm2(ff_out + x)
        out = self.dropout(out)
        return out

# %%
class Encoder(nn.Module):
    def __init__(self, src_vocab_size, embedding_size, num_layers, heads,
                 forward_expansion, max_length, p, device):
        super().__init__()
        self.device = device
        self.word_embedding = embedding_layer(bert_model,tokenizer)
        self.positional_embedding = PositionalEncoding(max_length, embedding_size)
        self.layers = nn.ModuleList([TransformerBlock(embedding_size, heads, forward_expansion, p) for _ in range(num_layers)])
        self.dropout = nn.Dropout(p)

    def forward(self, x, mask):
        mask = None
        pe = self.word_embedding(x)
        N = pe.size(0)
        seq_len = pe.size(1)
        positions = torch.arange(0, seq_len).expand(N, seq_len).to(self.device)
        out = self.dropout((pe + self.positional_embedding(positions)))
        for layer in self.layers:
            out = layer(out, out, out ,mask)
        return out

# %%
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, src_pad_idx, embedding_size=768,
                 num_layers=1, forward_expansion=8, heads=8, max_length=100, p=0.1):
        super().__init__()
        self.src_pad_idx = src_pad_idx
        self.encoder = Encoder(src_vocab_size, embedding_size, num_layers, heads,
                               forward_expansion, max_length, p, device)

    def get_src_mask(self, src):
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2).to(device)
        return src_mask

    def forward(self, src):
        src_mask = None
        enc_out = self.encoder(src, src_mask).to(device)
        return enc_out

# %%
class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.transformer1 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.transformer2 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.fc1 = nn.Linear(768*2, 256).to(device)
        self.fc2 = nn.Linear(256, 3).to(device)

    def forward(self, x_pre,x_hyp):
        out1 = self.transformer1(x_pre)
        out2 = self.transformer2(x_hyp)
        out1 = torch.mean(out1,1)
        out2 = torch.mean(out2,1)
        x = torch.cat((out1,out2),1)
        x = F.relu(self.fc1(self.dropout1(x)))
        x = nn.functional.softmax(self.fc2(self.dropout2(x)),dim=1)
        return x

# %%
bsize = 32
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=bsize, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=bsize, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %%
def get_model_acc(model,data_loader):
    model.eval()
    predicted_labels = []
    true_labels = []
    for x_pre, x_hyp, y in data_loader:
        outputs = model(x_pre,x_hyp)
        prediction= torch.argmax(outputs, dim=1).cpu().numpy()
        predicted_labels.extend(prediction)
        true_label = torch.argmax(y, dim=1).cpu().numpy()
        true_labels.extend(true_label)
    model.train()
    return accuracy_score(true_labels, predicted_labels)

# %%
model = torch.load('modelx.pth', map_location=device)

# %%
get_model_acc(model.to(device),test_loader)
# Out:
# 0.7215189873417721

# %%
get_model_acc(model,val_loader)
# Out:
# 0.7455197132616488

# %%
get_model_acc(model,train_loader)
# Out:
# 0.8496260683760684

# %%
def get_inference_text(num):
    if num == 0:
         return 'entailment'
    elif num == 1:
         return 'neutral'
    elif num == 2:
         return 'contradiction'

# %%
count = 0
for x_pre, x_hyp, y in val_loader:
    outputs = model(x_pre,x_hyp)
    prediction = torch.argmax(outputs, dim=1).cpu().numpy()
    for i in range(len(x_pre)):
          p = prediction[i]
          t = np.argmax(y[i].numpy())
          if p != t:
             count = count +1
             print(count)
             print(x_pre[i])
             print(x_hyp[i])
             print(get_inference_text(p))
             print(get_inference_text(t))
             print('------------------------------------------')
    print('================================================')
# Out:
# 1
# Intrapartum course notable for meconium stained amniotic fluid but no identified sepsis risk factors.
# Amniotic fluid was observed to be stained with meconium
# contradiction
# entailment
# ------------------------------------------
# 2
# He continued to receive his daily aspirin, but his beta blocker was held secondary to his chronic obstructive pulmonary disease flare.
# The has a pulmonary condition.
# neutral
# entailment
# ------------------------------------------
# 3
# Family reports that patient has been undergoing "neuro" eval for progressive memory loss over past year or so.
# Patient has acute cognitive impairment
# entailment
# contradiction
# ------------------------------------------
# 4
# Initially [**7-8**] pain but now [**4-7**] s/p Morphine 2mg IV at 9:30 am.
# The patient has significant pain.
# entailment
# neutral
# ------------------------------------------
# 5
# She is still complaining of non-productive cough, congestion, fever/chills, wheezing.
# She had recent sick contacts
# entailment
# neutral
# ------------------------------------------
# 6
# CHF, EF 55% 6.
# Congestive heart failure
# neutral
# entailment
# ------------------------------------------
# 7
# She was extubated on [**3319-9-3**] at 5 P.M., tolerated well and was transferred to the floor on [**9-2**].
# She was functioning well after tube was removed
# contradiction
# entailment
# ------------------------------------------
# 8
# Her EKG showed a ventricularly paced rhythm with no significant changes from prior tracings.
# Patient has abnormal EKG
# neutral
# entailment
# ------------------------------------------
# ================================================
# 9
# Her hemodynamics showed PA pressures of 56/35, wedge of 31, cardiac output of 3.88 and index of 1.86.
# The patient has low pulmonary arterial pressure.
# entailment
# contradiction
# ------------------------------------------
# 10
# Of note, recently hospitalized from 12/20-12-29/06 with NSTEMI s/p stent placed at [**Hospital1 111**] (see below) - in note states pt was d/c'd off lasix, but discharge meds state he was taking lasix.
# the patient is taking the appropiate medications
# neutral
# contradiction
# ------------------------------------------
# 11
# She was then admitted to MICU for presumed urosepsis. .
# Patient has sepsis
# neutral
# entailment
# ------------------------------------------
# 12
# A barrium swallow on [**2632-10-27**] was suggestive of partial obstruction at the second portion of the duodenum.
# Barium swallow revealed small bowel obstruction
# neutral
# entailment
# ------------------------------------------
# 13
# He was admitted to the MICU for management of sepsis. .
# He had an infection leading to sepsis
# neutral
# entailment
# ------------------------------------------
# ================================================
# 14
# Her son found her sitting on the floor yesterday evening and called 911.
# the patient was found on the ground
# contradiction
# entailment
# ------------------------------------------
# 15
# Migraines with visual aura.
# the patient has migraines
# neutral
# entailment
# ------------------------------------------
# 16
# Left ventriculogram revealed preserved LV function and no mitral regurgitation.
# Patient has normal LV function
# neutral
# entailment
# ------------------------------------------
# 17
# Her [** Location **]us UGIB required hospitalization, which was notable for a hematocrit of 16 on admission, 11 units of packed red blood cells transfusion during stay, 2 units of fresh frozen platelets, esophagogastroduodenoscopy showing gastritis and normal duodenum, cauterization of a gastric AVM, and angiography followed by embolization of left gastric artery.
# The patient’s bleed was caused by gastric varacies.
# neutral
# contradiction
# ------------------------------------------
# 18
# HTN 10.sinusitis diagnosed during last admission 11. h/o R PTX last hospitalization requiring CT placement (d/c'd) 12. ?hypoxic brain injury with paresis and cognitive deficit 13.
# The patient has multiple medical conditions.
# entailment
# neutral
# ------------------------------------------
# 19
# No history of blood clots or DVTs, has never had chest pain prior to one week ago.
# Patient has angina
# contradiction
# entailment
# ------------------------------------------
# 20
# He was given Lasix 20 mg IV x 1 with good response.
# patient is fluid depleted
# entailment
# contradiction
# ------------------------------------------
# 21
# She was lightheaded and weak.
# She felt faint
# neutral
# entailment
# ------------------------------------------
# 22
# Mother developed separation of symphysis pubis and was put in traction.
# Patient has orthopedic injuries
# neutral
# entailment
# ------------------------------------------
# 23
# Elevated ESR - several years, ?etiology - polymyalgia rheumatica 10.
# the patient has chronic pain
# entailment
# neutral
# ------------------------------------------
# 24
# The patient had [** Location **]usly been in his usual state of health until [**11-3**] when he began to experience a "flu-like" illness that was associated with high fevers, cough, shortness of breath, dyspnea, and nausea with a decreased  At the outside hospital, the patient was found to have bilateral interstitial infiltrates in the lower lobes and was treated with a course of several different antibiotics.
# The patient has pneumonia.
# neutral
# entailment
# ------------------------------------------
# 25
# History of pulmonary embolism.
# patient has had a PE
# neutral
# entailment
# ------------------------------------------
# 26
# During admission, patient was noted to have acute renal failure on top of CRI secondary to multiple myeloma.
# the patient has medication induced renal failure
# entailment
# neutral
# ------------------------------------------
# ================================================
# 27
# On arrival to the MICU, the pt is resting comfortably, denies lightheadedness.
# The patient is on the regular hospital ward.
# neutral
# contradiction
# ------------------------------------------
# 28
# He took an OTC indigestion remedy, and his pain eventually resolved after a couple of hours.
# His pain worsened after taking an over the counter medication
# entailment
# contradiction
# ------------------------------------------
# 29
# At that time, a CBC and Chem-7 was drawn and the Chem-7 was within the normal range for all of his electrolytes as well as his renal function.
# patient has a normal diet
# contradiction
# neutral
# ------------------------------------------
# 30
# Left femoral A-V fistula [**3362-3-10**]
# History of lower extremity trauma
# entailment
# neutral
# ------------------------------------------
# ================================================
# 31
# On the day of admission, she had difficulty driving, she pulled over and passed out.
# The patient is hypotensive.
# entailment
# neutral
# ------------------------------------------
# 32
# At her oncologist's office, she was noted to have an irregularly irregular pulse in the 150s.
# The patient has a cardiac arrhythmia.
# neutral
# entailment
# ------------------------------------------
# 33
# On [**1-28**], she underwent a Myoview which showed a mildly dilated left ventricular infarction involving the basal portion of her inferior wall as well as her anterior wall and a probable infarction with moderate ischemia of the lateral wall and an ejection fraction of 41%.
# The patient had an echocardiogram.
# neutral
# entailment
# ------------------------------------------
# 34
# Bilateral carotid stenosis 80 to 90% right greater then left.
# The patient has a CVA.
# entailment
# neutral
# ------------------------------------------
# 35
# Bilateral carpal tunnel release surgery.
# History of carpal tunnel syndrome
# neutral
# entailment
# ------------------------------------------
# 36
# HISTORY OF PRESENT ILLNESS:  The patient is a 49 year old otherwise healthy female, on only aspirin 81 mg daily, who comes in after a routine physical examination and her primary care physician having heard [**Name Initial (PRE) **] murmur.
# Patient has a negative ROS
# contradiction
# neutral
# ------------------------------------------
# 37
# PERSONAL HABITS:  She is single and lives with a friend.
# The patient has no children.
# entailment
# neutral
# ------------------------------------------
# 38
# Had Apgars of 5, 5 and 8 at 1, 5 and 10 minutes.
# APGARS were normal at 1, 5 and 10 minutes
# entailment
# contradiction
# ------------------------------------------
# 39
# HISTORY:  Baby Girl [**Known patient lastname **] is the [**3004**]-gram product of a 34-1/7- weeks twin gestation born to a 32-year-old G9, P2, now 3 mother.
# Patient has normal weight
# contradiction
# neutral
# ------------------------------------------
# ================================================
# 40
# On weaning to 6L NC, his O2 sat decreased to 81-82%
# Patient has poor O2 sats
# neutral
# entailment
# ------------------------------------------
# 41
# History of gastric bypass surgery (complicated by a ventral hernia, and reversal of her bypass, as well as abdominal wall abscesses, and chronic abdominal pain).
# The patient has chronic pain.
# neutral
# entailment
# ------------------------------------------
# 42
# 89F with multiple medical problems who presented to [**Hospital1 68**] on [**3287-1-7**] d/t hypotension from E. coli urosepsis in setting of poor PO intake, hypovolemia, and poor IV access/fluid administration.
# History of UTI
# neutral
# entailment
# ------------------------------------------
# 43
# Unable to keep fluid down.
# Patient has nausea
# neutral
# entailment
# ------------------------------------------
# 44
# Hx of substance abuse CHF EF 55% Diastolic dysfunction VRE, MRSA Hx of chronic pain Right shoulder pain Anemia of chronic disease Constipation
# Patient has constant shoulder pain
# entailment
# neutral
# ------------------------------------------
# 45
# HISTORY OF PRESENT ILLNESS:  Patient is an unfortunate 58-year-old male, who is a fire fighter, who sustained an approximately 14 foot fall on a moving fire truck going approximately 5 miles per hour.
# The patient sustained a gun shot wound.
# neutral
# contradiction
# ------------------------------------------
# 46
# [**Known patient lastname 24765**] is an 84 y/o man with PMH notable for CAD, PVD, and chronic atrial fibrillation on coumadin who presents to the ED from [**Hospital **] Rehab due to hypotension in setting of UTI.
# The patient has urosepsis.
# neutral
# entailment
# ------------------------------------------
# ================================================
# 47
# PRENATAL SCREENS:  Blood group A+, direct antibody test negative, RPR nonreactive, rubella immune, hepatitis B surface antigen negative, group B streptococcus unknown.
# Patient has blood type B negative
# entailment
# contradiction
# ------------------------------------------
# 48
# HISTORY OF PRESENT ILLNESS:  Baby Girl [**Known patient lastname **] #2 is the 1755 gram product of a 33 and [**1-2**] week triplet gestation by IVF conception, born to a 35 year-old, Gravida 0, now 3 mom.
# the patient is breathing normally
# contradiction
# neutral
# ------------------------------------------
# 49
# During that admission he had a paracentesis for ~5 liters and started on spironolactone, lasix, and protonix.
# The patient would benefit from a liver transplant.
# entailment
# neutral
# ------------------------------------------
# 50
# Notes worsening SOB over the past few [**Known patient lastname 8656**], mild cough of whitish sputum, no hemoptysis.
# Patient has evidence of URI
# neutral
# entailment
# ------------------------------------------
# 51
# ESRD: on HD Tues/Th/Sat through L AV fistula, makes some urine 3.
# Patient has CKD
# neutral
# entailment
# ------------------------------------------
# 52
# CHF (EF indeterminate on most recent Echo).
# Patient has leg swelling
# entailment
# neutral
# ------------------------------------------
# 53
# Catheterization revealed a 100% totally occlusion of the first obtuse marginal, status post cypher stent placement.
# The patient had an acute myocardial infarction.
# neutral
# entailment
# ------------------------------------------
# 54
# She has a history of a positive PPD with a negative chest x- ray.
# The patient has a positive PPD.
# contradiction
# entailment
# ------------------------------------------
# 55
# OTHER PAST MEDICAL HISTORY: AFib - on amiodarone, coumadin stopped in late [**5-19**] LGIB Breast CA -2.7 cm grade I infiltrating lobular cancer, negative lymph nodes, negative LVI,negative margins and ER positive, HER-2/neu negative.
# Family history of breast cancer
# entailment
# neutral
# ------------------------------------------
# 56
# Renal consult was obtained at that time for a creatinine of 2.0.
# Patient has AKI
# neutral
# entailment
# ------------------------------------------
# ================================================
# 57
# Over the next couple of weeks in the Intensive Care Unit, the patient's ventilatory support had been easily weaned, and she was ultimately extubated approximately a week after transplant.
# The patient is on immunosuppressive medications.
# neutral
# entailment
# ------------------------------------------
# 58
# HISTORY OF PRESENT ILLNESS:  This is a 63 year old primarily Spanish speaking male with a history of end-stage renal disease secondary to diabetes mellitus on dialysis.
# The patient has an arterial venous fistula.
# entailment
# neutral
# ------------------------------------------
# 59
# She first had epistaxis from the right nare starting last Thursday.
# the patient has thrombocytopenia
# entailment
# neutral
# ------------------------------------------
# 60
# Atrial fibrillation, on Coumadin.
# Patient has NSR
# neutral
# contradiction
# ------------------------------------------
# 61
# Obstetrical history was notable for 2 [** Location **]us sections in [**3452**] at 28 weeks gestation and [**3457**] at 36 weeks gestation.
# She has a history of infertility
# neutral
# contradiction
# ------------------------------------------
# 62
# Mild stress incontinence.
# Denies bladder leakage
# neutral
# contradiction
# ------------------------------------------
# 63
# ﻿The patient was hemodynamically stable upon admission with an hematocrit of 34.
# The patient’s CBC was within normal limits
# contradiction
# neutral
# ------------------------------------------
# 64
# She received epidural anesthesia.
# Received anesthetic for pain
# neutral
# entailment
# ------------------------------------------
# 65
# At that time, a CBC and Chem-7 was drawn and the Chem-7 was within the normal range for all of his electrolytes as well as his renal function.
# patient is dehydrated
# neutral
# contradiction
# ------------------------------------------
# 66
# Ventricular drain was also removed on [**2810-12-14**].
# History of elevated intracranial pressure
# neutral
# entailment
# ------------------------------------------
# ================================================
# 67
# There was also FDG avidity between the right atrial appendage and the left ventricular outflow track without anatomic correlate.
# The patient has malignancy
# entailment
# neutral
# ------------------------------------------
# 68
# Intrapartum course notable for meconium stained amniotic fluid but no identified sepsis risk factors.
# The infant has multiple risk factors for sepsis
# neutral
# contradiction
# ------------------------------------------
# 69
# Upon presentation to the ED, he was given Vanco and Unasyn, was intermittently hypoxic with O2 sats 85% while sleeping and was placed on 2L NC and admitted to floor.
# His oxygen saturation was low
# neutral
# entailment
# ------------------------------------------
# ================================================
# 70
# Hct has been stable without other s/s of bleeding.
# Patient has no internal bleeding
# entailment
# neutral
# ------------------------------------------
# 71
# She notes some swelling throughout but denies joint swelling or redness.
# Denies joint effusion
# contradiction
# entailment
# ------------------------------------------
# 72
# Currently is nauseated, has double vision, is seeing bugs crawling all over the ceiling.
# Complains of diplopia
# neutral
# entailment
# ------------------------------------------
# 73
# Stroke in the past with diagnosis by MR in [**3190**] but without residual deficits.
# History of stroke
# neutral
# entailment
# ------------------------------------------
# 74
# She initially attributed this to her first prednisone which had been started that day for a gout flare.
# The patient has gout
# neutral
# entailment
# ------------------------------------------
# ================================================
# 75
# Her hematocrit was followed q. six hours and prior to discharge her hematocrit was 33.
# The patient had a bleed.
# entailment
# neutral
# ------------------------------------------
# 76
# On [**1-28**], she underwent a Myoview which showed a mildly dilated left ventricular infarction involving the basal portion of her inferior wall as well as her anterior wall and a probable infarction with moderate ischemia of the lateral wall and an ejection fraction of 41%.
# The patient coronary artery disease.
# entailment
# neutral
# ------------------------------------------
# 77
# Status post thyroidectomy.
# The patient has had neck surgery.
# neutral
# entailment
# ------------------------------------------
# 78
# The patient was on aspirin for chronic atrial fibrillation and spent a short course at rehabilitation before eventually being discharge to home.
# The patient has a history of arrhythmia
# neutral
# entailment
# ------------------------------------------
# 79
# [**Name (NI) 632**] mother reports dark discharge from the J-tube.
# The patient has chronic disease
# entailment
# neutral
# ------------------------------------------
# 80
# Infusion stopped and she was treated with Benadryl 50 mg x 1, prednisone 40 mg x 1, ativan 1 mg.
# Patient has had an allergic reaction
# neutral
# entailment
# ------------------------------------------
# 81
# As lab results returned, the ED physicians had become concerned for impending sepsis given elevated wbc count and fever.
# The patient is bacteremic.
# entailment
# neutral
# ------------------------------------------
# ================================================
# 82
# Recent MRI did not show any change in adenoma size -S[** Location **] rupture [**1-11**] MVA in [**3181**], no splenectomy required -h/o VRE bacteremia in [**3-15**].
# The patient has a pituitary macroadenoma
# contradiction
# neutral
# ------------------------------------------
# 83
# The infant emerged with spontaneous cry.
# The patient was born by vaginal delivery.
# contradiction
# neutral
# ------------------------------------------
# 84
# Reflex Sympathetic Dystrophy s/p fall, on disability, now resolved
# History of complex regional pain syndrome
# neutral
# entailment
# ------------------------------------------
# 85
# Infusion stopped and she was treated with Benadryl 50 mg x 1, prednisone 40 mg x 1, ativan 1 mg.
# Patient has recently had iodinated contrast
# entailment
# neutral
# ------------------------------------------
# 86
# The birth weight was 2,005 grams, birth length 44.5 cm, and the birth head circumference 30.5 cm.
# Patient is severely underweight
# entailment
# contradiction
# ------------------------------------------
# 87
# Atrial fibrillation, on Coumadin.
# Patient had elevated INR
# neutral
# entailment
# ------------------------------------------
# 88
# PRENATAL SCREENS:  Blood type O+, antibody negative, RPR nonreactive, rubella nonimmune, hepatitis B surface antigen negative, group beta strep status unknown.
# No history of sexually transmitted infections
# entailment
# neutral
# ------------------------------------------
# 89
# She had to 2PIVs placed and was started on octreotide and PPI gtt.
# the patient is GI bleeding
# neutral
# entailment
# ------------------------------------------
# ================================================
# 90
# Lactate improved from 2.7 to 1.1.
# Lactate levels increased
# entailment
# contradiction
# ------------------------------------------
# 91
# HISTORY:  Baby Girl [**Known patient lastname **] is the [**3004**]-gram product of a 34-1/7- weeks twin gestation born to a 32-year-old G9, P2, now 3 mother.
# Patient is a male
# neutral
# contradiction
# ------------------------------------------
# 92
# CHF, EF 55% 6.
# complains of shortness of breath
# entailment
# neutral
# ------------------------------------------
# 93
# Patient admitted to [**Hospital Ward Name **] 3, continued to have abdominal pain, RUQ U/S c/w cholecystitis however no LFT abnormalities on admission.
# Patient has positive Murphy’s sign
# entailment
# neutral
# ------------------------------------------
# ================================================
# 94
# [**Known patient lastname 26444**] is a 54y/o gentleman with HTN, HLD, DM2, CKD (baseline Cr 2.0-2.2), CAD s/p CABG [**2947**] (LIMA-LAD, SVG-PDA, and radial-OM1-OM2) with systolic and diastolic heart failure (EF has been as low as 20% in the past) who is admitted from clinic due to concern for CHF exacerbation.
# the patient has heart failure
# neutral
# entailment
# ------------------------------------------
# 95
# HISTORY OF PRESENT ILLNESS:  The patient is a 69-year-old gentleman with a past medical history significant for longstanding diabetes mellitus, coronary artery disease, and peripheral vascular disease who had been followed by Dr. [**First Name4 (NamePattern1) **] [**Last Name (NamePattern1) 1393**] for a painful nonhealing ulceration in the medial aspect of his right fifth toe.
# the patient has a non healing ulcer
# neutral
# entailment
# ------------------------------------------
# 96
# Hx of substance abuse CHF EF 55% Diastolic dysfunction VRE, MRSA Hx of chronic pain Right shoulder pain Anemia of chronic disease Constipation
# Patient has low hematocrit
# neutral
# entailment
# ------------------------------------------
# 97
# 88F with CAD, chronic diastolic CHF, Afib on coumadin, cardioembolic CVA, DM admitted with respiratory distress.
# the patient has an acute heart failure exacerbation
# entailment
# neutral
# ------------------------------------------
# 98
# She denied any recent rashes, CP, SOB or abdominal pain.
# She has no respiratory disease
# entailment
# neutral
# ------------------------------------------
# 99
# HISTORY: Not following commands.
# Patient is disorientated
# neutral
# entailment
# ------------------------------------------
# ================================================
# 100
# Decision was made to continue chest tube placement and chest tube drained 220cc of straw colored fluid.
# The patient has a pleural effusion.
# neutral
# entailment
# ------------------------------------------
# 101
# She required 100%oxygen.
# patient is intubated
# entailment
# neutral
# ------------------------------------------
# 102
# Her respiratory status seems to improve with nebs and diuresis.
# The patient is short of breath.
# neutral
# entailment
# ------------------------------------------
# 103
# She was admitted from [**Date range (1) 9292**] and discharged to a nursing home with a prednisone taper and levofloxacin and pain service f/u for likely radicular pain. .
# the patient is on antibiotics and steroids
# neutral
# entailment
# ------------------------------------------
# ================================================
# 104
# He states that he ate several handfuls of store-bought mixed nuts and reports that within 1 hour he noted swelling of his tongue.
# He has several allergies to food and drugs
# entailment
# neutral
# ------------------------------------------
# 105
# PMH: AAA, PVD w/ L iliac aneurysm, R [**Doctor Last Name **] aneurysm approx 5cm, L [**Doctor Last Name **] aneurysm approx 3 cm, chronic Afib, HTN, benign prostatic hyperplasia (no surgical history)
# The patient is at low risk for a stroke.
# neutral
# contradiction
# ------------------------------------------
# 106
# During that admission he had a paracentesis for ~5 liters and started on spironolactone, lasix, and protonix.
# The patient has cirrhosis.
# neutral
# entailment
# ------------------------------------------
# 107
# In the [**Name (NI) **], pt was febrile to 103 with BP 89/57.
# the patient had bacteremia
# entailment
# neutral
# ------------------------------------------
# 108
# PAST MEDICAL HISTORY:  Acute renal failure during last medical admission which is now resolved.
# the acute renal failure did not resolve
# entailment
# contradiction
# ------------------------------------------
# 109
# He stated at that time that he had been unable to move for 2 days [**12-21**] his back pain and was not eating or drinking.
# the patient has back pain
# neutral
# entailment
# ------------------------------------------
# 110
# He was found by his son on the floor next to his bed, who called EMS.
# Patient was unconscious
# neutral
# entailment
# ------------------------------------------
# ================================================
# 111
# He was transferred to [**First Name4 (NamePattern1) 1212**] [**Last Name (NamePattern1) **] [**First Name (Titles) **] [**Last Name (Titles) **] for cardiac catheterization, which showed severe three vessel disease and aortic stenosis.
# Patient requires a CABG
# neutral
# entailment
# ------------------------------------------
# 112
# CHF exacerbation was in the setting of new inferior HK and he was diuresed with hopes of pursuing RHC/LHC.
# The patient is fluid overloaded.
# neutral
# entailment
# ------------------------------------------
# 113
# Per her family, she fractured her pubic ramus 3 weeks ago.
# She sustained a fall 3 weeks ago
# entailment
# neutral
# ------------------------------------------
# 114
# No feature of autoimmune hepatitis.
# There are signs and symptoms of autoimmune hepatitis
# entailment
# contradiction
# ------------------------------------------
# 115
# [**Known patient lastname 24765**] is an 84 y/o man with PMH notable for CAD, PVD, and chronic atrial fibrillation on coumadin who presents to the ED from [**Hospital **] Rehab due to hypotension in setting of UTI.
# The patient has a chronic indwelling foley.
# entailment
# neutral
# ------------------------------------------
# 116
# At his last visit to oncology, he reported poor a[** Location **]e with early satiety.
# He also complains of nausea
# entailment
# neutral
# ------------------------------------------
# 117
# Started Rituxan for 4 weeks in 5/[**3492**].
# History of cancer
# entailment
# neutral
# ------------------------------------------
# 118
# HTN, DM, GERD, Hep B&C, IVDU(methadone), OA, BPH, CVA, MI, Pancytopenia-thrombocytopenia, HIT-, PNA, anxiety gunshot wound-LLE,Appy, L knee arthroscopy, L knee fusion c/b infection-hardware removal/flap
# Patient has abnormal blood pressure
# entailment
# neutral
# ------------------------------------------
# 119
# Anxiety 12. h/o Anemia - hemolytic anemia after Keflex 13.
# History of panic attacks
# entailment
# neutral
# ------------------------------------------
# 120
# This pregnancy is remarkable for a maternal past history of Crohn's disease, with two exacerbations during this pregnancy, requiring hospitalization.
# The patient has had a small bowel obstruction.
# entailment
# neutral
# ------------------------------------------
# ================================================
# 121
# Left common femoral dorsalis pedis bypass graft.
# Patient has CAD
# entailment
# neutral
# ------------------------------------------
# 122
# He states that he may have used 2x100mc fentanyl patches instead of his normal 50mcg and 100mcg as prescribed.
# Patient has taken his medications as written
# entailment
# contradiction
# ------------------------------------------
# 123
# Given hypotension, a quick bedside US of chest was performed, which showed no pericardial effusion.
# Patient has pericardial fluid
# neutral
# contradiction
# ------------------------------------------
# 124
# 61 yo M w/ hx etOH cirrhosis [**1-31**] EtOh, anemia, and hepato-renal syndrome presented to OSH for routine paracentesis and was found to have hyperkalemia.
# The patient has impaired liver function.
# neutral
# entailment
# ------------------------------------------
# 125
# History of [**Male First Name (un) **] mounted spotted fever.
# Patient is febrile
# entailment
# neutral
# ------------------------------------------
# 126
# Patient was brought to the [**Hospital1 **] Emergency Department.
# The patient presented to his primary care physician’s office
# entailment
# contradiction
# ------------------------------------------
# 127
# He was admitted to [**Hospital3 3704**] [**Hospital3 **] for a rather paroxysmal episode of pulmonary edema and during the work up it was noted that his peripheral vascular disease was profound and a bypass in these extremities was planned.
# Patient has PAD
# neutral
# entailment
# ------------------------------------------
# 128
# TIA, Arthritis, Gout, CRI (? Dialysis), Bladder tumor s/p resection
# the patient had a bladder tumor
# neutral
# entailment
# ------------------------------------------
# 129
# His diarrhea acutely worsened over the past 24 hours- he had 8 large watery BMs over this time period.
# He has constipation
# entailment
# contradiction
# ------------------------------------------
# 130
# Decision was made to continue chest tube placement and chest tube drained 220cc of straw colored fluid.
# The patient has a parapneunomic effusion.
# entailment
# neutral
# ------------------------------------------
# 131
# Cranial nerves II through XII are intact.
# Patient has normal brain MRI
# entailment
# neutral
# ------------------------------------------
# 132
# Per report, [**Date Range 17970**] at OSH were negative for DVT, while CTA chest was positive for PE.
# The patient has no history of PE.
# entailment
# contradiction
# ------------------------------------------
# ================================================
# 133
# He was brought in by  his cousin for concern for GIB, and currently denies that he had any hematemesis but instead endorses hematochezia.
# the patient has hematochezia
# neutral
# entailment
# ------------------------------------------
# 134
# When she arrived with his jacket he had shaking chills and was conscious and conversive.
# The patient is aphasic.
# entailment
# contradiction
# ------------------------------------------
# 135
# Of note, pt had a "double pneumonia" 2 months prior to admission in [**State 1823**], for which he was treated with levo and CTX.
# the patient has an abnormal chest x ray
# entailment
# neutral
# ------------------------------------------
# 136
# Estimated blood loss was [**2872**] cc and she received 3 units of packed red blood cells in total and her hematocrit at the postoperative check was at 34.
# the patient was transfused intraoperatively
# neutral
# entailment
# ------------------------------------------
# 137
# s/p MI cath [**Hospital3 **] 60 % circ and 70% RCA with EF 59% [**3370-12-1**]  [**3373-11-1**] had wheezing, so chest CT was obtained showing mass, right hilar 3 cm mass encasing bronchus, 4 biopsies were non-diagnostic HTN +PPD, treated
# Patient has evidence of CAD
# neutral
# entailment
# ------------------------------------------
# 138
# HISTORY:  This is a 35 week male infant [**Year (4 digits) **] by spontaneous vaginal delivery after spontaneous onset of labor to a 24 year old gravida 3, para 2 now 3 woman.
# Pregnancy and delivery were unremarkable
# contradiction
# neutral
# ------------------------------------------
# 139
# - Myelodysplastic syndrome first diagnosed [**3213-7-9**], treated with danazol and aranesp.
# The patient has a history of anemia
# entailment
# neutral
# ------------------------------------------
# ================================================
# 140
# HISTORY: Not following commands.
# Patient can follow verbal requests
# entailment
# contradiction
# ------------------------------------------
# 141
# 2) Status post appendectomy.
# patient has a history of prior appendectomy
# neutral
# entailment
# ------------------------------------------
# 142
# He has had subsequent dyspnea on exertion which has recently worsened.
# The patient does not get short of breath with activity.
# entailment
# contradiction
# ------------------------------------------
# 143
# She spoke with her oncology team, and was given a prescription for oxycodone 20 mg, which she took [**Hospital1 **].
# The patient has pain issues.
# neutral
# entailment
# ------------------------------------------
# 144
# HISTORY:  Baby [**Name (NI) **] [**Known patient lastname 6048**] is the 3.09 kg product of a 36 and [**4-24**] week gestation born to a 37 year-old, Gravida IV, Para 2 woman.
# The patient has normal height.
# contradiction
# neutral
# ------------------------------------------
# 145
# The patient further denies any history of recent HA. .
# The patient has no history of head trauma
# contradiction
# neutral
# ------------------------------------------
# 146
# Given Levofloxacin 500mg X1, continuous nebs, solumedrol 125mg IV x1 Started on BiPap, more awake and comfortable, with repeat ABG 7.25/100/70.
# the patient has COPD
# neutral
# entailment
# ------------------------------------------
# ================================================
# 147
# During the procedure the patient was provided with some relief of obstruction by placing a stent and then patient was extubated and hopsital course was complicated by a post obstructive pneumonia.
# the patient had an uncomplicated hospital stay
# neutral
# contradiction
# ------------------------------------------
# 148
# He was responding inappropriately to questions (i.e. saying "no" when he meant to say "yes"), but appeared to understand what was being said to him.
# The patient has expressive dysphasia.
# neutral
# entailment
# ------------------------------------------
# 149
# Noted her hemorrhoids are acting up.
# The patient has blood streaks while defecating.
# entailment
# neutral
# ------------------------------------------
# 150
# 47yo M with PMHx metastatic colon CA to liver and lungs, hereditary telangiectasias complicated by chronic nosebleeds, a TIA, and a large pulmonary AVM repaired in [**1-/3145**] who presented on [**3151-4-7**] with chest and calf pain and fever.
# Patient has colon neoplasm
# neutral
# entailment
# ------------------------------------------
# 151
# The patient further denies any history of recent HA. .
# The patient has had no recent headaches
# contradiction
# entailment
# ------------------------------------------
# 152
# The patient is now admitted for elective surgery.
# The patient is undergoing emergent surgery.
# neutral
# contradiction
# ------------------------------------------
# ================================================
# 153
# The mother presented in labor on [**11-17**] and progressed to deliver spontaneous vaginal delivery with Apgars of 8 at one minute and 9 at five minutes.
# Patient has abnormal Apgar’s
# neutral
# contradiction
# ------------------------------------------
# 154
# Given the patient's recent surgery and that the bleeding had stopped a colonoscopy was planned as an outpatient.
# Patient has significant PSH
# contradiction
# entailment
# ------------------------------------------
# 155
# Her [** Location **]us UGIB required hospitalization, which was notable for a hematocrit of 16 on admission, 11 units of packed red blood cells transfusion during stay, 2 units of fresh frozen platelets, esophagogastroduodenoscopy showing gastritis and normal duodenum, cauterization of a gastric AVM, and angiography followed by embolization of left gastric artery.
# The patient had a gastric arteriovenous malformation causing the upper GI bleed.
# neutral
# entailment
# ------------------------------------------
# 156
# In ER, he was found to be febrile and unresponsive.
# The patient is obtunded.
# neutral
# entailment
# ------------------------------------------
# 157
# Stool culture reportedly was not sent prior to delivery.
# Stool culture was sent prior to delivery
# entailment
# contradiction
# ------------------------------------------
# 158
# Had an ultimately negative esophagogastroduodenoscopy and colonoscopy.
# Patient still needs age appropriate colon cancer screening
# neutral
# contradiction
# ------------------------------------------
# 159
# On arrival to the MICU, patient is hemodynamically stable.
# Patient has no need for ICU care
# contradiction
# neutral
# ------------------------------------------
# 160
# Diabetes type 2.
# Patient has CAD
# entailment
# neutral
# ------------------------------------------
# ================================================
# 161
# As lab results returned, the ED physicians had become concerned for impending sepsis given elevated wbc count and fever.
# The patient is hypothermic.
# entailment
# contradiction
# ------------------------------------------
# 162
# On the evening of [**5-1**], the patient was transferred to [**Hospital1 **] for detoxification, and then subsequently sent to [**Hospital1 47**] for medical clearance given concern for agitation and possible delirium tremens.
# the patient is an alcoholic
# neutral
# entailment
# ------------------------------------------
# 163
# On [**7-24**], he had a CT of the chest and CTA of his coronary arteries, which showed extensive plaque in all major coronary arteries with significant stenosis in the left main, LAD and RCA, an ejection fraction of 69% with normal wall motion.
# patient has normal cardiac output
# contradiction
# entailment
# ------------------------------------------
# 164
# 36yo G2P1 who presented at 18+2 wks for termination of severely anomalous fetus.
# Patient has had an abortion
# neutral
# entailment
# ------------------------------------------
# 165
# She received a total of 4 L NS in the Ed.
# Patient has hypotension
# entailment
# neutral
# ------------------------------------------
# 166
# This symptoms were not amenable to TPA, so Mr.
# The patient did not receive a throbolytic.
# contradiction
# entailment
# ------------------------------------------
# 167
# During this admission, he was also found to have a patent foramen ovale on echocardiography.
# the patient has a PFO
# neutral
# entailment
# ------------------------------------------
# 168
# Patient was sent back to the Emergency Department today because of difficulty breathing.
# The patient has a pulmonary problem.
# neutral
# entailment
# ------------------------------------------
# 169
# He is transferred to the floor to await biopsy results and further plans.
# His is being evaluated for cancer
# entailment
# neutral
# ------------------------------------------
# ================================================
# 170
# The patient further denies any history of recent HA. .
# The patient complains of temporal headache
# neutral
# contradiction
# ------------------------------------------
# 171
# HISTORY OF PRESENT ILLNESS:  The patient is a 49 year old otherwise healthy female, on only aspirin 81 mg daily, who comes in after a routine physical examination and her primary care physician having heard [**Name Initial (PRE) **] murmur.
# Patient has multiple medical conditions
# entailment
# contradiction
# ------------------------------------------
# 172
# The RCA occlusion was stented.
# patient has heart failure
# entailment
# neutral
# ------------------------------------------
# 173
# HISTORY:  Baby [**Name (NI) **] [**Known patient lastname 6048**] is the 3.09 kg product of a 36 and [**4-24**] week gestation born to a 37 year-old, Gravida IV, Para 2 woman.
# The patient has low birth weight.
# entailment
# contradiction
# ------------------------------------------
# 174
# Per her family, she fractured her pubic ramus 3 weeks ago.
# History of pelvic fracture
# neutral
# entailment
# ------------------------------------------
# 175
# Head CT was negative for bleed.
# The patient has intracranial hemorrhage.
# neutral
# contradiction
# ------------------------------------------
# 176
# On arrival to the MICU, the pt is resting comfortably, denies lightheadedness.
# The patient is not hypotensive.
# contradiction
# neutral
# ------------------------------------------
# 177
# COPD/Asthma: Spirometry ([**4-/3393**]) FVC 2.48 (67%), FEV1 1.96 (68%), FEV1/FVC 101%, DLCO ([**3-/3392**]) 51%, Lung vol ([**3-/3392**]): TLC 64%, FRC 48%, RV 49%, ERV 47%, multiple admissions, intubation x 1 [**3391**] 3.
# the patient has a history of obstructive lung disease
# neutral
# entailment
# ------------------------------------------
# 178
# Reported benign antepartum, admitted to Labor and Delivery in labor.
# The patient is in labor.
# neutral
# entailment
# ------------------------------------------
# 179
# IVF dichorionic, diamniotic twin gestation reduced from     triplets.
# Twin gestation conceived by IVF
# neutral
# entailment
# ------------------------------------------
# 180
# [**Known patient lastname 13932**] is a 53-year-old gentleman with a history of rheumatic heart disease, who has been followed over the years by serial echocardiograms.
# the patient has a history of rheumatic heart disease
# neutral
# entailment
# ------------------------------------------
# ================================================
# 181
# Initial ECG showed ST elevations in the inferior leads with ST depressions in V1-V4.
# the patient is having an STEMI
# neutral
# entailment
# ------------------------------------------
# 182
# EF [**2610-11-28**] to 25% 3.
# The patient has congestive heart failure.
# neutral
# entailment
# ------------------------------------------
# 183
# History was taken entirely from the patients husband and daughters.
# the patient has altered mental status
# entailment
# neutral
# ------------------------------------------
# 184
# Pregnancy complicated by ultrasound finding of 13 mm ventricular dilatation at 13 weeks.
# Patient has angina
# entailment
# neutral
# ------------------------------------------
# 185
# Type II Diabetes Mellitus 3.
# The patient has type II diabetes.
# neutral
# entailment
# ------------------------------------------
# 186
# Decelerations occurred during labor, with vaginal delivery and face presentation.
# Delivery was via c-section
# entailment
# contradiction
# ------------------------------------------
# 187
# He was discharged on medical therapy and returns today for elective CABG.
# the patient has coronary artery disease
# neutral
# entailment
# ------------------------------------------
# 188
# Obstructive sleep apnea on C-PAP, 12 mm HG.
# The patient is overweight.
# entailment
# neutral
# ------------------------------------------
# 189
# For FS of 63, given additionaly amp of D50 with latest FS of 123.
# The patient initially received too much insulin.
# entailment
# neutral
# ------------------------------------------
# 190
# BP on arrival was 189/119.
# The patient was hypotensive
# entailment
# contradiction
# ------------------------------------------
# 191
# HTN 10.sinusitis diagnosed during last admission 11. h/o R PTX last hospitalization requiring CT placement (d/c'd) 12. ?hypoxic brain injury with paresis and cognitive deficit 13.
# The patient has brain damage.
# neutral
# entailment
# ------------------------------------------
# 192
# Repeat Hct stable, but in setting of drop in BP, he was transferred to MICU for closer monitoring.
# The patient has a GI bleed.
# entailment
# neutral
# ------------------------------------------
# ================================================
# 193
# She was extubated on [**3319-9-3**] at 5 P.M., tolerated well and was transferred to the floor on [**9-2**].
# She was in a coma
# contradiction
# neutral
# ------------------------------------------
# 194
# CRI (baseline Cr 1.5-1.7) 2.
# the patient has kidney disease
# neutral
# entailment
# ------------------------------------------
# 195
# Abdominal aortic aneurysm measuring 4.7 cm.
# aneurysm is infrarenal
# entailment
# neutral
# ------------------------------------------
# 196
# Recent MRI did not show any change in adenoma size -S[** Location **] rupture [**1-11**] MVA in [**3181**], no splenectomy required -h/o VRE bacteremia in [**3-15**].
# The patient has an adenoma
# neutral
# entailment
# ------------------------------------------
# 197
# Had an ultimately negative esophagogastroduodenoscopy and colonoscopy.
# Patient has no pain
# contradiction
# neutral
# ------------------------------------------
# 198
# The patient has received several bronchoscopies with transbronchial biopsy and pathology revealed necrotizing granulomas.
# The patient has an infection
# entailment
# neutral
# ------------------------------------------
# 199
# History was taken entirely from the patients husband and daughters.
# history was obtained from the family
# neutral
# entailment
# ------------------------------------------
# 200
# Given Levofloxacin 500mg X1, continuous nebs, solumedrol 125mg IV x1 Started on BiPap, more awake and comfortable, with repeat ABG 7.25/100/70.
# the patient had no pneumonia on chest x ray
# contradiction
# neutral
# ------------------------------------------
# ================================================
# 201
# Left ventriculogram revealed preserved LV function and no mitral regurgitation.
# Patient has mitral regurgitation
# neutral
# contradiction
# ------------------------------------------
# 202
# Negative bronchoalveolar lavage in [**2852-2-8**] and in [**2852-2-8**] for Pneumocystis carinii pneumonia and neuro fungi.
# patient is immunocompromised
# neutral
# entailment
# ------------------------------------------
# 203
# Type II Diabetes Mellitus 3.
# The patient does not require insulin.
# contradiction
# neutral
# ------------------------------------------
# 204
# She fell to her knees and her husband and neighbor came to help her clean up.
# The patient has balance issues.
# entailment
# neutral
# ------------------------------------------
# 205
# Bleeding from left femoral arteriotomy and venotomy site with hemostasis achieved after Femstop applied.
# The patient had a recent cardiac catheterization.
# entailment
# neutral
# ------------------------------------------
# ================================================
# 206
# ﻿The patient was hemodynamically stable upon admission with an hematocrit of 34.
# The patient was stable.
# contradiction
# entailment
# ------------------------------------------
# 207
# On arrival to the MICU, patient is hemodynamically stable.
# Patient has normal vital signs
# contradiction
# entailment
# ------------------------------------------
# 208
# Lung adenocarcinoma with metastases to brain, [**Year (4 digits) 494**], pericardium.
# The patient has stage IV lung cancer.
# neutral
# entailment
# ------------------------------------------
# 209
# Over the past week PTA he has been more somnolent and difficult to arrouse. .
# He is disorientated and complains of weakness
# entailment
# neutral
# ------------------------------------------
# 210
# Per report, patient was found unconscious one day PTA in [**Location (un) **] on her wheelchair and was brought in by ambulance.
# She had a syncopal episode
# entailment
# neutral
# ------------------------------------------
# 211
# She was transferred to the medical floor hemodynamically stable.
# The patient is hypotensive.
# entailment
# contradiction
# ------------------------------------------
# ================================================
# 212
# HISTORY:  This is a 35 week male infant [**Year (4 digits) **] by spontaneous vaginal delivery after spontaneous onset of labor to a 24 year old gravida 3, para 2 now 3 woman.
# Labor was not induced
# contradiction
# entailment
# ------------------------------------------
# 213
# Given continuous albuterol, methylprednisolone.
# The patient is being given medication to constrict small airways.
# entailment
# contradiction
# ------------------------------------------
# 214
# HTN urinary retention legally blind (optic atrophy of childhood) lumbar stenosis s/p L4-5 laminoforaminectomy [**3166**] R foot drop, using brace x 10 mo chronic gait problems, balance problems
# Patient has vision difficulties
# neutral
# entailment
# ------------------------------------------
# 215
# He required treatment for apnea prematurity with caffeine, which he also remains on at the time of this dictation.
# He had apnea as a result of prematurity
# neutral
# entailment
# ------------------------------------------
# 216
# Coombs test was positive, and the serum haptoglobin was less than 0.6.
# patient has a positive coomb's test
# neutral
# entailment
# ------------------------------------------
# 217
# Well controlled on Lipitor.
# He has hyperlipidemia
# neutral
# entailment
# ------------------------------------------
# 218
# No known sick contacts.
# No recent travel
# entailment
# neutral
# ------------------------------------------
# 219
# He developed R sided chest discomfort and chills 2 hours after receiving bleomycin, with T 101.8, O2 sat 88% on RA.
# He has a history of cancer
# neutral
# entailment
# ------------------------------------------
# 220
# Chronic RLE ulcer, rest non-invasive arterial studies normal on [**3379-1-8**].
# Peripheral artery disease
# entailment
# contradiction
# ------------------------------------------
# 221
# The patient presented to [**Hospital6 117**] on [**11-2**], complained of abdominal pain in his left upper and lower quadrant.
# The patient has a small bowel obstruction
# entailment
# neutral
# ------------------------------------------
# 222
# He was started on IVF and given a total of 25mg of IV Valium.
# The patient is in alcohol withdrawal.
# entailment
# neutral
# ------------------------------------------
# ================================================
# 223
# Pulse returned at 7:05.
# The patient was unstable
# contradiction
# entailment
# ------------------------------------------
# 224
# The clindamycin was discontinued after five days.
# Patient has an infection
# neutral
# entailment
# ------------------------------------------
# 225
# Lungs are clear bilaterally with good air entry.
# Patient denies cough or shortness of breath
# entailment
# neutral
# ------------------------------------------
# 226
# ...
# the patient has hematemesis
# neutral
# contradiction
# ------------------------------------------
# 284
# She denied any loss of consciousness.
# The patient did not have a loss of consciousness.
# entailment
# neutral
# ------------------------------------------
# 285
# This is a 59 year old woman with a h/o CAD s/p stenting and DM2 who was admitted from podiatry clinic [**4-1**] with purulent discharge from left foot ulcer, also with erythema of surrounding tissue.
# The patient has osteomyelitis of the left foot.
# entailment
# neutral
# ------------------------------------------
# 286
# The patient is now admitted for elective surgery.
# The patient is undergoing elective surgery.
# neutral
# entailment
# ------------------------------------------
# 287
# She initially attributed this to her first prednisone which had been started that day for a gout flare.
# the patient is hyperglycemic
# entailment
# neutral
# ------------------------------------------
# 288
# Diabetes type 2.
# History of type 1 diabetes
# neutral
# contradiction
# ------------------------------------------
# ================================================
# 289
# Presented with spontaneous onset of labor and progressed to spontaneous vaginal delivery without anesthesia.
# the delivery was vaginal
# neutral
# entailment
# ------------------------------------------
# 290
# He was getting his head laceration repaired when he started to seize.
# The patient had head trauma.
# neutral
# entailment
# ------------------------------------------
# 291
# Head CT was negative for bleed.
# There is concern for stroke.
# entailment
# neutral
# ------------------------------------------
# 292
# Positive chills yesterday.
# patient has a fever
# entailment
# neutral
# ------------------------------------------
# 293
# [**Known patient lastname **] is a 33 year old male with h/o large B-cell lymphoma status post allogenic stem cell transplant in [**3397**], complicated by severe graft versus host disease of the skin and oral mucousa, and recent admission 5/11-23/08 for pneumosepsis and subsequently went to [**Hospital1 **] for rehabilitation.
# The patient is on immunosuppression.
# neutral
# entailment
# ------------------------------------------
# 294
# He found no relationship with pain to meals or bowel movements.
# He has pain after eating
# neutral
# contradiction
# ------------------------------------------
# 295
# Pulse returned at 7:05.
# Pulseless electrical activity at 7:05
# entailment
# contradiction
# ------------------------------------------
# 296
# Non-contrast head CT done before her seizure demonstrated possible low attenuation within the white matter of the left occipital lobe and within the right occipital lobe to a lesser extent.
# Patient has had a CT scan performed
# neutral
# entailment
# ------------------------------------------
# 297
# She was brought to the ED where she had another seizure and left face twitching as well as left leg movements were noticed.
# Patient has a seizure disorder
# neutral
# entailment
# ------------------------------------------
# 298
# Abdominal CT liver laceration wit subcapsular hematoma.
# the patient has a liver laceration
# neutral
# entailment
# ------------------------------------------
# ================================================
# 299
# She otherwise denies any chest pain/pressure (her anginal equivalent), PND, palpitations, N/V, diarrhea, BRBPR, dysuria, fevers.
# Patient has no atherosclerosis
# entailment
# neutral
# ------------------------------------------
# 300
# Pt was found to be hypoglycemic on arrival, and received 2 amps of glucose.
# the patient was hyperglycemic
# entailment
# contradiction
# ------------------------------------------
# 301
# The birth weight was 2,005 grams, birth length 44.5 cm, and the birth head circumference 30.5 cm.
# Patient has is normal size and weight
# contradiction
# neutral
# ------------------------------------------
# 302
# In the [**Name (NI) **], pt was noted to have a temp of 100.5, HR 140s-150s, ANC 256.
# The patient is receiving chemotherapy
# entailment
# neutral
# ------------------------------------------
# 303
# In the course of routine workup for conversion from Prograf to Rapamune, a liver duplex to evaluate for Hepatic Artery thrombosis was done on [**8-11**] per protocol.
# Patient has liver disease
# neutral
# entailment
# ------------------------------------------
# 304
# CVA [**2975**] c/b residual facial droop, dysarthria, dysphagia, right sided paralysis, nonverbal at baseline Vascular dementia Depression Insomnia Urinary incontinence Diverticulosis s/p recent colectomy on [**7-10**] for a lower GI bleed  Repair of several abd wall ventral hernias on [**7-11**] HTN Hyponatremia hx MSSA bacteremia gastritis with anemia Vitamin D deficiency s/p appendectomy
# History of stroke
# neutral
# entailment
# ------------------------------------------
# 305
# Head CT negative. .
# History of head trauma
# contradiction
# neutral
# ------------------------------------------
# 306
# Had Apgars of 5, 5 and 8 at 1, 5 and 10 minutes.
# APGARS improved at 10 minutes
# contradiction
# entailment
# ------------------------------------------
# 307
# TIA - [**2787**] 7.
# patient has a normal brain MRI
# contradiction
# neutral
# ------------------------------------------
# 308
# THE FIRST HALF OF THE HISTORY AND PHYSICAL AS WELL AS THE BRIEF HOSPITAL COURSE WAS DONE BY THE ADMITING CARDIOLOGY TEAM AND THE SECOND WAS DONE BY THE SURGERY TEAM, RESPECTIVELY:  75 yo F with HTN, Hyperlipidemia, DM, h/o CVA in [**2715**], AFib, breast cancer s/p radiation and lumpectomy initally admitted to [**Hospital 70**] Hospital for CHF and a SBP of 240.
# The patient was admitted for a hypertensive emergency.
# neutral
# entailment
# ------------------------------------------
# ================================================
# 309
# Is bringin up greenish sputum.
# He has cough
# neutral
# entailment
# ------------------------------------------
# 310
# His sputum was negative for acid fast bacilli and Pneumocystis carinii pneumonia.
# Patient has TB
# neutral
# contradiction
# ------------------------------------------
# 311
# More recently, a CT of the chest noted ground-glass abnormalities, raising concern for bronchoalveolar carcinoma.
# Patient has cancer
# entailment
# neutral
# ------------------------------------------
# 312
# The patient noted an increase in shortness of breath for a few days and a chest x-ray revealed a new left pleural effusion.
# The patient has a pulmonary condition.
# neutral
# entailment
# ------------------------------------------
# 313
# Chest x-ray was consistent with mild congestive heart failure.
# Patient has pulmonary edema
# neutral
# entailment
# ------------------------------------------
# 314
# His sputum was negative for acid fast bacilli and Pneumocystis carinii pneumonia.
# Patient has URI
# neutral
# entailment
# ------------------------------------------
# 315
# 89F with multiple medical problems who presented to [**Hospital1 68**] on [**3287-1-7**] d/t hypotension from E. coli urosepsis in setting of poor PO intake, hypovolemia, and poor IV access/fluid administration.
# She has syncope
# entailment
# neutral
# ------------------------------------------
# 316
# The patient was then given Nitroglycerin drip, as well as started on heparin drip.
# Patient has angina
# entailment
# neutral
# ------------------------------------------
# 317
# During the procedure the patient was provided with some relief of obstruction by placing a stent and then patient was extubated and hopsital course was complicated by a post obstructive pneumonia.
# the patient had MRSA
# entailment
# neutral
# ------------------------------------------
# ================================================
# 318
# Cranial nerves II through XII are intact.
# Patient has a normal neurological exam
# neutral
# entailment
# ------------------------------------------
# 319
# In transit, she vomited and was subsequently intubated to protect her airway given her mental status.
# Patient is on a ventilator
# entailment
# neutral
# ------------------------------------------
# 320
# Per report, [**Date Range 17970**] at OSH were negative for DVT, while CTA chest was positive for PE.
# The patient has a history of PE.
# neutral
# entailment
# ------------------------------------------
# 321
# PERSONAL HABITS:  She is single and lives with a friend.
# The patient lives alone.
# entailment
# contradiction
# ------------------------------------------
# 322
# She stated that she was in her usual state of health until yesterday afternoon when she began complaining of fatigue, malaise, and nausea.
# She is febrile
# entailment
# neutral
# ------------------------------------------
# 323
# He was brought in by  his cousin for concern for GIB, and currently denies that he had any hematemesis but instead endorses hematochezia.
# the patient has a lower gi bleed
# entailment
# neutral
# ------------------------------------------
# ================================================
# 324
# The patient denied any headache, visual changes, chest pain, pleuritic pain, back pain, abdominal pain, diarrhea, blood per rectum, melena, dysuria, rash, or joint pain.
# the patient has no medical history
# entailment
# neutral
# ------------------------------------------
# 325
# A renal biopsy at this time showed signs of rejection and he received a three day pulse of steroids and subsequently did well.
# The patient had transplant failure.
# entailment
# contradiction
# ------------------------------------------
# 326
# HISTORY OF PRESENT ILLNESS:  This is a 63 year old male with chronic obstructive pulmonary disease, status post multiple recent admissions for chronic obstructive pulmonary disease flares, status post recent discharge from [**Hospital3 **] [**Hospital **] [**First Name (Titles) **] [**Last Name (Titles) **] on [**6-26**], when he was intubated in the Medicine Intensive Care Unit for a chronic obstructive pulmonary disease flare.
# Patient has abnormal FEV1
# entailment
# neutral
# ------------------------------------------
# 327
# Then developed N/V, vomiting >12 times of clear vomitus last night.
# Patient has colitis
# neutral
# contradiction
# ------------------------------------------
# 328
# In the [**Name (NI) **], pt was noted to have a temp of 100.5, HR 140s-150s, ANC 256.
# The patient’s vitals and lab work are within normal limits
# neutral
# contradiction
# ------------------------------------------
# 329
# [**Known patient lastname 4399**] was off all therapy for his myeloma since that time.
# Patient had been treated for malignancy in the past
# entailment
# neutral
# ------------------------------------------
# 330
# Left common femoral dorsalis pedis bypass graft.
# Patient has PAD
# neutral
# entailment
# ------------------------------------------
# ================================================
# 331
# Pt received 5U PRBCs--> Hct 29.8.
# The patient has a bleed.
# entailment
# neutral
# ------------------------------------------
# 332
# Decelerations occurred during labor, with vaginal delivery and face presentation.
# Delivery was at full term
# contradiction
# neutral
# ------------------------------------------
# 333
# On the floor, pt initially unresponsive to command, voice, touch, arouse briefly to sternal rub.
# Patient is minimally responsible
# contradiction
# entailment
# ------------------------------------------
# 334
# Pt denies any recent chills, fevers, nausea, vomiting, diarrhea, chest pain, shortness of breath.
# The patient denies recent illness
# entailment
# neutral
# ------------------------------------------
# 335
# He was given cefepime, PO vancomycin, IV vancomycin and admitted to BMT.
# there is concern for sepsis
# entailment
# neutral
# ------------------------------------------
# 336
# Anxiety 12. h/o Anemia - hemolytic anemia after Keflex 13.
# The patient had an adverse reaction to Keflex
# neutral
# entailment
# ------------------------------------------
# 337
# Erythromycin eye ointment and vitamin K were given.
# The patient got the expected post delivery care.
# contradiction
# neutral
# ------------------------------------------
# 338
# CARDIOVASCULAR: A regular rate and rhythm.
# Patient has normal echo
# entailment
# neutral
# ------------------------------------------
# 339
# Obstetrical history was notable for 2 [** Location **]us sections in [**3452**] at 28 weeks gestation and [**3457**] at 36 weeks gestation.
# History of two deliveries
# neutral
# entailment
# ------------------------------------------
# 340
# Atrioventricular block s/p pacemaker in [**2654**] 8.
# Patient has conduction abnormality
# entailment
# neutral
# ------------------------------------------
# 341
# On transfer to floor, pt. denies cp, sob, dizziness, weakness, palpitations, nausea, vomiting, abdominal pain.
# The patient is not having a myocardial infarction.
# entailment
# neutral
# ------------------------------------------
# ================================================
# 342
# IVF dichorionic, diamniotic twin gestation reduced from     triplets.
# The twins shared a placenta
# entailment
# contradiction
# ------------------------------------------
# 343
# She was lightheaded and weak.
# She was volume depleted
# entailment
# neutral
# ------------------------------------------
# 344
# Carotid sinus massage and exercise were performed with no prominent effect on AV nodal conduction.
# The patient is hemodynamically stable
# entailment
# neutral
# ------------------------------------------
# 345
# She said they also have her on a low salt diet.
# She is on a low fat diet
# contradiction
# neutral
# ------------------------------------------
# 346
# His infarct was felt to be small vessel.
# Patient has had a stroke
# neutral
# entailment
# ------------------------------------------
# 347
# Her hematocrit was followed q. six hours and prior to discharge her hematocrit was 33.
# The patient‰Ûªs hematocrit was closely monitored.
# contradiction
# entailment
# ------------------------------------------
# 348
# CHF exacerbation was in the setting of new inferior HK and he was diuresed with hopes of pursuing RHC/LHC.
# The patient has congestive heart failure.
# entailment
# neutral
# ------------------------------------------
# 349
# HISTORY OF PRESENT ILLNESS:  This is a 63 year old male with chronic obstructive pulmonary disease, status post multiple recent admissions for chronic obstructive pulmonary disease flares, status post recent discharge from [**Hospital3 **] [**Hospital **] [**First Name (Titles) **] [**Last Name (Titles) **] on [**6-26**], when he was intubated in the Medicine Intensive Care Unit for a chronic obstructive pulmonary disease flare.
# Patient has emphysema
# neutral
# entailment
# ------------------------------------------
# 350
# CARDIOVASCULAR: A regular rate and rhythm.
# Patient has normal cardiac exam
# neutral
# entailment
# ------------------------------------------
# 351
# He was admitted to the [**Hospital1 188**] in [**2-18**], with hypoxia and bilateral infiltrates.
# His oxygen saturation was low
# neutral
# entailment
# ------------------------------------------
# 352
# HISTORY OF PRESENT ILLNESS:  The patient is a 49 year old otherwise healthy female, on only aspirin 81 mg daily, who comes in after a routine physical examination and her primary care physician having heard [**Name Initial (PRE) **] murmur.
# Patient takes only one medication
# contradiction
# entailment
# ------------------------------------------
# 353
# On review of systems, she reports a history of prior [**Date Range **] in [**2864**] at which time she experienced left facial numnbess/tingling.
# The patient has a history of neurologic deficit.
# neutral
# entailment
# ------------------------------------------
# ================================================
# 354
# At that time, a CBC and Chem-7 was drawn and the Chem-7 was within the normal range for all of his electrolytes as well as his renal function.
# patient has normal renal function
# contradiction
# entailment
# ------------------------------------------
# 355
# Pt has hx of MRSA infection in this wound. .
# The patient had a chronically infected wound.
# entailment
# neutral
# ------------------------------------------
# 356
# She had to 2PIVs placed and was started on octreotide and PPI gtt.
# the GI bleed is lower
# entailment
# neutral
# ------------------------------------------
# 357
# At that time, he was transferred to the Medical Intensive Care Unit.
# The patient is intubated.
# entailment
# neutral
# ------------------------------------------
# 358
# TIA - [**2787**] 7.
# patient has history of TIA
# neutral
# entailment
# ------------------------------------------
# ================================================
