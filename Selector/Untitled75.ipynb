# %%
# !pip install fasttext
# !pip install fastparquet
# !gdown --id '1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM'
# !gdown --id '1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp'
# !gdown --id '1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN'
# !unzip MedNLI_dataset.zip
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 7.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (71.0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.26.4)
# Using cached pybind11-2.13.1-py3-none-any.whl (238 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4246765 sha256=eedbaab20412e1509defe2806d663dbae6453de1c9d3f00a655a1618c503a4e7
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.1
# Collecting fastparquet
#   Downloading fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.26.4)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Downloading fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.6 MB/s eta 0:00:00
# Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 83.1 MB/s eta 0:00:00
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.8.3 fastparquet-2024.5.0
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM
# From (redirected): https://drive.google.com/uc?id=1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM&confirm=t&uuid=f85df9d1-5c43-4390-94ca-bd217de66c19
# To: /content/modelw.pth
# 100% 516M/516M [00:02<00:00, 179MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp
# To: /content/MedNLI_dataset.zip
# 100% 681k/681k [00:00<00:00, 109MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN
# From (redirected): https://drive.google.com/uc?id=1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN&confirm=t&uuid=97c0588d-fb31-41b0-b56f-920d0ed984d9
# To: /content/TrustModelw5.pth
# 100% 516M/516M [00:16<00:00, 31.3MB/s]
# Archive:  MedNLI_dataset.zip
#    creating: MedNLI_dataset/
#   inflating: MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet
#   inflating: MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet
#   inflating: MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.8.2-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.26.4)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.3.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.3.0->stanza)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Downloading stanza-1.8.2-py3-none-any.whl (990 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.1/990.1 kB 33.6 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 1.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 83.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
# Successfully installed emoji-2.12.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 stanza-1.8.2

# %%
# @title imports
from transformers import AutoTokenizer, AutoModel
import pandas as pd
import shutil
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset,DataLoader
from sklearn.metrics import accuracy_score
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import stanza

# %%
# @title CODES
def find_pre_and_hyp(query):
    start_pre = query.find("[PRE]") + len("[PRE]")
    end_pre = query.find("[HYP]")
    start_hyp = query.find("[HYP]") + len("[HYP]")
    end_hyp = query.find("OUTPUT:")
    premise = query[start_pre:end_pre].strip()
    hypothesis = query[start_hyp:end_hyp].strip()

    return premise,hypothesis


class CustomDataset(Dataset):
    def __init__(self, x_list, y_list):
        self.samples = []
        for x,y in zip(x_list,y_list):
            #x_tensor = torch.tensor(x,dtype = torch.float32)
            y_tensor = torch.tensor(y,dtype = torch.float32)
            self.samples.append((x[0],x[1],y_tensor))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]


def get_lists(data):
    x_list = []
    y_list = []
    i =0
    for query,answer in zip(data['query'],data['answer']):
        i = i + 1
        if answer == 'entailment':
           y = [1,0,0]
        elif answer == 'neutral':
           y = [0,1,0]
        elif answer == 'contradiction':
           y = [0,0,1]
        else:
           print('should not get here')

        premise,hypothesis = find_pre_and_hyp(query)
        x_list.append((premise,hypothesis))
        y_list.append(y)
    return x_list,y_list


class embedding_layer(nn.Module):
  def __init__(self,bert_model,tokenizer):
    super(embedding_layer, self).__init__()
    self.bert_model = bert_model
    self.tokenizer = tokenizer

  def forward(self, x):
    with torch.no_grad():
         s = tokenizer(x,return_tensors="pt",padding=True).to(device)
         vec = bert_model(**s)['last_hidden_state'].to(device)
    return vec

class PositionalEncoding(nn.Module):
    def __init__(self, seq_len,embedding_size):
        super().__init__()
        self.dropout = nn.Dropout(0.1)
        self.embedding_size = embedding_size
        self.seq_len = seq_len

    def forward(self, x):
        pe = torch.zeros(x.size(0), x.size(1), self.embedding_size).to(device)
        div_term = torch.zeros(x.size(0), 1, self.embedding_size).to(device)
        ks = torch.arange(self.embedding_size).float().to(device)
        values = torch.exp(-torch.log(torch.tensor(1000.0)) * 2 * ks / self.embedding_size).to(device)
        values = values.view(1, 1, -1).to(device)
        div_term = div_term + values
        x = x.reshape([x.shape[0],x.shape[1],1]).to(device)
        pe[:, :, ::2] = torch.sin(x * div_term)[:, :, ::2].to(device)
        pe[:, :, 1::2] = torch.cos(x * div_term)[:, :, 1::2].to(device)
        return self.dropout(pe)

class MultiHeadAttention(nn.Module):
    def __init__(self, embedding_size, heads):
        super().__init__()
        self.embedding_size = embedding_size
        self.heads = heads
        self.head_dim = embedding_size // heads
        assert(self.heads * self.head_dim == self.embedding_size), "Invalid number of heads"
        self.fc_values = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_keys = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_queries = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_out = nn.Linear(heads * self.head_dim, embedding_size).to(device)

    def forward(self, values, keys, queries, mask):
        N = queries.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], queries.shape[1]
        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = queries.reshape(N, query_len, self.heads, self.head_dim)
        values = self.fc_values(values).to(device)
        keys = self.fc_keys(keys).to(device)
        queries = self.fc_queries(queries).to(device)
        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys]).to(device)
        if mask is not None:
            energy = energy.masked_fill(mask.to(device) == 0, float("-1e20")).to(device)
        energy = torch.softmax(energy / (self.embedding_size ** 0.5), dim=3).to(device)
        attention = torch.einsum("nhql,nlhd->nqhd", [energy, values]).to(device)
        attention = attention.reshape(N, query_len, self.heads * self.head_dim).to(device)
        out = self.fc_out(attention)
        return out

class TransformerBlock(nn.Module):
    def __init__(self, embedding_size, heads, forward_expansion, p):
        super().__init__()
        self.attention = MultiHeadAttention(embedding_size, heads)
        self.norm1 = nn.LayerNorm(embedding_size)
        self.feed_forward = nn.Sequential(nn.Linear(embedding_size, forward_expansion * embedding_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion * embedding_size, embedding_size))
        self.norm2 = nn.LayerNorm(embedding_size)
        self.dropout = nn.Dropout(p)
    def forward(self, values, keys, queries, mask):
        attention_out = self.attention(values, keys, queries, mask)
        x = self.norm1(attention_out + queries)
        x = self.dropout(x)
        ff_out = self.feed_forward(x)
        out = self.norm2(ff_out + x)
        out = self.dropout(out)
        return out

class Encoder(nn.Module):
    def __init__(self, src_vocab_size, embedding_size, num_layers, heads,
                 forward_expansion, max_length, p, device):
        super().__init__()
        self.device = device
        self.word_embedding = embedding_layer(bert_model,tokenizer)
        self.positional_embedding = PositionalEncoding(max_length, embedding_size)
        self.layers = nn.ModuleList([TransformerBlock(embedding_size, heads, forward_expansion, p) for _ in range(num_layers)])
        self.dropout = nn.Dropout(p)

    def forward(self, x, mask):
        mask = None
        pe = self.word_embedding(x)
        N = pe.size(0)
        seq_len = pe.size(1)
        positions = torch.arange(0, seq_len).expand(N, seq_len).to(self.device)
        out = self.dropout((pe + self.positional_embedding(positions)))
        for layer in self.layers:
            out = layer(out, out, out ,mask)
        return out


class Transformer(nn.Module):
    def __init__(self, src_vocab_size, src_pad_idx, embedding_size=768,
                 num_layers=1, forward_expansion=8, heads=8, max_length=100, p=0.1):
        super().__init__()
        self.src_pad_idx = src_pad_idx
        self.encoder = Encoder(src_vocab_size, embedding_size, num_layers, heads,
                               forward_expansion, max_length, p, device)

    def get_src_mask(self, src):
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2).to(device)
        return src_mask

    def forward(self, src):
        src_mask = None
        enc_out = self.encoder(src, src_mask).to(device)
        return enc_out


class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.transformer1 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.transformer2 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.fc1 = nn.Linear(768*2, 256).to(device)
        self.fc2 = nn.Linear(256, 3).to(device)

    def forward(self, x_pre,x_hyp):
        out1 = self.transformer1(x_pre)
        out2 = self.transformer2(x_hyp)
        out1 = torch.mean(out1,1)
        out2 = torch.mean(out2,1)
        x = torch.cat((out1,out2),1)
        x = F.relu(self.fc1(self.dropout1(x)))
        x = nn.functional.softmax(self.fc2(self.dropout2(x)),dim=1)
        return x

def get_model_acc(model,data_loader):
    model.eval()
    predictions = []
    true_labels = []
    for x_pre, x_hyp, y in data_loader:
        outputs = model(x_pre,x_hyp)
        predicted_labels = torch.argmax(outputs, dim=1).cpu().numpy()
        predictions.extend(predicted_labels)
        l1 = torch.argmax(y, dim=1).cpu().numpy()
        true_labels.extend(l1)
    model.train()
    return accuracy_score(true_labels, predictions)


def get_inf_from_num(num):
    if num == 0:
       return 'entailment'
    elif num == 1:
       return 'neutral'
    elif num == 2:
       return 'contradiction'

class NNN(nn.Module):
    def __init__(self):
        super(NNN, self).__init__()
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.transformer1 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.transformer2 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.fc1 = nn.Linear(768*2, 256).to(device)
        self.fc2 = nn.Linear(256, 2).to(device)

    def forward(self, x_pre,x_hyp):
        out1 = self.transformer1(x_pre)
        out2 = self.transformer2(x_hyp)
        out1 = torch.mean(out1,1)
        out2 = torch.mean(out2,1)
        x = torch.cat((out1,out2),1)
        x = F.relu(self.fc1(self.dropout1(x)))
        x = nn.functional.softmax(self.fc2(self.dropout2(x)),dim=1)
        return x

def get_inference_from_tns(tns):
    infr = np.argmax(tns.cpu().detach().numpy())
    if infr == 0:
       return 'entailment'
    elif infr == 1:
       return 'neutral'
    elif infr == 2:
       return 'contradiction'
    else:
       return 'shouldnt get here'


def get_trustworthy_from_tns(tns):
    infr = np.argmax(tns.cpu().detach().numpy())
    if infr == 0:
       return 'trustworthy'
    elif infr == 1:
       return 'untrustworthy'
    else:
       return 'shouldnt get here'

def get_trust_untrust_dataset(trustmodel,data_loader):
    trustmodel.eval()
    model.eval()
    trust_x_list = []
    untrust_x_list = []
    trust_y_list = []
    untrust_y_list = []
    for x_pre,x_hyp,y in data_loader:
        outputs = model(x_pre,x_hyp)
        outputs_tw = trustmodel(x_pre,x_hyp)
        y = y.to(device)
        for i in range(len(outputs)):
                 p = get_inference_from_tns(outputs[i])
                 t = get_inference_from_tns(y[i])
                 tw = get_trustworthy_from_tns(outputs_tw[i])
                 if tw == 'trustworthy':
                    trust_x_list.append((x_pre[i],x_hyp[i]))
                    trust_y_list.append(y[i].tolist())
                 elif tw == 'untrustworthy':
                    untrust_x_list.append((x_pre[i],x_hyp[i]))
                    untrust_y_list.append(y[i].tolist())
                 else:
                    print('shouldnt get here')
    trust_dataset = CustomDataset(trust_x_list,trust_y_list)
    untrust_dataset = CustomDataset(untrust_x_list,untrust_y_list)
    trust_data_loader = torch.utils.data.DataLoader(trust_dataset, batch_size=32, shuffle=True)
    untrust_data_loader = torch.utils.data.DataLoader(untrust_dataset, batch_size=32, shuffle=True)
    #print('trust num: ' + str(len(trust_y_list)))
    #print('untrust num: ' + str(len(untrust_y_list)))
    #print('trust acc: ' + str(get_model_acc(model,trust_data_loader)))
    #print('untrust acc: ' + str(get_model_acc(model,untrust_data_loader)))
    return trust_dataset,untrust_dataset

# %%
test_data = pd.read_parquet('MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet', engine='fastparquet')
train_data = pd.read_parquet('MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet', engine='fastparquet')
valid_data = pd.read_parquet('MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet', engine='fastparquet')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("gsarti/biobert-nli")
bert_model = AutoModel.from_pretrained("gsarti/biobert-nli").to(device)
src_pad_idx = 0
src_vocab_size = bert_model.config.vocab_size
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
train_x_list,train_y_list = get_lists(train_data)
test_x_list,test_y_list = get_lists(test_data)
val_x_list,val_y_list = get_lists(valid_data)

# %%
train_dataset = CustomDataset(train_x_list,train_y_list)
test_dataset = CustomDataset(test_x_list,test_y_list)
val_dataset = CustomDataset(val_x_list,val_y_list)

# %%
bsize = 1
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=bsize, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=bsize, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %%
model = torch.load('modelw.pth')
newmodel = torch.load('TrustModelw5.pth')

# %%
stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading these customized packages for language: en (English)...
# ====================================
# | Processor       | Package        |
# ------------------------------------
# | tokenize        | mimic          |
# | pos             | mimic_charlm   |
# | lemma           | mimic_nocharlm |
# | depparse        | mimic_charlm   |
# | ner             | i2b2           |
# | pretrain        | mimic          |
# | forward_charlm  | mimic          |
# | backward_charlm | mimic          |
# ====================================
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/tokenize/mimic.pt:   0%|       …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/tokenize/mimic.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/pos/mimic_charlm.pt:   0%|     …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/pos/mimic_charlm.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/lemma/mimic_nocharlm.pt:   0%| …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/lemma/mimic_nocharlm.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/depparse/mimic_charlm.pt:   0%|…
# INFO:stanza:Downloaded file to /root/stanza_resources/en/depparse/mimic_charlm.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/ner/i2b2.pt:   0%|          | 0…
# INFO:stanza:Downloaded file to /root/stanza_resources/en/ner/i2b2.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/pretrain/mimic.pt:   0%|       …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/pretrain/mimic.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/forward_charlm/mimic.pt:   0%| …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/forward_charlm/mimic.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/backward_charlm/mimic.pt:   0%|…
# INFO:stanza:Downloaded file to /root/stanza_resources/en/backward_charlm/mimic.pt
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# ==============================
# | Processor | Package        |
# ------------------------------
# | tokenize  | mimic          |
# | pos       | mimic_charlm   |
# | lemma     | mimic_nocharlm |
# | depparse  | mimic_charlm   |
# | ner       | i2b2           |
# ==============================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
def fused_model(x_pre,x_hyp):
    pass

# %%
def get_nsubjs(text):
    l = []
    doc = nlp(text)
    for sentence in doc.sentences:
        for dependency in sentence.dependencies:
            if dependency[1] == 'nsubj':
               l.append(dependency[2].text)
    return l

# %%
def have_common_elements(list1, list2):
    return any(elem in list2 for elem in list1)

# %%
count = 0
w = 0
for x_pre,x_hyp,y in test_loader:
    dp_answer = np.argmax(model(x_pre,x_hyp).cpu().detach().numpy())
    ground_truth = np.argmax(y.cpu().detach().numpy())
    dp_trust = np.argmax(newmodel(x_pre,x_hyp).cpu().detach().numpy())
    if dp_trust == 1: #untrust
          if len(x_pre[0])<=70 and len(x_hyp[0])<=70:
             count +=1
             print('num: '+str(count))
             if ground_truth!=dp_answer:
                w += 1
             print(x_pre)
             print(x_hyp)
             print('dp: '+ str(get_inf_from_num(dp_answer)))
             print('ground_truth: '+ str(get_inf_from_num(ground_truth)))
             print('========================================================')
print(w)
#print(count)
# Out:
# num: 1
# ('He denied headache or nausea or vomiting.',)
# ('He has no head pain',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 2
# ('He denied headache or nausea or vomiting.',)
# ('He is afebrile',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 3
# ('sinusitis asthma (not active) HSV-1 [**2572**]',)
# ('The patient has a herpes viral infection.',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 4
# ('PAST MEDICAL HISTORY:  Type 2 diabetes mellitus.',)
# ('the patient has type 2 diabetes',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 5
# ('PAST MEDICAL HISTORY:  Type 2 diabetes mellitus.',)
# ('the patient has type 1 diabetes',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 6
# ('PAST MEDICAL HISTORY:  Type 2 diabetes mellitus.',)
# ('the patient is on insulin',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 7
# ('Patient was also noted to have recent weight loss.',)
# ('patient has weight loss',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 8
# ('Patient was also noted to have recent weight loss.',)
# ('patient has weight gain',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 9
# ('htn hypercholesterolemia possible TIA in past new onset Afib (1wk PTA)',)
# ('The patient is at risk for embolic strokes.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 10
# ('He was also given lasix 80mg IV x1 with diuresis of 1800cc.',)
# ('He was volume depleted',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 11
# ('He was also given lasix 80mg IV x1 with diuresis of 1800cc.',)
# ('He has congestive heart failure',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 12
# ('History of CVA.',)
# ('patient has history of stroke',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 13
# ('It is difficult for her to move her right leg.',)
# ('The patient has had a left middle cerebral artery infarction.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 14
# ('He was then transferred to [**Hospital3 **] for further evaluation.',)
# ('He complains of abdominal pain',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 15
# ('There were no neurological changes recorded at the outside hospital.',)
# ('The patient has a stable neurological exam.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 16
# ('There were no neurological changes recorded at the outside hospital.',)
# ('The patient has a normal neurological exam.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 17
# ('The patient was extubated this morning.',)
# ('the patient was extubated',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 18
# ('The patient was extubated this morning.',)
# ('the patient is intubated',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 19
# ('She was taken to cesarean section for progression of labor.',)
# ('The patient delivered vaginally.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 20
# ('Nutmeg liver reaction, common bile duct within normal limits.',)
# ('patient has abnormal liver',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 21
# ('Nutmeg liver reaction, common bile duct within normal limits.',)
# ('patient has normal liver enzymes',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 22
# ('Nutmeg liver reaction, common bile duct within normal limits.',)
# ('patient has budd-chiari syndrome',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 23
# ('COPD: 1 ppd / 40 years.',)
# ('The patient has normal lungs.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 24
# ('He presented preoperatively for coronary artery bypass grafting.',)
# ('Patient has CAD',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 25
# ('He presented preoperatively for coronary artery bypass grafting.',)
# ('Patient has had a STEMI',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 26
# ('The PDA and posterolateral vessels had 90% ostial lesions.',)
# ('Patient has no CAD',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 27
# ('The PDA and posterolateral vessels had 90% ostial lesions.',)
# ('Patient may required CABG',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 28
# ('WBC 21.7, Hct 42.4, Plate 493, N 88, band 1.',)
# ('The patient has an elevated white blood cell count.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 29
# ('WBC 21.7, Hct 42.4, Plate 493, N 88, band 1.',)
# ('The patient has a normal white blood cell count.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 30
# ('He has no complaint of chest pain.',)
# ('the patient denies chest pain',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 31
# ('He has no complaint of chest pain.',)
# ('the patient has chest pain',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 32
# ('He has no complaint of chest pain.',)
# ('the patient denies shortness of breath',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 33
# ('She notes improved abdominal pain from prior.',)
# ('The patient had abdominal pain.',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 34
# ('She notes improved abdominal pain from prior.',)
# ('The patient has not had abdominal pain.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 35
# ('She notes improved abdominal pain from prior.',)
# ('The patient was given pain medications.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 36
# ('First set of cardiac enzymes were negative.',)
# ('The patient is being rules out for acute coronary syndrome.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 37
# ('First set of cardiac enzymes were negative.',)
# ('The patient had positive cardiac enzymes.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 38
# ('First set of cardiac enzymes were negative.',)
# ('The patient is not having a myocardial infarction.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 39
# ('This resulted in near-cessation of bleeding.',)
# ('Bleeding is uncontrolled.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 40
# ('This resulted in near-cessation of bleeding.',)
# ('Patient experienced trauma',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 41
# ('Status post CABG in [**2568-7-15**].',)
# ('Patient has extensive CAD',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 42
# ('She was evaluated by neurosurgery, deemed to be intact neurologically.',)
# ('Her neurological exam was normal',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 43
# ('She was evaluated by neurosurgery, deemed to be intact neurologically.',)
# ('No history of cerebrovascular accidents',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 44
# ('She was speaking normally at that time.',)
# ('The patient was known to communicate normally at a defined time.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 45
# ('She was speaking normally at that time.',)
# ('The patient has no known normal time where she was speaking normally.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 46
# ('He had no EKG changes and first set of enzymes were negative.',)
# ('the patient has chest pain',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 47
# ('He had no EKG changes and first set of enzymes were negative.',)
# ('the patient denies chest pain',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 48
# ('He had no EKG changes and first set of enzymes were negative.',)
# ('the patient has negative enzymes',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 49
# ('Recent gallstone pancreatitis [**1-23**] 12.',)
# ('Patient has elevated Alk phos',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 50
# ('She also received avalox 400mg IV.',)
# ('the patient recieved antibiotics',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 51
# ('She also received avalox 400mg IV.',)
# ('the patient has pneumonia',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 52
# ('She was given 20 mg IV etomidate, 150 mg IV succinylcholine.',)
# ('the patient was given general anesthetics',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 53
# ('She was given 20 mg IV etomidate, 150 mg IV succinylcholine.',)
# ('the procedure was performed with local anesthesia',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 54
# ('She was given 20 mg IV etomidate, 150 mg IV succinylcholine.',)
# ('the patient is undergoing an elective surgery',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 55
# ('Code stroke was called at 11:30a.',)
# ('The patient had a stroke',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 56
# ('Code stroke was called at 11:30a.',)
# ('The patient has atrial fibrillation',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 57
# ('He had been seizure free since then until the day of presentation.',)
# ('the patient had a seizure',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 58
# ('He had been seizure free since then until the day of presentation.',)
# ('the patient has no history of seizures',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 59
# ('He had 3 episodes of NB/NB emesis.',)
# ('He had vomiting',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 60
# ('He had 3 episodes of NB/NB emesis.',)
# ('He had abdominal pain',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 61
# ('The labor was induced with Pitocin.',)
# ('The patient underwent induced labor.',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 62
# ('The labor was induced with Pitocin.',)
# ('The patient underwent spontaneous labor.',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 63
# ('The labor was induced with Pitocin.',)
# ('The patient had prolonged pregnancy.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 64
# ('EKG with sinus tachycardia, no acute ST/TWI.',)
# ('patient is tachycardic',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 65
# ('EKG with sinus tachycardia, no acute ST/TWI.',)
# ('patient has normal blood pressure',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 66
# ('EKG with sinus tachycardia, no acute ST/TWI.',)
# ('patient is hypotensive',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 67
# ('No apparent residual symptoms.',)
# ('The patient is a symtomatic.',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 68
# ('He was warmed, dried and stimulated.',)
# ('the patient was warmed',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 69
# ('He was warmed, dried and stimulated.',)
# ('the patient was cooled',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 70
# ('He was warmed, dried and stimulated.',)
# ('the patient is obtunded',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 71
# ('Surgical clips are seen apparently in the distal sigmoid colon.',)
# ('Previous procedure done on sidmoid colon',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 72
# ('Surgical clips are seen apparently in the distal sigmoid colon.',)
# ('Patient has history of abdominal pain',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 73
# ('(Lactate only 1.3 and pt afebrile).  .',)
# ('Temperature was within normal range',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 74
# ('(Lactate only 1.3 and pt afebrile).  .',)
# ('Elevated temperature',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 75
# ('(Lactate only 1.3 and pt afebrile).  .',)
# ('Patient is in good health',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 76
# ('She had one episode of nausea/NBNB vomiting the day PTA.',)
# ('She had recent vomiting',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 77
# ('She had one episode of nausea/NBNB vomiting the day PTA.',)
# ('She complains of weakness',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 78
# ('Abdomen was soft, nontender, non distended.',)
# ('Abdominal exam was unremarkable',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 79
# ('Abdomen was soft, nontender, non distended.',)
# ('Abdomen was tender to palpation',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 80
# ('Abdomen was soft, nontender, non distended.',)
# ('The patient has left lower quadrant abdominal pain',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 81
# ('Alzheimers Dememtia "Mini strokes"',)
# ('the patient lives in assisted living',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 82
# ('At [**Hospital1 18**], her VS were T97.3 HR90 BP99/49 RR24 95% NRB.',)
# ('the patient has tachypnea',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 83
# ('At [**Hospital1 18**], her VS were T97.3 HR90 BP99/49 RR24 95% NRB.',)
# ('the patient has normal respiratory rate',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 84
# ('At [**Hospital1 18**], her VS were T97.3 HR90 BP99/49 RR24 95% NRB.',)
# ('the patient is short of breath',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 85
# ('OB History:  G5, P1-0-4-1.',)
# ('the patient has had abortions',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 86
# ('OB History:  G5, P1-0-4-1.',)
# ('the patient has had a premature child',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 87
# ('OB History:  G5, P1-0-4-1.',)
# ('the patient elective abortions',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 88
# ('Multiple consultations were performed.',)
# ('Patient has seen numerous specialists',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 89
# ('Multiple consultations were performed.',)
# ('Patient has multiple disease',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 90
# ('Her hematocrit stabilized and bleeding was mostly resolved.',)
# ('The patient had a declining hematocrit.',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 91
# ('Her hematocrit stabilized and bleeding was mostly resolved.',)
# ('The patient has an elevated hematocrit.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 92
# ('Her hematocrit stabilized and bleeding was mostly resolved.',)
# ('The patient has a bleeding disorder.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 93
# ('Selective catheterization left internal carotid artery.',)
# ('A procedure to analyze the coronary arteries.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 94
# ('Selective catheterization left internal carotid artery.',)
# ('The study always shows if there is coronary artery disease.',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 95
# ('Atrial fibrillation, not known whether chronic or paroxysmal.',)
# ('The patient has atrial fibrillation.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 96
# ('Atrial fibrillation, not known whether chronic or paroxysmal.',)
# ('The patient has normal heart rhythm.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 97
# ('Atrial fibrillation, not known whether chronic or paroxysmal.',)
# ('The patient is anti coagulated.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 98
# ('She was found to have BRBPR on rectal exam.',)
# ('the patient had bright read blood per rectum',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 99
# ('She was found to have BRBPR on rectal exam.',)
# ('the patient has hemorrhoids',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 100
# ('Diastolic CHF, LVEF >70% 2/06 10.',)
# ('Patient has decreased diastolic filling',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 101
# ('Diastolic CHF, LVEF >70% 2/06 10.',)
# ('Patient has angina',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 102
# ('Diastolic CHF, LVEF >70% 2/06 10.',)
# ('Patient has abnormal echo',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 103
# ('CT head showed no acute intracranial process.',)
# ('the patient is confused',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 104
# ('49 yo male found to have a heart murmur a few months ago.',)
# ('the patient has a heart murmur',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 105
# ('49 yo male found to have a heart murmur a few months ago.',)
# ('He has an ASD',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 106
# ('Congestive heart failure.',)
# ('Patient has a chronic condition',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 107
# ('Congestive heart failure.',)
# ('Patient has no PMH',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 108
# ('Congestive heart failure.',)
# ('Patient has low ejection fraction',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 109
# ('Congestive heart failure.',)
# ('Patient has abnormal ejection fracture',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 110
# ('Congestive heart failure.',)
# ('Patient has a normal echo',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 111
# ('Congestive heart failure.',)
# ('Patient has pulmonary edema',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 112
# ('Congestive heart failure.',)
# ('Heart disease',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 113
# ('Congestive heart failure.',)
# ('Normal cardiac function',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 114
# ('Congestive heart failure.',)
# ('Edema and cough',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 115
# ('CT abdomen confirmed acute uncomplicated diverticulitis.',)
# ('CT scan of the abdomen was abnormal',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 116
# ('CT abdomen confirmed acute uncomplicated diverticulitis.',)
# ('The patient had abdominal pain and nausea',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 117
# ('Moving all four extremities, responding to sternal rub.',)
# ('Patient has normal response to the given stimulus',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 118
# ('Moving all four extremities, responding to sternal rub.',)
# ('Patient is unresponsive',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 119
# ('Moving all four extremities, responding to sternal rub.',)
# ('Patient has had a stroke',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 120
# ('Mild mitral regurgitation.',)
# ('Cardiac valve dysfunction',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 121
# ('Mild mitral regurgitation.',)
# ('Normal cardiac function',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 122
# ('Mild mitral regurgitation.',)
# ('Heart murmur',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 123
# ('He was emergently intubated, and a right femoral cordis was placed.',)
# ('Patient has central venous line in place',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 124
# ('She had no LOC.',)
# ('The patient lost consciousness.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 125
# ('She had no LOC.',)
# ('The patient did not have head trauma.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 126
# ('She recovered consciousness once the medics arrived.',)
# ('She was previously unconscious',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 127
# ('She recovered consciousness once the medics arrived.',)
# ('She remained unconscious once medics arrived',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 128
# ('She recovered consciousness once the medics arrived.',)
# ('She sustained trauma',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 129
# ('DM x 20yrs 4.',)
# ('Patient has chronic medical condition',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 130
# ('DM x 20yrs 4.',)
# ('Patient has normal A1c',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 131
# ('DM x 20yrs 4.',)
# ('Patient has elevated blood glucose',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 132
# ('Blood glucose 626.',)
# ('Patient has hyperglycemia',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 133
# ('Blood glucose 626.',)
# ('Patient has normal A1c',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 134
# ('Blood glucose 626.',)
# ('Patient has diabetes type 1',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 135
# ('Status post dilatation and curettage.',)
# ('Patient was recently pregnent',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 136
# ('Status post dilatation and curettage.',)
# ('Patient has had an invasive procedure',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 137
# ('The patient denied headache, numbness, tingling, or double vision.',)
# ('The patient denied diplopia',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 138
# ('The patient denied headache, numbness, tingling, or double vision.',)
# ('The patient had loss of sensation in the extremities',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 139
# ('No EGD done at the time.',)
# ('The patient did not have an upper endoscopy performed.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 140
# ('No EGD done at the time.',)
# ('The patient had an EGD performed.',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 141
# ('No EGD done at the time.',)
# ('The patient has GERD like symptoms.',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 142
# ('She vomited twice while she was there.',)
# ('the patient is vomiting',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 143
# ('She vomited twice while she was there.',)
# ('the patient has a headache',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 144
# ('Presented to ER and ruled in for MI.',)
# ('Patient has impaired myocardial perfusion',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 145
# ('Presented to ER and ruled in for MI.',)
# ('Patient has abnormal EKG',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 146
# ('Severe hyperemesis requiring TPN.',)
# ('Patient has malnutrition',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 147
# ('Severe hyperemesis requiring TPN.',)
# ('Patient has no IV in place',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 148
# ('Severe hyperemesis requiring TPN.',)
# ('Patient is pregnant',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 149
# ('Severe hyperemesis requiring TPN.',)
# ('Mild vomiting treated with PO medication',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 150
# ('Severe hyperemesis requiring TPN.',)
# ('Patient has lost weight',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 151
# ('Pupils equal, round, reactive to light, 5 down to 3 mm bilaterally.',)
# ('patient has equal pupils',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 152
# ('Pupils equal, round, reactive to light, 5 down to 3 mm bilaterally.',)
# ('patient has non reactive pupils',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 153
# ('Pupils equal, round, reactive to light, 5 down to 3 mm bilaterally.',)
# ('patient is obtunded',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 154
# ('Non-insulin dependent-diabetes mellitus.',)
# ('No history of hyperglycemia',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 155
# ('Also a history of hepatopulmonary syndrome and with MELD score of 27.',)
# ('The patient has liver failure.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 156
# ('Also a history of hepatopulmonary syndrome and with MELD score of 27.',)
# ('The patient has alcoholic cirrhosis.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 157
# ('He began feeling fatigued at the beginning of [**Month (only) **].',)
# ('the patient has fatigue',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 158
# ('He tried mylanta in AM without relief.',)
# ('patient has chest discomfort',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 159
# ('He tried mylanta in AM without relief.',)
# ('patient denies pain',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 160
# ('He tried mylanta in AM without relief.',)
# ('patient has GERD',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 161
# ('Lungs are otherwise clear.',)
# ('The patient had chest imaging.',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 162
# ('Lungs are otherwise clear.',)
# ('The patient’s lungs are completely opacified on chest x-ray.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 163
# ('Lungs are otherwise clear.',)
# ('The patient does not have pneumonia.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 164
# ('Denies CP or abdominal pain.',)
# ('The patient does not have chest pain.',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 165
# ('Denies CP or abdominal pain.',)
# ('The patient has chest pain.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 166
# ('Denies CP or abdominal pain.',)
# ('The patient is not having a myocardial infarction.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 167
# ('Mother has a remote history of HSV reported in [**3148**].',)
# ('Mother has a history of herpes simplex',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 168
# ('Mother has a remote history of HSV reported in [**3148**].',)
# ('Mother has a history of antiviral medication',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 169
# ('No chest pain.',)
# ('the patient denies chest pain',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 170
# ('No chest pain.',)
# ('the patient has chest pain',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 171
# ('No chest pain.',)
# ('EKG is normal',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 172
# ('She continues to have some lightheadedness and epigastric pain. .',)
# ('The patient has epigastric pain',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 173
# ('She continues to have some lightheadedness and epigastric pain. .',)
# ('the patient has a gastric ulcer',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 174
# ("Apgar's were 8 and 8.",)
# ('Patient has poor Apgar’s',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 175
# ("Apgar's were 8 and 8.",)
# ('Patient is a female newborn',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 176
# ('He had no nausea or vomiting prior the EGD.',)
# ('the patient underwent an EGD',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 177
# ('He had no nausea or vomiting prior the EGD.',)
# ('the patient has chronic abdominal pain',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 178
# ('She placed him back on O2.',)
# ('the patient is on oxygen',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 179
# ('She placed him back on O2.',)
# ('the patient has chest pain',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 180
# ('An emergent Hematology consultation was obtained.',)
# ('the patient had an emergent hematology consult',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 181
# ('An emergent Hematology consultation was obtained.',)
# ('the patient has heparin induced thrombocytopenia',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 182
# ('He was transferred to [**Hospital1 22**] for further management.',)
# ('The patient was treated at a different hospital.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 183
# ('He was transferred to [**Hospital1 22**] for further management.',)
# ('The patient was not treated at a hospital.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 184
# ('He was transferred to [**Hospital1 22**] for further management.',)
# ('The patient required a higher level of care.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 185
# ('Status post Bankart repair of his right shoulder in [**3354**].',)
# ('He had a shoulder dislocation',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 186
# ('Status post Bankart repair of his right shoulder in [**3354**].',)
# ('He had a recent fall',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 187
# ('Head circumference 30.5 cm, 25th-50th percentile.',)
# ('the patient has normal head circumference',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 188
# ('Head circumference 30.5 cm, 25th-50th percentile.',)
# ('the patient has macrocephaly',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 189
# ('Head circumference 30.5 cm, 25th-50th percentile.',)
# ('the patient has a normal weight',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 190
# ('Family found her about 3 AM on the floor.',)
# ('the patient was found on the floor',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 191
# ('Type 1 diabetes mellitus since age 9.',)
# ('Patient has had diabetic ketoacidosis',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 192
# ('Transferred to CCU for further management. .',)
# ('The patient required intensive care',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 193
# ('Transferred to CCU for further management. .',)
# ('The patient was discharged home',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 194
# ('Transferred to CCU for further management. .',)
# ('The patient had elevated troponin levels',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 195
# ('She denies any abdominal discomfort or dyspepsia now or in the past.',)
# ('the patient denies abdominal pain',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 196
# ('She denies any abdominal discomfort or dyspepsia now or in the past.',)
# ('the patient has abdominal pain',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 197
# ('She denies any abdominal discomfort or dyspepsia now or in the past.',)
# ('the patient denies chest pain',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 198
# ('No abscess noted; no s[** Location **] or portal vein thrombosis.',)
# ('The patient does not have a clot within the portal vein.',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 199
# ('No abscess noted; no s[** Location **] or portal vein thrombosis.',)
# ('The patient does note have any hepatic lesions.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 200
# ('The patient denies alcohol use.',)
# ('The patient does not drink alcohol',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 201
# ('The patient denies alcohol use.',)
# ('The patient abuses alcohol',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 202
# ('The patient denies alcohol use.',)
# ('The patient has no history of drug abuse',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 203
# ('Labor was induced with Pitocin.',)
# ('Patient is in labor',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 204
# ('Labor was induced with Pitocin.',)
# ('Patient was given a C-section',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 205
# ('Labor was induced with Pitocin.',)
# ('Patient labor is not progressing',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 206
# ('Seizure disorder, in the setting of renal failure.',)
# ('kidney dysfunction',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 207
# ('Seizure disorder, in the setting of renal failure.',)
# ('Patient is on dialysis',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 208
# ("Alzheimer's dementia 3.",)
# ('Patient has abnormal brain MRI',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 209
# ("Alzheimer's dementia 3.",)
# ('the patient has dementia',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 210
# ('The patient usually walks without any assistance.',)
# ('The patient is at baseline ambulatory',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 211
# ('The patient usually walks without any assistance.',)
# ('The patient is wheelchair-bound',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 212
# ('The patient usually walks without any assistance.',)
# ('The patient performs activities of daily living independently',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 213
# ('Next was in [**3079**] with severe left sided weakness.',)
# ('Patient has signs of stroke',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 214
# ('Next was in [**3079**] with severe left sided weakness.',)
# ('Patient has a TIA',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 215
# ('Patient also on coumadin for h/o DVT.',)
# ('The patient is being anticoagulated.',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 216
# ('Patient also on coumadin for h/o DVT.',)
# ('The patient has a hypercoaguable condition.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 217
# ('BPH w h/o obstruction requiring foley placement.',)
# ('Prostate enlargement',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 218
# ('BPH w h/o obstruction requiring foley placement.',)
# ('High levels of PSA',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 219
# ('Insulin dependent diabetes mellitus, diagnosed age    thirteen.',)
# ('Patient has elevated serum glucose',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 220
# ('Her BP fell to 97/52, then later rose to 197/92 (very labile).',)
# ('Patient has intermittent hypotension',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 221
# ('Her BP fell to 97/52, then later rose to 197/92 (very labile).',)
# ('Patient has stable blood pressure',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 222
# ('Mild aortic stenosis on echo- history of syncope 9.',)
# ('Echo showed narrowing of the aorta',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 223
# ('Routine drying, suctioning and stimulated.',)
# ('The infant was recently born.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 224
# ('Routine drying, suctioning and stimulated.',)
# ('The mother has not delivered the patient yet.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 225
# ('Routine drying, suctioning and stimulated.',)
# ('The delivery was a normal spontaneous vaginal delivery.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 226
# ('Paroxysmal atrial fibrillation.',)
# ('Patient has abnormal EKG',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 227
# ('Paroxysmal atrial fibrillation.',)
# ('Patient has NSR',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 228
# ('Paroxysmal atrial fibrillation.',)
# ('Patient has angina',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 229
# ('Paroxysmal atrial fibrillation.',)
# ('Patient has occasional abnormal cardiac rhythms',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 230
# ('Paroxysmal atrial fibrillation.',)
# ('Patient has normal EKG',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 231
# ('Paroxysmal atrial fibrillation.',)
# ('Patient has palpitations',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 232
# ('Paroxysmal atrial fibrillation.',)
# ('Arrhythmia',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 233
# ('Paroxysmal atrial fibrillation.',)
# ('The patient is on a beta blocker',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 234
# ('Paroxysmal atrial fibrillation.',)
# ('Arrhythmia',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 235
# ('S/he denies recent fevers, chills or rigors.',)
# ('the patient denies fevers.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 236
# ('S/he denies recent fevers, chills or rigors.',)
# ('the patient denies weight loss.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 237
# ('No abdominal pain or diarrhea.',)
# ('the patient has no abdominal pain.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 238
# ('No abdominal pain or diarrhea.',)
# ('the patient has diarrhea.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 239
# ('No abdominal pain or diarrhea.',)
# ('the patient has no chest pain.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 240
# ('Duodenal ulcer/melena, [**2608-10-28**], H. pylori negative.',)
# ('the patient has a normal duodenum',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 241
# ('Status post appendectomy 11.',)
# ('No surgical history',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 242
# ('Status post appendectomy 11.',)
# ('The patient has a history of  obstructing fecaliths in the appendix',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 243
# ('Autoimmune hemolytic anemia.',)
# ('A disease that causes red blood cells to lyse.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 244
# ('Autoimmune hemolytic anemia.',)
# ('Patients with this disease also have other autoimmune diseases.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 245
# ('She was discharged on bed rest and treated with terbutaline.',)
# ('Patient is no longer inpatient',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 246
# ('She was discharged on bed rest and treated with terbutaline.',)
# ('Patient is no longer taking medications',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 247
# ('She was discharged on bed rest and treated with terbutaline.',)
# ('Patient has a follow up appointment',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 248
# ('Pt had normal physical exam and reported "melena" in the rectal vault.',)
# ('The patient has blood found within the rectum.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 249
# ('Pt had normal physical exam and reported "melena" in the rectal vault.',)
# ('The patient does not have a GI bleed.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 250
# ...
# num: 295
# ('Transferred here for possible intervention.',)
# ('He required medical care',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 296
# ('Transferred here for possible intervention.',)
# ('He presented with chest pain',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 297
# ('No shortness of breath or orthopnea, no Chest pain or discomfort.',)
# ('patient has no chest pain',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 298
# ('No shortness of breath or orthopnea, no Chest pain or discomfort.',)
# ('patient has chest pain',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 299
# ('No shortness of breath or orthopnea, no Chest pain or discomfort.',)
# ('chest x ray is normal',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 300
# ('Per family members, rash started at least for 1 wk.',)
# ('Patient has a dermatologic finding on exam',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 301
# ('Per family members, rash started at least for 1 wk.',)
# ('Patient has shingles',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 302
# ('Per her son, Mrs.',)
# ('The patient has a son.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 303
# ('Per her son, Mrs.',)
# ('The patient does not have a son.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 304
# ('Per her son, Mrs.',)
# ('The son is an adult.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 305
# ('The patient reports having reactive airway disease.',)
# ('The patient has COPD and/or atshma.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 306
# ('The patient reports having reactive airway disease.',)
# ('The patient has normal pulmonary function.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 307
# ('The patient reports having reactive airway disease.',)
# ('The patient uses an inhaler.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 308
# ('Reports a history of chlamydia in the past.',)
# ('Patient has prior infection',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 309
# ('She was not experiencing hematemasis.',)
# ('She was not vomiting blood',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 310
# ('In ED the pt was exhibiting Kussmaul breathing and was tachycardic.',)
# ('Patient has abnormal heart rhythm',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 311
# ('There was peripheral flexing in her lower extremities.',)
# ('The patient is able to ambulate',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 312
# ('She does admit to some diarrhea at home.',)
# ('The patient has diarrhea',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 313
# ('She does admit to some diarrhea at home.',)
# ('The patient is constipated',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 314
# ('No recent change in bowel or bladder habits.',)
# ('The patient has stable bowel habits.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 315
# ('No recent change in bowel or bladder habits.',)
# ('The patient does not have a urinary tract infection.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 316
# ('The pregnancy was complicated by increased maternal blood pressures.',)
# ('there is maternal hypertension',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 317
# ('The pregnancy was complicated by increased maternal blood pressures.',)
# ('there is pre eclampsia',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 318
# ('82F with Sjogrens, vasculitis, GI bleed, HTN who p/w GIB.',)
# ('The patient has a gastrointestinal bleed',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 319
# ('She was volume resusciatated with 4 Units PRBCs and 3 liters of NS.',)
# ('She was treated for volume depletion',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 320
# ('She was volume resusciatated with 4 Units PRBCs and 3 liters of NS.',)
# ('She is hypotensive',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 321
# ('Pt intubated in the field.',)
# ('Pt received a breathing tube',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 322
# ('Pt intubated in the field.',)
# ('Patient needed no respiratory support',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 323
# ('Pt intubated in the field.',)
# ('Pt was in respiratory failure',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 324
# ('She notes that her a[** Location **]e and sleep have been poor.',)
# ('The patient has not been sleeping well',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 325
# ('She notes that her a[** Location **]e and sleep have been poor.',)
# ('The patient has no complaints',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 326
# ('She notes that her a[** Location **]e and sleep have been poor.',)
# ('The patient has been feeling ill',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 327
# ('The discharge summary was reviewed, and is briefly summarized below. .',)
# ('The patient was hospitalized.',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 328
# ('The discharge summary was reviewed, and is briefly summarized below. .',)
# ('The patient was not hospitalized.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 329
# ('The discharge summary was reviewed, and is briefly summarized below. .',)
# ('The patient was hospitalized for acute coronary syndrome.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 330
# ('Today she was too weak to get out of bed.',)
# ('She has not been ambulatory',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 331
# ('Today she was too weak to get out of bed.',)
# ('She is ambulatory',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 332
# ('Today she was too weak to get out of bed.',)
# ('She has nausea and vomiting',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 333
# ('It was also associated with diaphoresis.',)
# ('The patient has sweats.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 334
# ('Status post colostomy now reversed.',)
# ('the patient has a history of a colostomy',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 335
# ('Status post colostomy now reversed.',)
# ('the patient has no surgical history',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 336
# ('Status post colostomy now reversed.',)
# ('the patient has a history of colon cancer',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 337
# ('Her platelets were approx 100 at the time of transfer. .',)
# ('The patient has elevated platelets.',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 338
# ('Her platelets were approx 100 at the time of transfer. .',)
# ('The patient has a bleeding disorder.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 339
# ('CT showing grade IV s[** Location **] laceration w/ hemoperitoneum.',)
# ('the patient had a MVA',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 340
# ('He had poor memory of preceding events, but was A&Ox3 post-extubation.',)
# ('She was previously intubated',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 341
# ('He had poor memory of preceding events, but was A&Ox3 post-extubation.',)
# ('She was unconscious post-extubation',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 342
# ('He had poor memory of preceding events, but was A&Ox3 post-extubation.',)
# ('She was previously unconscious',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 343
# ('Denies head trauma.',)
# ('History of concussions',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 344
# ('The transbronchial biopsy was nondiagnostic.',)
# ('Patient has a mediastinal mass',)
# dp: contradiction
# ground_truth: entailment
# ========================================================
# num: 345
# ('The transbronchial biopsy was nondiagnostic.',)
# ('Patient has a negative CT exam',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 346
# ('as above, CRI, GERD, HTN, hyperlipidemia, renal calculi',)
# ('The patient has flank pain.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 347
# ('There is no pericardial effusion.',)
# ('No abnormal collection of fluid in the pericardial cavity',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 348
# ('There is no pericardial effusion.',)
# ('The patient denies shortness of breath',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 349
# ('She is being called out to the medical floor in stable condition.',)
# ('the patient was in the icu',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 350
# ('#NAME?',)
# ('Reports feeling sensation of irregular heartbeats',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 351
# ('#NAME?',)
# ('No complaints of irregular heartbeat',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 352
# ('History of SBO and partial SBO in the past.',)
# ('History of small bowel obstruction',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 353
# ('History of SBO and partial SBO in the past.',)
# ('History of abdominal surgery',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 354
# ('The day of her admission she was told that her blood pressure was low.',)
# ('the patient is hypotensive',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 355
# ('The day of her admission she was told that her blood pressure was low.',)
# ('the patient is hypertensive',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 356
# ('Pregnancy was complicated by a UTI x2, HSV infection.',)
# ('Delivery was via c-section',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 357
# ('Of note, while on the morphine gtt her BP dropped to 83/30.',)
# ('The patient does not have IV access.',)
# dp: contradiction
# ground_truth: contradiction
# ========================================================
# num: 358
# ('Of note, while on the morphine gtt her BP dropped to 83/30.',)
# ('The morphine caused the hypotension.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 359
# ('CVA in [**2987**] with residual left-sided weakness 8.',)
# ('Patient has had prior stroke',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 360
# ('CVA in [**2987**] with residual left-sided weakness 8.',)
# ('The patient has athersclerotic disease in the carotid arteries.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 361
# ('History of peripheral neuropathy.',)
# ('The patient has decreased sensation at the extremities.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 362
# ('History of peripheral neuropathy.',)
# ('The patient has diabetes.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 363
# ('She had CT abdomen which was negative.',)
# ('patient has normal ct abdomen',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 364
# ('She had CT abdomen which was negative.',)
# ('patient has kidney stones',)
# dp: entailment
# ground_truth: contradiction
# ========================================================
# num: 365
# ('She had CT abdomen which was negative.',)
# ('patient has abdominal pain',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 366
# ('Restrictive lung disease.',)
# ('Patient has decreased FEV1',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 367
# ('Restrictive lung disease.',)
# ('Patient has normal PFTs',)
# dp: neutral
# ground_truth: contradiction
# ========================================================
# num: 368
# ('Restrictive lung disease.',)
# ('Patient has abnormal chest CT',)
# dp: contradiction
# ground_truth: neutral
# ========================================================
# num: 369
# ('He denies recent fevers, chills or rigors.',)
# ('The patient is not febrile.',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# num: 370
# ('He denies recent fevers, chills or rigors.',)
# ('The patient does not have symptoms of an infection.',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 371
# ('He denies recent fevers, chills or rigors.',)
# ('The patient has no symptoms of a fever.',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 372
# ('He denies recent fevers, chills or rigors.',)
# ('The patient does not have an infection.',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 373
# ('He denies recent fevers, chills or rigors.',)
# ('He is afebrile',)
# dp: entailment
# ground_truth: entailment
# ========================================================
# num: 374
# ('He denies recent fevers, chills or rigors.',)
# ('He denies pain',)
# dp: entailment
# ground_truth: neutral
# ========================================================
# num: 375
# ('Started on levophed for BP support despite 8LNS.',)
# ('The patient is in the ICU',)
# dp: neutral
# ground_truth: neutral
# ========================================================
# num: 376
# ('Papillary peritoneal serous carcinoma, metastatic.',)
# ('Patient has stage IV cancer',)
# dp: neutral
# ground_truth: entailment
# ========================================================
# 136
