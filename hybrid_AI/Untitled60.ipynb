# %%
# !pip install fasttext
# !pip install fastparquet
# !gdown --id '1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM'
# !gdown --id '1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp'
# !gdown --id '1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN'
# !unzip MedNLI_dataset.zip
# !pip install stanza
# !pip install medialpy
# !pip install contractions
# !wget https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin
# !wget https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin.wv.vectors.npy
# !wget https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin.trainables.syn1neg.npy
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (71.0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.26.4)
# Using cached pybind11-2.13.1-py3-none-any.whl (238 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4246768 sha256=edcee05ffa6c987a8283221fac381283f23940d2bf6d77d50dcfbf687e6d8a0c
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.1
# Collecting fastparquet
#   Downloading fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.26.4)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Downloading fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.4 MB/s eta 0:00:00
# Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 78.2 MB/s eta 0:00:00
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.8.3 fastparquet-2024.5.0
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM
# From (redirected): https://drive.google.com/uc?id=1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM&confirm=t&uuid=a0f15f45-81e1-4d29-bb90-5fcbb14c9ddc
# To: /content/modelw.pth
# 100% 516M/516M [00:13<00:00, 38.6MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp
# To: /content/MedNLI_dataset.zip
# 100% 681k/681k [00:00<00:00, 7.65MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN
# From (redirected): https://drive.google.com/uc?id=1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN&confirm=t&uuid=2eee1dff-3233-4e6e-a68f-49d0a037e947
# To: /content/TrustModelw5.pth
# 100% 516M/516M [00:06<00:00, 78.7MB/s]
# Archive:  MedNLI_dataset.zip
#    creating: MedNLI_dataset/
#   inflating: MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet
#   inflating: MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet
#   inflating: MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet
# Collecting stanza
#   Downloading stanza-1.8.2-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.26.4)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.3.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.3.0->stanza)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Downloading stanza-1.8.2-py3-none-any.whl (990 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.1/990.1 kB 18.9 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 558.6 kB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 62.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
# Successfully installed emoji-2.12.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 stanza-1.8.2
# Collecting medialpy
#   Downloading medialpy-0.0.4-py3-none-any.whl.metadata (2.6 kB)
# Downloading medialpy-0.0.4-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: medialpy
# Successfully installed medialpy-0.0.4
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (13 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 12.2 MB/s eta 0:00:00
# Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24
# --2024-08-01 16:13:39--  https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.23, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/7f920b29a2c3861a475f296d397ff679528b064dbb51debf33568ae5f4f7e088?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin%3B+filename%3D%22w2v_OA_CR_100d.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1722788019&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=HvohViQJL5tVJHz7xF1lLLshR4FcaIruax5cSlv0eHbenclTp0Bb5ml3NHRjBYnPs7PjaMvXt7QGMXOkKRhSwDako-tYG4RmdjF2gQ0XuXe8BU5dGXxAo7Qz7vKZHDmWtmNYZmK0NQuCOJL9922DFAiyMla4J6uBgC6bwIlydOrvNJu4nIzG5GsdH-mQQdVVq9iqM80vwqCNiDoOBnx8XXugHiv8jYgzMnKnb1EjGG6VomKwXgSgOUUkO7KHXI0AjcFS2eaIPwKYapFVWVj4d8pWfQUf4pAGxt6Le5FX%7EAJmy-Bn--Kzgp%7ERSDs0FPguj1lvcZNwhey0jrCAJCkMrg__&Key-Pair-Id=K3ESJI6DHPFC7 [following]
# --2024-08-01 16:13:39--  https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/7f920b29a2c3861a475f296d397ff679528b064dbb51debf33568ae5f4f7e088?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin%3B+filename%3D%22w2v_OA_CR_100d.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1722788019&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=HvohViQJL5tVJHz7xF1lLLshR4FcaIruax5cSlv0eHbenclTp0Bb5ml3NHRjBYnPs7PjaMvXt7QGMXOkKRhSwDako-tYG4RmdjF2gQ0XuXe8BU5dGXxAo7Qz7vKZHDmWtmNYZmK0NQuCOJL9922DFAiyMla4J6uBgC6bwIlydOrvNJu4nIzG5GsdH-mQQdVVq9iqM80vwqCNiDoOBnx8XXugHiv8jYgzMnKnb1EjGG6VomKwXgSgOUUkO7KHXI0AjcFS2eaIPwKYapFVWVj4d8pWfQUf4pAGxt6Le5FX%7EAJmy-Bn--Kzgp%7ERSDs0FPguj1lvcZNwhey0jrCAJCkMrg__&Key-Pair-Id=K3ESJI6DHPFC7
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.154.206.4, 18.154.206.14, 18.154.206.17, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.154.206.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24237857 (23M) [application/octet-stream]
# Saving to: ‘w2v_OA_CR_100d.bin’
#
# w2v_OA_CR_100d.bin  100%[===================>]  23.11M  --.-KB/s    in 0.1s
#
# 2024-08-01 16:13:39 (221 MB/s) - ‘w2v_OA_CR_100d.bin’ saved [24237857/24237857]
#
# --2024-08-01 16:13:39--  https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin.wv.vectors.npy
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.17, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/72926d774155dfaef4763802927a53fa6315afc5ada32b5c797c4c8db9066bf4?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin.wv.vectors.npy%3B+filename%3D%22w2v_OA_CR_100d.bin.wv.vectors.npy%22%3B&Expires=1722788019&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=LWcUNE4iHITv20tXiyuxMalH-1c%7ELjSAbh%7EFil8FUY1khMI3N3%7EPLGPAoLt7hGoShqCnYtQjNrXvjmHWyHN8YGhmTAXT%7Ezo6xbAPPsa6WkYHLXhMcW71O22DN5L96Sdpt6wbw%7EyR3ELw4T5FC5kjpfgTRAjUkO2n8D1ZJT9%7ELTIVXU81mu1KsQSV%7E7csQaUkV6vYm0ToE66GpgGRcmnl3bOKwwwNV4J5F4Bk4C-Jha65hQjxKd8CIyFOen8kJx%7Eo94bkNqLTdXGGUuCpy%7E5rBphjKZko7d%7EHYEkMpnbKNuM3HrbZcaCxC-eZhIaIICtgIE9hDiL74Hmwea-POsQdsA__&Key-Pair-Id=K3ESJI6DHPFC7 [following]
# --2024-08-01 16:13:39--  https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/72926d774155dfaef4763802927a53fa6315afc5ada32b5c797c4c8db9066bf4?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin.wv.vectors.npy%3B+filename%3D%22w2v_OA_CR_100d.bin.wv.vectors.npy%22%3B&Expires=1722788019&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=LWcUNE4iHITv20tXiyuxMalH-1c%7ELjSAbh%7EFil8FUY1khMI3N3%7EPLGPAoLt7hGoShqCnYtQjNrXvjmHWyHN8YGhmTAXT%7Ezo6xbAPPsa6WkYHLXhMcW71O22DN5L96Sdpt6wbw%7EyR3ELw4T5FC5kjpfgTRAjUkO2n8D1ZJT9%7ELTIVXU81mu1KsQSV%7E7csQaUkV6vYm0ToE66GpgGRcmnl3bOKwwwNV4J5F4Bk4C-Jha65hQjxKd8CIyFOen8kJx%7Eo94bkNqLTdXGGUuCpy%7E5rBphjKZko7d%7EHYEkMpnbKNuM3HrbZcaCxC-eZhIaIICtgIE9hDiL74Hmwea-POsQdsA__&Key-Pair-Id=K3ESJI6DHPFC7
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.154.206.17, 18.154.206.4, 18.154.206.28, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133344128 (127M) [binary/octet-stream]
# Saving to: ‘w2v_OA_CR_100d.bin.wv.vectors.npy’
#
# w2v_OA_CR_100d.bin. 100%[===================>] 127.17M   152MB/s    in 0.8s
#
# 2024-08-01 16:13:40 (152 MB/s) - ‘w2v_OA_CR_100d.bin.wv.vectors.npy’ saved [133344128/133344128]
#
# --2024-08-01 16:13:40--  https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin.trainables.syn1neg.npy
# Resolving huggingface.co (huggingface.co)... 18.164.174.23, 18.164.174.17, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/db1819eafe7cc01a478aaf2fb7e3fc11bfeca24efafdff879a527e7f34e046e2?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin.trainables.syn1neg.npy%3B+filename%3D%22w2v_OA_CR_100d.bin.trainables.syn1neg.npy%22%3B&Expires=1722788020&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=O9fTF7LfhPlE07jGS-eVWxuAe7e0UQp4eNSq5lRkSfFjO3oBJ6aUZoSRvpEzn7VxFKCaopF95OqLBkz28Y6j0nQwpv0qpo35pt-E%7EFmZvDfAUjWI0X-viVRV6TjEuT8OpjXDKqWIJXKp7ubTLxUC0UokIXj62Gi1JaBLSA8GWl42py74w-UNnPY%7EXBU-wbls-IDYIVJS0B8359LrMspg0QALGrspVwSimtQGO8IAUCVvtPjoQ5zoOsvv8EYrV1tnYZVth9HFquZ21OJLMKnUBrC15ZFXs0D8eNci1UZ3l3E%7Ewda7ZrvMemNdoaCFqHnYb1G7yOW7NdjtCKaSMZV36A__&Key-Pair-Id=K3ESJI6DHPFC7 [following]
# --2024-08-01 16:13:41--  https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/db1819eafe7cc01a478aaf2fb7e3fc11bfeca24efafdff879a527e7f34e046e2?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin.trainables.syn1neg.npy%3B+filename%3D%22w2v_OA_CR_100d.bin.trainables.syn1neg.npy%22%3B&Expires=1722788020&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=O9fTF7LfhPlE07jGS-eVWxuAe7e0UQp4eNSq5lRkSfFjO3oBJ6aUZoSRvpEzn7VxFKCaopF95OqLBkz28Y6j0nQwpv0qpo35pt-E%7EFmZvDfAUjWI0X-viVRV6TjEuT8OpjXDKqWIJXKp7ubTLxUC0UokIXj62Gi1JaBLSA8GWl42py74w-UNnPY%7EXBU-wbls-IDYIVJS0B8359LrMspg0QALGrspVwSimtQGO8IAUCVvtPjoQ5zoOsvv8EYrV1tnYZVth9HFquZ21OJLMKnUBrC15ZFXs0D8eNci1UZ3l3E%7Ewda7ZrvMemNdoaCFqHnYb1G7yOW7NdjtCKaSMZV36A__&Key-Pair-Id=K3ESJI6DHPFC7
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.154.206.17, 18.154.206.4, 18.154.206.28, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133344128 (127M) [binary/octet-stream]
# Saving to: ‘w2v_OA_CR_100d.bin.trainables.syn1neg.npy’
#
# w2v_OA_CR_100d.bin. 100%[===================>] 127.17M   200MB/s    in 0.6s
#
# 2024-08-01 16:13:41 (200 MB/s) - ‘w2v_OA_CR_100d.bin.trainables.syn1neg.npy’ saved [133344128/133344128]

# %%
# @title imports
from transformers import AutoTokenizer, AutoModel
import pandas as pd
import stanza
import shutil
import numpy as np
from numpy.linalg import norm
import string
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from gensim.models import FastText, Word2Vec, KeyedVectors
from torch.utils.data import Dataset,DataLoader
from sklearn.metrics import accuracy_score
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
import medialpy
from stanza import Pipeline
import contractions
import shutil
from google.colab import drive
drive.mount('/content/drive')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Mounted at /content/drive

# %%
# @title CODES
def find_pre_and_hyp(query):
    start_pre = query.find("[PRE]") + len("[PRE]")
    end_pre = query.find("[HYP]")
    start_hyp = query.find("[HYP]") + len("[HYP]")
    end_hyp = query.find("OUTPUT:")
    premise = query[start_pre:end_pre].strip()
    hypothesis = query[start_hyp:end_hyp].strip()

    return premise,hypothesis


class CustomDataset(Dataset):
    def __init__(self, x_list, y_list):
        self.samples = []
        for x,y in zip(x_list,y_list):
            #x_tensor = torch.tensor(x,dtype = torch.float32)
            y_tensor = torch.tensor(y,dtype = torch.float32)
            self.samples.append((x[0],x[1],y_tensor))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]


def get_lists(data):
    x_list = []
    y_list = []
    i =0
    for query,answer in zip(data['query'],data['answer']):
        i = i + 1
        if answer == 'entailment':
           y = [1,0,0]
        elif answer == 'neutral':
           y = [0,1,0]
        elif answer == 'contradiction':
           y = [0,0,1]
        else:
           print('should not get here')

        premise,hypothesis = find_pre_and_hyp(query)
        x_list.append((premise,hypothesis))
        y_list.append(y)
    return x_list,y_list


class embedding_layer(nn.Module):
  def __init__(self,bert_model,tokenizer):
    super(embedding_layer, self).__init__()
    self.bert_model = bert_model
    self.tokenizer = tokenizer

  def forward(self, x):
    with torch.no_grad():
         s = tokenizer(x,return_tensors="pt",padding=True).to(device)
         vec = bert_model(**s)['last_hidden_state'].to(device)
    return vec

class PositionalEncoding(nn.Module):
    def __init__(self, seq_len,embedding_size):
        super().__init__()
        self.dropout = nn.Dropout(0.1)
        self.embedding_size = embedding_size
        self.seq_len = seq_len

    def forward(self, x):
        pe = torch.zeros(x.size(0), x.size(1), self.embedding_size).to(device)
        div_term = torch.zeros(x.size(0), 1, self.embedding_size).to(device)
        ks = torch.arange(self.embedding_size).float().to(device)
        values = torch.exp(-torch.log(torch.tensor(1000.0)) * 2 * ks / self.embedding_size).to(device)
        values = values.view(1, 1, -1).to(device)
        div_term = div_term + values
        x = x.reshape([x.shape[0],x.shape[1],1]).to(device)
        pe[:, :, ::2] = torch.sin(x * div_term)[:, :, ::2].to(device)
        pe[:, :, 1::2] = torch.cos(x * div_term)[:, :, 1::2].to(device)
        return self.dropout(pe)

class MultiHeadAttention(nn.Module):
    def __init__(self, embedding_size, heads):
        super().__init__()
        self.embedding_size = embedding_size
        self.heads = heads
        self.head_dim = embedding_size // heads
        assert(self.heads * self.head_dim == self.embedding_size), "Invalid number of heads"
        self.fc_values = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_keys = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_queries = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_out = nn.Linear(heads * self.head_dim, embedding_size).to(device)

    def forward(self, values, keys, queries, mask):
        N = queries.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], queries.shape[1]
        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = queries.reshape(N, query_len, self.heads, self.head_dim)
        values = self.fc_values(values).to(device)
        keys = self.fc_keys(keys).to(device)
        queries = self.fc_queries(queries).to(device)
        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys]).to(device)
        if mask is not None:
            energy = energy.masked_fill(mask.to(device) == 0, float("-1e20")).to(device)
        energy = torch.softmax(energy / (self.embedding_size ** 0.5), dim=3).to(device)
        attention = torch.einsum("nhql,nlhd->nqhd", [energy, values]).to(device)
        attention = attention.reshape(N, query_len, self.heads * self.head_dim).to(device)
        out = self.fc_out(attention)
        return out

class TransformerBlock(nn.Module):
    def __init__(self, embedding_size, heads, forward_expansion, p):
        super().__init__()
        self.attention = MultiHeadAttention(embedding_size, heads)
        self.norm1 = nn.LayerNorm(embedding_size)
        self.feed_forward = nn.Sequential(nn.Linear(embedding_size, forward_expansion * embedding_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion * embedding_size, embedding_size))
        self.norm2 = nn.LayerNorm(embedding_size)
        self.dropout = nn.Dropout(p)
    def forward(self, values, keys, queries, mask):
        attention_out = self.attention(values, keys, queries, mask)
        x = self.norm1(attention_out + queries)
        x = self.dropout(x)
        ff_out = self.feed_forward(x)
        out = self.norm2(ff_out + x)
        out = self.dropout(out)
        return out

class Encoder(nn.Module):
    def __init__(self, src_vocab_size, embedding_size, num_layers, heads,
                 forward_expansion, max_length, p, device):
        super().__init__()
        self.device = device
        self.word_embedding = embedding_layer(bert_model,tokenizer)
        self.positional_embedding = PositionalEncoding(max_length, embedding_size)
        self.layers = nn.ModuleList([TransformerBlock(embedding_size, heads, forward_expansion, p) for _ in range(num_layers)])
        self.dropout = nn.Dropout(p)

    def forward(self, x, mask):
        mask = None
        pe = self.word_embedding(x)
        N = pe.size(0)
        seq_len = pe.size(1)
        positions = torch.arange(0, seq_len).expand(N, seq_len).to(self.device)
        out = self.dropout((pe + self.positional_embedding(positions)))
        for layer in self.layers:
            out = layer(out, out, out ,mask)
        return out


class Transformer(nn.Module):
    def __init__(self, src_vocab_size, src_pad_idx, embedding_size=768,
                 num_layers=1, forward_expansion=8, heads=8, max_length=100, p=0.1):
        super().__init__()
        self.src_pad_idx = src_pad_idx
        self.encoder = Encoder(src_vocab_size, embedding_size, num_layers, heads,
                               forward_expansion, max_length, p, device)

    def get_src_mask(self, src):
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2).to(device)
        return src_mask

    def forward(self, src):
        src_mask = None
        enc_out = self.encoder(src, src_mask).to(device)
        return enc_out


class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.transformer1 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.transformer2 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.fc1 = nn.Linear(768*2, 256).to(device)
        self.fc2 = nn.Linear(256, 3).to(device)

    def forward(self, x_pre,x_hyp):
        out1 = self.transformer1(x_pre)
        out2 = self.transformer2(x_hyp)
        out1 = torch.mean(out1,1)
        out2 = torch.mean(out2,1)
        x = torch.cat((out1,out2),1)
        x = F.relu(self.fc1(self.dropout1(x)))
        x = nn.functional.softmax(self.fc2(self.dropout2(x)),dim=1)
        return x

def get_model_acc(model,data_loader):
    #model.eval()
    #with torch.no_grad():
    predictions = []
    true_labels = []
    for x_pre, x_hyp, y in data_loader:
             outputs = model(x_pre,x_hyp)
             predicted_labels = torch.argmax(outputs, dim=1).cpu().numpy()
             predictions.extend(predicted_labels)
             l1 = torch.argmax(y, dim=1).cpu().numpy()
             true_labels.extend(l1)
    #model.train()
    return accuracy_score(true_labels, predictions)


def get_inf_from_num(num):
    if num == 0:
       return 'entailment'
    elif num == 1:
       return 'neutral'
    elif num == 2:
       return 'contradiction'

class NNN(nn.Module):
    def __init__(self):
        super(NNN, self).__init__()
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.transformer1 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.transformer2 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.fc1 = nn.Linear(768*2, 256).to(device)
        self.fc2 = nn.Linear(256, 2).to(device)

    def forward(self, x_pre,x_hyp):
        out1 = self.transformer1(x_pre)
        out2 = self.transformer2(x_hyp)
        out1 = torch.mean(out1,1)
        out2 = torch.mean(out2,1)
        x = torch.cat((out1,out2),1)
        x = F.relu(self.fc1(self.dropout1(x)))
        x = nn.functional.softmax(self.fc2(self.dropout2(x)),dim=1)
        return x

def get_inference_from_tns(tns):
    infr = np.argmax(tns.cpu().detach().numpy())
    if infr == 0:
       return 'entailment'
    elif infr == 1:
       return 'neutral'
    elif infr == 2:
       return 'contradiction'
    else:
       return 'shouldnt get here'


def get_trustworthy_from_tns(tns):
    infr = np.argmax(tns.cpu().detach().numpy())
    if infr == 0:
       return 'trustworthy'
    elif infr == 1:
       return 'untrustworthy'
    else:
       return 'shouldnt get here'

def get_trust_untrust_dataset(trustmodel,data_loader):
    trustmodel.eval()
    model.eval()
    trust_x_list = []
    untrust_x_list = []
    trust_y_list = []
    untrust_y_list = []
    for x_pre,x_hyp,y in data_loader:
        outputs = model(x_pre,x_hyp)
        outputs_tw = trustmodel(x_pre,x_hyp)
        y = y.to(device)
        for i in range(len(outputs)):
                 p = get_inference_from_tns(outputs[i])
                 t = get_inference_from_tns(y[i])
                 tw = get_trustworthy_from_tns(outputs_tw[i])
                 if tw == 'trustworthy':
                    trust_x_list.append((x_pre[i],x_hyp[i]))
                    trust_y_list.append(y[i].tolist())
                 elif tw == 'untrustworthy':
                    untrust_x_list.append((x_pre[i],x_hyp[i]))
                    untrust_y_list.append(y[i].tolist())
                 else:
                    print('shouldnt get here')
    trust_dataset = CustomDataset(trust_x_list,trust_y_list)
    untrust_dataset = CustomDataset(untrust_x_list,untrust_y_list)
    trust_data_loader = torch.utils.data.DataLoader(trust_dataset, batch_size=32, shuffle=True)
    untrust_data_loader = torch.utils.data.DataLoader(untrust_dataset, batch_size=32, shuffle=True)
    #print('trust num: ' + str(len(trust_y_list)))
    #print('untrust num: ' + str(len(untrust_y_list)))
    #print('trust acc: ' + str(get_model_acc(model,trust_data_loader)))
    #print('untrust acc: ' + str(get_model_acc(model,untrust_data_loader)))
    return trust_dataset,untrust_dataset

# %%
test_data = pd.read_parquet('MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet', engine='fastparquet')
train_data = pd.read_parquet('MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet', engine='fastparquet')
valid_data = pd.read_parquet('MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet', engine='fastparquet')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("gsarti/biobert-nli")
bert_model = AutoModel.from_pretrained("gsarti/biobert-nli").to(device)
src_pad_idx = 0
src_vocab_size = bert_model.config.vocab_size
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
train_x_list,train_y_list = get_lists(train_data)
test_x_list,test_y_list = get_lists(test_data)
val_x_list,val_y_list = get_lists(valid_data)

# %%
train_dataset = CustomDataset(train_x_list,train_y_list)
test_dataset = CustomDataset(test_x_list,test_y_list)
val_dataset = CustomDataset(val_x_list,val_y_list)

# %%
bsize = 32
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=bsize, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=bsize, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %%
with torch.no_grad():
     model = torch.load('modelw.pth')
     newmodel = torch.load('TrustModelw5.pth')
     print(get_model_acc(model,test_loader))
# Out:
# 0.7334739803094233

# %%
w2v = Word2Vec.load('w2v_OA_CR_100d.bin')

# %%
stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
def extract_svo_rest(sentence):
    doc = nlp(sentence)
    subject = None
    verb = None
    rest_of_sentence = None

    for sent in doc.sentences:
        for word in sent.words:
            # Check for subject
            if 'subj' in word.deprel:
                subject = word.text
            # Check for verb
            if word.deprel == 'root':
                verb = word.text

        # Create the rest of the sentence by excluding the subject and verb
        rest_of_sentence = ' '.join([word.text for word in sent.words if word.text != subject and word.text != verb])

    return subject, verb, rest_of_sentence

# Function to process multiple sentences
def get_svos(text):
    sentences = text.split('. ')
    svo_results = []

    for sentence in sentences:
        # Strip any leading/trailing whitespace and check if sentence is not empty
        sentence = sentence.strip()
        if sentence:  # Avoid processing empty strings
            subject, verb, rest_of_sentence = extract_svo_rest(sentence)
            svo_results.append((sentence, subject, verb, rest_of_sentence))

    return svo_results
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading these customized packages for language: en (English)...
# ====================================
# | Processor       | Package        |
# ------------------------------------
# | tokenize        | mimic          |
# | pos             | mimic_charlm   |
# | lemma           | mimic_nocharlm |
# | depparse        | mimic_charlm   |
# | ner             | i2b2           |
# | forward_charlm  | mimic          |
# | pretrain        | mimic          |
# | backward_charlm | mimic          |
# ====================================
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/tokenize/mimic.pt:   0%|       …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/tokenize/mimic.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/pos/mimic_charlm.pt:   0%|     …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/pos/mimic_charlm.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/lemma/mimic_nocharlm.pt:   0%| …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/lemma/mimic_nocharlm.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/depparse/mimic_charlm.pt:   0%|…
# INFO:stanza:Downloaded file to /root/stanza_resources/en/depparse/mimic_charlm.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/ner/i2b2.pt:   0%|          | 0…
# INFO:stanza:Downloaded file to /root/stanza_resources/en/ner/i2b2.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/forward_charlm/mimic.pt:   0%| …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/forward_charlm/mimic.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/pretrain/mimic.pt:   0%|       …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/pretrain/mimic.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/backward_charlm/mimic.pt:   0%|…
# INFO:stanza:Downloaded file to /root/stanza_resources/en/backward_charlm/mimic.pt
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# ==============================
# | Processor | Package        |
# ------------------------------
# | tokenize  | mimic          |
# | pos       | mimic_charlm   |
# | lemma     | mimic_nocharlm |
# | depparse  | mimic_charlm   |
# | ner       | i2b2           |
# ==============================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
def get_cos_similarity(prem,hypt):
    try:
      a = w2v.wv.get_vector(prem)
      b = w2v.wv.get_vector(hypt)
      return (a@b)/(norm(a)*norm(b))
    except:
      return 0

# %%
def deabbreviation(text):
    try:
       return medialpy.find(text).meaning[0]
    except:
       return text

# %%
def preprocess_text(text):
    text = contractions.fix(text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    ntokens = []
    for token in tokens:
        ntokens.append(deabbreviation(token).lower())
    stop_words = set(stopwords.words('english'))
    stop_words.remove('no')
    stop_words.remove('not')
    filtered_tokens = [word for word in ntokens if word not in stop_words]
    processed_text = ' '.join(filtered_tokens)
    return processed_text

# %%
def check_subject_verb_match(prem_svos,hypt_svos):
    r = False
    for prems, psubjects, pverbs, prests in prem_svos:
        for hypts, hsubjects, hverbs, hrests in hypt_svos:
            if psubjects == hsubjects and pverbs == hverbs:
               r = True
    return r

# %%
def check_subject_match(prem_svos,hypt_svos):
    r = False
    for prems, psubjects, pverbs, prests in prem_svos:
        for hypts, hsubjects, hverbs, hrests in hypt_svos:
            if psubjects == hsubjects:
               r = True
    return r

# %%
def similarity(prem,hypt):
    count = 0
    l = len(word_tokenize(prem)) if len(word_tokenize(prem)) < len(word_tokenize(hypt)) else len(word_tokenize(hypt))
    for hypword in hypt.split():
        for preword in prem.split():
                    if get_cos_similarity(hypword,preword)>=0.8:
                       count +=1
    return count/l

# %%
def get_hybrid_answer(prem,hypt,dp_answer,sim_score):
    if sim_score > 0.66:
      if (detect_negation(prem) and not detect_negation(hypt)) or (not detect_negation(prem) and detect_negation(hypt)):
          return 'contradiction'
      else:
          return 'entailment'
    else:
      print('default')
      return dp_answer

# %%
def get_reliability_from_num(num):
    if num == 0:
       return 'reliable'
    elif num == 1:
       return 'unreliable'
    else:
       return None

# %%
def detect_negation(sentence):
    sentence = contractions.fix(sentence)
    doc = nlp(sentence)
    negations = []
    r = False
    for sentence in doc.sentences:
        for word in sentence.words:
            if (word.text.lower() == "not" or word.text.lower() == "no" or word.text.lower() == "never" or word.text.lower() == "non") and word.head > 0:
                head_word = sentence.words[word.head - 1]
                negations.append(head_word.text)
                r = True
    return r

# %%
def print_inf(count,wrong_label,corrected_label,uncorrected_label,prem,hypt,hy_answer,dp_answer,ground_truth):
    print('num: '+str(count))
    print('wrong label: '+str(wrong_label))
    print('corrected label: '+str(corrected_label))
    print('uncorrected label: '+str(uncorrected_label))
    print('premise: '+prem)
    print('hypothesis: '+hypt)
    print('hy: '+ hy_answer)
    print('dp: '+ dp_answer)
    print('ground_truth: '+ ground_truth)
    print('=====================================================================================================')

# %%
model.eval()
newmodel.eval()
count = 0
wrong_label = 0
corrected_label = 0
uncorrected_label = 0
for x_pre,x_hyp,y in test_loader:
  for i in range(len(x_pre)):
      with torch.no_grad():
          dp_answer = get_inf_from_num(np.argmax(model(x_pre[i],x_hyp[i]).cpu().detach().numpy()))
          ground_truth = get_inf_from_num(np.argmax(y[i].cpu().detach().numpy()))
          dp_trust = get_reliability_from_num(np.argmax(newmodel(x_pre[i],x_hyp[i]).cpu().detach().numpy()))
      if dp_trust == 'unreliable':
          prem = x_pre[i]
          hypt = x_hyp[i]
          prem_svos = get_svos(prem)
          hypt_svos = get_svos(hypt)

          if check_subject_verb_match(prem_svos,hypt_svos):
             pass
             #sim_score = similarity(preprocess_text(prem),preprocess_text(hypt))
             #hy_answer = get_hybrid_answer(prem,hypt,dp_answer,sim_score)
             #count +=1
             #if ground_truth != dp_answer:
                #wrong_label += 1
             #if ground_truth != dp_answer and hy_answer == ground_truth:
                #corrected_label += 1
             #if ground_truth == dp_answer and hy_answer != ground_truth:
                #uncorrected_label += 1
             #print_inf(count,wrong_label,corrected_label,uncorrected_label,prem,hypt,hy_answer,dp_answer,ground_truth)

          elif check_subject_match(prem_svos,hypt_svos):
             sim_score = similarity(preprocess_text(prem),preprocess_text(hypt))
             hy_answer = get_hybrid_answer(prem,hypt,dp_answer,sim_score)
             count +=1
             if ground_truth != dp_answer:
                wrong_label += 1
             if ground_truth != dp_answer and hy_answer == ground_truth:
                corrected_label += 1
             if ground_truth == dp_answer and hy_answer != ground_truth:
                uncorrected_label += 1
             print_inf(count,wrong_label,corrected_label,uncorrected_label,prem,hypt,hy_answer,dp_answer,ground_truth)
# Out:
# default
# num: 1
# wrong label: 0
# corrected label: 0
# uncorrected label: 0
# premise: He denied headache or nausea or vomiting.
# hypothesis: He has no head pain
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 2
# wrong label: 1
# corrected label: 0
# uncorrected label: 0
# premise: He denied headache or nausea or vomiting.
# hypothesis: He is afebrile
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# default
# num: 3
# wrong label: 1
# corrected label: 0
# uncorrected label: 0
# premise: He was initially reluctant to undergo surgery but has had increasing amounts of chest pain episodes.
# hypothesis: He has coronary artery disease
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 4
# wrong label: 2
# corrected label: 0
# uncorrected label: 0
# premise: He was also given lasix 80mg IV x1 with diuresis of 1800cc.
# hypothesis: He was volume depleted
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 5
# wrong label: 2
# corrected label: 0
# uncorrected label: 0
# premise: He was also given lasix 80mg IV x1 with diuresis of 1800cc.
# hypothesis: He has congestive heart failure
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 6
# wrong label: 2
# corrected label: 0
# uncorrected label: 0
# premise: The patient also reports continued fever and an unusual amount of fatigue.
# hypothesis: The patient has been feeling ill
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 7
# wrong label: 2
# corrected label: 0
# uncorrected label: 0
# premise: The patient also reports continued fever and an unusual amount of fatigue.
# hypothesis: The patient has influenza
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 8
# wrong label: 2
# corrected label: 0
# uncorrected label: 0
# premise: He was then transferred to [**Hospital3 **] for further evaluation.
# hypothesis: He complains of abdominal pain
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# num: 9
# wrong label: 3
# corrected label: 0
# uncorrected label: 0
# premise: The patient was extubated this morning.
# hypothesis: the patient is intubated
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# num: 10
# wrong label: 4
# corrected label: 1
# uncorrected label: 0
# premise: This twin emerged with a spontaneous cry and required only routine care and blow-by oxygen in the OR.
# hypothesis: This twin received standard care in the OR
# hy: entailment
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# num: 11
# wrong label: 5
# corrected label: 1
# uncorrected label: 0
# premise: This twin emerged with a spontaneous cry and required only routine care and blow-by oxygen in the OR.
# hypothesis: This twin required resuscitation
# hy: entailment
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# num: 12
# wrong label: 6
# corrected label: 2
# uncorrected label: 0
# premise: HISTORY: Multi[** Location **]jections status post MVA with shoulder pain, evaluate shoulder injury.
# hypothesis: Shoulder pain after motor vehicle accident
# hy: entailment
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# default
# num: 13
# wrong label: 6
# corrected label: 2
# uncorrected label: 0
# premise: The patient was brought to the outside hospital where EKG noted the patient had new wide left bundle branch block morphology.
# hypothesis: The patient has EKG changes consistent with acute myocardial infarction.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 14
# wrong label: 6
# corrected label: 2
# uncorrected label: 0
# premise: The patient was brought to the outside hospital where EKG noted the patient had new wide left bundle branch block morphology.
# hypothesis: The patient has a history of coronary artery disease.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 15
# wrong label: 6
# corrected label: 2
# uncorrected label: 0
# premise: She was treated with nebs and PO prednisone and apparently appeared well.
# hypothesis: She had dyspnea and cough
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 16
# wrong label: 6
# corrected label: 2
# uncorrected label: 0
# premise: (Lactate only 1.3 and pt afebrile).  .
# hypothesis: Elevated temperature
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 17
# wrong label: 6
# corrected label: 2
# uncorrected label: 0
# premise: Magnesium sulfate was discontinued and mother had further bleeding and concern for abruption.
# hypothesis: The mother had recent abdominal trauma
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 18
# wrong label: 6
# corrected label: 2
# uncorrected label: 0
# premise: She was eventually found to have multiple problems including pericardial effusion, cardiac tamponade, a small pleural effusion, swollen knee with a joint effusion and joint pain.
# hypothesis: She has an abnormal chest X-ray
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 19
# wrong label: 6
# corrected label: 2
# uncorrected label: 0
# premise: She was eventually found to have multiple problems including pericardial effusion, cardiac tamponade, a small pleural effusion, swollen knee with a joint effusion and joint pain.
# hypothesis: She has arthritis
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 20
# wrong label: 7
# corrected label: 2
# uncorrected label: 0
# premise: She had one episode of nausea/NBNB vomiting the day PTA.
# hypothesis: She complains of weakness
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# num: 21
# wrong label: 7
# corrected label: 2
# uncorrected label: 1
# premise: Abdomen was soft, nontender, non distended.
# hypothesis: Abdomen was tender to palpation
# hy: entailment
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 22
# wrong label: 7
# corrected label: 2
# uncorrected label: 1
# premise: OB History:  G5, P1-0-4-1.
# hypothesis: the patient elective abortions
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# num: 23
# wrong label: 7
# corrected label: 2
# uncorrected label: 1
# premise: Chest pain occurred again on the day of admission while walking from the shuttle to [**Hospital6 1900**].
# hypothesis: There was chest pain with activity
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 24
# wrong label: 7
# corrected label: 2
# uncorrected label: 1
# premise: Congestive heart failure.
# hypothesis: Heart disease
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 25
# wrong label: 7
# corrected label: 2
# uncorrected label: 1
# premise: Congestive heart failure.
# hypothesis: Normal cardiac function
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 26
# wrong label: 7
# corrected label: 2
# uncorrected label: 1
# premise: Congestive heart failure.
# hypothesis: Edema and cough
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 27
# wrong label: 7
# corrected label: 2
# uncorrected label: 1
# premise: Mild mitral regurgitation.
# hypothesis: Cardiac valve dysfunction
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 28
# wrong label: 8
# corrected label: 2
# uncorrected label: 1
# premise: Mild mitral regurgitation.
# hypothesis: Normal cardiac function
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 29
# wrong label: 8
# corrected label: 2
# uncorrected label: 1
# premise: Mild mitral regurgitation.
# hypothesis: Heart murmur
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 30
# wrong label: 8
# corrected label: 2
# uncorrected label: 1
# premise: She recovered consciousness once the medics arrived.
# hypothesis: She remained unconscious once medics arrived
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 31
# wrong label: 8
# corrected label: 2
# uncorrected label: 1
# premise: The patient denied headache, numbness, tingling, or double vision.
# hypothesis: The patient had loss of sensation in the extremities
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# num: 32
# wrong label: 9
# corrected label: 3
# uncorrected label: 1
# premise: 25.Chronic atrial fibrillation - The patient is not on anticoagulation for this.
# hypothesis: the patient is not anticoagulated
# hy: entailment
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# default
# num: 33
# wrong label: 10
# corrected label: 3
# uncorrected label: 1
# premise: 25.Chronic atrial fibrillation - The patient is not on anticoagulation for this.
# hypothesis: the patient is anticoagulated
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 34
# wrong label: 10
# corrected label: 3
# uncorrected label: 1
# premise: In the ED, the patient was treated with ASA 325mg, 80mg IV lasix, O2, NTG gtt and was started on non-invasive ventilation, with reported resolution of pain.
# hypothesis: The patient received the treatment used for a CHF exacerbation.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 35
# wrong label: 10
# corrected label: 3
# uncorrected label: 1
# premise: In the ED, the patient was treated with ASA 325mg, 80mg IV lasix, O2, NTG gtt and was started on non-invasive ventilation, with reported resolution of pain.
# hypothesis: The patient has congestive heart failure.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 36
# wrong label: 11
# corrected label: 3
# uncorrected label: 1
# premise: Severe hyperemesis requiring TPN.
# hypothesis: Mild vomiting treated with PO medication
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 37
# wrong label: 11
# corrected label: 3
# uncorrected label: 1
# premise: Non-insulin dependent-diabetes mellitus.
# hypothesis: No history of hyperglycemia
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 38
# wrong label: 11
# corrected label: 3
# uncorrected label: 1
# premise: The patient now presents with metastatic recurrence of squamous cell carcinoma of the right mandible with extensive lymph node involvement.
# hypothesis: The patient has a history of smoking.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# num: 39
# wrong label: 11
# corrected label: 3
# uncorrected label: 1
# premise: A bronchoscopy done on the next hospital day yielded scant secretions and the patient was started on meropenem and Vancomycin for presumed recurrent pneumonia.
# hypothesis: The patient has concern pneumonia.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 40
# wrong label: 11
# corrected label: 3
# uncorrected label: 1
# premise: A bronchoscopy done on the next hospital day yielded scant secretions and the patient was started on meropenem and Vancomycin for presumed recurrent pneumonia.
# hypothesis: The patient has clear lungs.
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 41
# wrong label: 11
# corrected label: 3
# uncorrected label: 1
# premise: The patient is a poor historian and unfortunately has few notes to confirm his medical history.
# hypothesis: The patient has a cognitive condition.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 42
# wrong label: 12
# corrected label: 3
# uncorrected label: 1
# premise: The patient is a poor historian and unfortunately has few notes to confirm his medical history.
# hypothesis: The patient has had multiple medical visits at the clinic.
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 43
# wrong label: 12
# corrected label: 3
# uncorrected label: 1
# premise: About three weeks ago, patient reported an episode of chest "pressure" and "aching" spreading like a band across his upper chest and throat and slight radiation to both upper arms.
# hypothesis: The patient had angina
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 44
# wrong label: 13
# corrected label: 3
# uncorrected label: 1
# premise: The patient denies alcohol use.
# hypothesis: The patient does not drink alcohol
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# num: 45
# wrong label: 13
# corrected label: 3
# uncorrected label: 2
# premise: The patient denies alcohol use.
# hypothesis: The patient abuses alcohol
# hy: entailment
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 46
# wrong label: 13
# corrected label: 3
# uncorrected label: 2
# premise: The patient denies alcohol use.
# hypothesis: The patient has no history of drug abuse
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 47
# wrong label: 13
# corrected label: 3
# uncorrected label: 2
# premise: Seizure disorder, in the setting of renal failure.
# hypothesis: kidney dysfunction
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 48
# wrong label: 14
# corrected label: 3
# uncorrected label: 2
# premise: The patient usually walks without any assistance.
# hypothesis: The patient is at baseline ambulatory
# hy: contradiction
# dp: contradiction
# ground_truth: entailment
# =====================================================================================================
# default
# num: 49
# wrong label: 15
# corrected label: 3
# uncorrected label: 2
# premise: The patient usually walks without any assistance.
# hypothesis: The patient is wheelchair-bound
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 50
# wrong label: 15
# corrected label: 3
# uncorrected label: 2
# premise: The patient usually walks without any assistance.
# hypothesis: The patient performs activities of daily living independently
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 51
# wrong label: 15
# corrected label: 3
# uncorrected label: 2
# premise: BPH w h/o obstruction requiring foley placement.
# hypothesis: Prostate enlargement
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 52
# wrong label: 16
# corrected label: 3
# uncorrected label: 2
# premise: BPH w h/o obstruction requiring foley placement.
# hypothesis: High levels of PSA
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# default
# num: 53
# wrong label: 16
# corrected label: 3
# uncorrected label: 2
# premise: He complained of SOB at the nursing home today and was found to be hypoxic to the 80s on RA, and satting 90% on 6L, was noted to have a bandemia on his WBC, and set to the ED. .
# hypothesis: He has a history of COPD
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 54
# wrong label: 16
# corrected label: 3
# uncorrected label: 2
# premise: He was restarted on lasix 40mg, with plans to have follow up labs drawn in 1 week.
# hypothesis: He has a history of renal disease
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 55
# wrong label: 16
# corrected label: 3
# uncorrected label: 2
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Arrhythmia
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 56
# wrong label: 16
# corrected label: 3
# uncorrected label: 2
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Arrhythmia
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 57
# wrong label: 16
# corrected label: 3
# uncorrected label: 2
# premise: Status post appendectomy 11.
# hypothesis: No surgical history
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# num: 58
# wrong label: 16
# corrected label: 3
# uncorrected label: 2
# premise: The patient recently started developing similar symptoms of chest pressure and discomfort at rest.
# hypothesis: The patient has recent chest pain
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# num: 59
# wrong label: 16
# corrected label: 3
# uncorrected label: 3
# premise: Several hours post intervention, patient complained of pain in LLE and was unable to move her foot.
# hypothesis: The patient had full movement in the left lower extremity.
# hy: entailment
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 60
# wrong label: 16
# corrected label: 3
# uncorrected label: 3
# premise: Several hours post intervention, patient complained of pain in LLE and was unable to move her foot.
# hypothesis: The patient had a recent stroke.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# num: 61
# wrong label: 16
# corrected label: 3
# uncorrected label: 3
# premise: Prior to the onset of symptoms, the patient was able to walk several blocks with minimal difficulty.
# hypothesis: Prior of the onset of symptoms, the patient had mobility
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 62
# wrong label: 16
# corrected label: 3
# uncorrected label: 3
# premise: She has been on hemodialysis since [**3048-1-29**], after failure of her second kidney transplant.
# hypothesis: She is diabetic
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# num: 63
# wrong label: 16
# corrected label: 3
# uncorrected label: 4
# premise: Congestive heart failure, apparently diastolic dysfunction with a normal ejection fraction.
# hypothesis: Normal heart function
# hy: entailment
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 64
# wrong label: 16
# corrected label: 3
# uncorrected label: 4
# premise: Congestive heart failure, apparently diastolic dysfunction with a normal ejection fraction.
# hypothesis: History of hypertension and myocardial infarction
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 65
# wrong label: 17
# corrected label: 3
# uncorrected label: 4
# premise: Though he was DNR/DNI, pt's son asked to have pt intubated overnight. found to be oozing fluid from various sites in CXR without infiltrate, U/A clean.
# hypothesis: Urinary tract infection found on lab analysis
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 66
# wrong label: 17
# corrected label: 3
# uncorrected label: 4
# premise: Postoperative day #9 the patient remained afebrile with a heart rate of 63 and sinus rhythm, respirations 18, satting at 96% on 3 liters, blood pressure 122/70.
# hypothesis: The patient is post op
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 67
# wrong label: 18
# corrected label: 3
# uncorrected label: 4
# premise: Postoperative day #9 the patient remained afebrile with a heart rate of 63 and sinus rhythm, respirations 18, satting at 96% on 3 liters, blood pressure 122/70.
# hypothesis: The patient has a well healing wound
# hy: contradiction
# dp: contradiction
# ground_truth: neutral
# =====================================================================================================
# default
# num: 68
# wrong label: 18
# corrected label: 3
# uncorrected label: 4
# premise: The patient was recently at NYP hoslpital in NY 2d prior to presentation as part of a preoperative evaltion for a Whipple.
# hypothesis: The patient is to undergo surgery.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 69
# wrong label: 19
# corrected label: 3
# uncorrected label: 4
# premise: The patient was recently at NYP hoslpital in NY 2d prior to presentation as part of a preoperative evaltion for a Whipple.
# hypothesis: The patient has a pancreatic mass.
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# default
# num: 70
# wrong label: 19
# corrected label: 3
# uncorrected label: 4
# premise: The patient awoke on the day of presentation with acute shortness of breath.
# hypothesis: The patient had sudden onset of difficulty breathing
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 71
# wrong label: 19
# corrected label: 3
# uncorrected label: 4
# premise: The patient awoke on the day of presentation with acute shortness of breath.
# hypothesis: The patient had no difficulty breathing
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 72
# wrong label: 19
# corrected label: 3
# uncorrected label: 4
# premise: The patient awoke on the day of presentation with acute shortness of breath.
# hypothesis: The patient has a history of DVT
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# num: 73
# wrong label: 19
# corrected label: 3
# uncorrected label: 4
# premise: The patient awoke on the day of presentation with acute shortness of breath.
# hypothesis: the patient has shortness of breath
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# num: 74
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: The patient awoke on the day of presentation with acute shortness of breath.
# hypothesis: the patient denies shortness of breath
# hy: entailment
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 75
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: The patient awoke on the day of presentation with acute shortness of breath.
# hypothesis: the patient has a PE
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 76
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: The patient reports having reactive airway disease.
# hypothesis: The patient has COPD and/or atshma.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 77
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: The patient reports having reactive airway disease.
# hypothesis: The patient has normal pulmonary function.
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 78
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: The patient reports having reactive airway disease.
# hypothesis: The patient uses an inhaler.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 79
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: Upon most recent discharge, patient was discharged to [**Hospital1 5908**] rehab.
# hypothesis: The patient requires no follow-up care
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 80
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: She was not experiencing hematemasis.
# hypothesis: She was not vomiting blood
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# num: 81
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: The patient remained hemodynamically stable and was admitted for further workup.
# hypothesis: the patient has hemodynamically stable
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 82
# wrong label: 19
# corrected label: 3
# uncorrected label: 5
# premise: The patient remained hemodynamically stable and was admitted for further workup.
# hypothesis: the patient is hypotensive
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 83
# wrong label: 20
# corrected label: 3
# uncorrected label: 5
# premise: The patient remained hemodynamically stable and was admitted for further workup.
# hypothesis: the patient denies pain
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# default
# num: 84
# wrong label: 20
# corrected label: 3
# uncorrected label: 5
# premise: She was volume resusciatated with 4 Units PRBCs and 3 liters of NS.
# hypothesis: She was treated for volume depletion
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 85
# wrong label: 21
# corrected label: 3
# uncorrected label: 5
# premise: She was volume resusciatated with 4 Units PRBCs and 3 liters of NS.
# hypothesis: She is hypotensive
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# num: 86
# wrong label: 22
# corrected label: 4
# uncorrected label: 5
# premise: The mother has no sign or symptom of labor, no rupture of the membranes or contractions prior to C-section.
# hypothesis: The mother was in labor
# hy: contradiction
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 87
# wrong label: 22
# corrected label: 4
# uncorrected label: 5
# premise: The patient is now extubated and off sedation and provided further details.
# hypothesis: The patient previously required respiratory support.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# num: 88
# wrong label: 22
# corrected label: 4
# uncorrected label: 6
# premise: The patient is now extubated and off sedation and provided further details.
# hypothesis: The patient has never been intubated.
# hy: entailment
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 89
# wrong label: 22
# corrected label: 4
# uncorrected label: 6
# premise: The patient is now extubated and off sedation and provided further details.
# hypothesis: The patient had a trauma.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 90
# wrong label: 23
# corrected label: 4
# uncorrected label: 6
# premise: The patient stopped intravenous fluids and got 10 mg of intravenous Lasix times three and put out 500 cc of urine output.
# hypothesis: The patient received too much fluid.
# hy: contradiction
# dp: contradiction
# ground_truth: neutral
# =====================================================================================================
# default
# num: 91
# wrong label: 24
# corrected label: 4
# uncorrected label: 6
# premise: Denies head trauma.
# hypothesis: History of concussions
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 92
# wrong label: 24
# corrected label: 4
# uncorrected label: 6
# premise: On ROS, patient reports c/o N and V x couple times over the past couple days (w/o blood). + chills at HD.
# hypothesis: The patient has been vomiting
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 93
# wrong label: 25
# corrected label: 4
# uncorrected label: 6
# premise: On ROS, patient reports c/o N and V x couple times over the past couple days (w/o blood). + chills at HD.
# hypothesis: The patient has an elevated temperature
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# default
# num: 94
# wrong label: 25
# corrected label: 4
# uncorrected label: 6
# premise: #NAME?
# hypothesis: Reports feeling sensation of irregular heartbeats
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 95
# wrong label: 25
# corrected label: 4
# uncorrected label: 6
# premise: #NAME?
# hypothesis: No complaints of irregular heartbeat
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# default
# num: 96
# wrong label: 25
# corrected label: 4
# uncorrected label: 6
# premise: The patient was sent to the HD unit prior to coming to the floor for workup of fever.
# hypothesis: The patient has elevated temperature
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 97
# wrong label: 25
# corrected label: 4
# uncorrected label: 6
# premise: The patient was sent to the HD unit prior to coming to the floor for workup of fever.
# hypothesis: The patient has an infection
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# default
# num: 98
# wrong label: 25
# corrected label: 4
# uncorrected label: 6
# premise: He denies recent fevers, chills or rigors.
# hypothesis: He is afebrile
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# num: 99
# wrong label: 25
# corrected label: 4
# uncorrected label: 6
# premise: Of note, patient does c/o progressive shortness of breath over the past year.
# hypothesis: The patient experiences dyspnea
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# default
# num: 100
# wrong label: 26
# corrected label: 4
# uncorrected label: 6
# premise: During that admission the patient became volume overloaded and was admitted to the MICU for initiation of HD.
# hypothesis: The patient is volume overloaded and in acute renal failure.
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# default
# num: 101
# wrong label: 26
# corrected label: 4
# uncorrected label: 6
# premise: During that admission the patient became volume overloaded and was admitted to the MICU for initiation of HD.
# hypothesis: The patient has congestive heart failure.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================

# %%
torch.save(model,'modelg.pth')

# %%
source_file_path = "modelg.pth"
destination_folder = "/content/drive/My Drive/modelg.pth"
shutil.copy(source_file_path, destination_folder)
# Out:
# '/content/drive/My Drive/modelg.pth'
