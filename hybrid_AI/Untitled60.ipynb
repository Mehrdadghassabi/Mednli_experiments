# %%
# !pip install fasttext
# !pip install fastparquet
# !gdown --id '1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM'
# !gdown --id '1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp'
# !gdown --id '1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN'
# !unzip MedNLI_dataset.zip
# !pip install stanza
# !pip install medialpy
# !pip install contractions
# !wget https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin
# !wget https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin.wv.vectors.npy
# !wget https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin.trainables.syn1neg.npy
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (71.0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.26.4)
# Using cached pybind11-2.13.1-py3-none-any.whl (238 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4246766 sha256=fc0458b508c76f8c9cd386ee949b665c0ad45e69c47d97ca85e9ef40456aba7f
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.1
# Collecting fastparquet
#   Downloading fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fastparquet) (1.26.4)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastparquet) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Downloading fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.6 MB/s eta 0:00:00
# Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.5 MB/s eta 0:00:00
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.8.3 fastparquet-2024.5.0
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM
# From (redirected): https://drive.google.com/uc?id=1-2oxSCi9q_iIGHt2JP80dhXL0I4bPoiM&confirm=t&uuid=030fa211-1f67-4966-9423-912107a570ef
# To: /content/modelw.pth
# 100% 516M/516M [00:12<00:00, 40.0MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1cAthveg1d3MjrKJtMKGzfX3eH8HJ-dQp
# To: /content/MedNLI_dataset.zip
# 100% 681k/681k [00:00<00:00, 109MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN
# From (redirected): https://drive.google.com/uc?id=1-3NwGAk6MW4qDpZnxgIoAzMzFHUazkfN&confirm=t&uuid=6ecde3dc-0aec-4a62-bdad-f7e9a95152f4
# To: /content/TrustModelw5.pth
# 100% 516M/516M [00:07<00:00, 69.7MB/s]
# Archive:  MedNLI_dataset.zip
#    creating: MedNLI_dataset/
#   inflating: MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet
#   inflating: MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet
#   inflating: MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet
# Collecting stanza
#   Downloading stanza-1.8.2-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.26.4)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.3.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.3.0->stanza)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Downloading stanza-1.8.2-py3-none-any.whl (990 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.1/990.1 kB 45.4 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 683.8 kB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 79.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
# Successfully installed emoji-2.12.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 stanza-1.8.2
# Collecting medialpy
#   Downloading medialpy-0.0.4-py3-none-any.whl.metadata (2.6 kB)
# Downloading medialpy-0.0.4-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: medialpy
# Successfully installed medialpy-0.0.4
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (13 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 19.8 MB/s eta 0:00:00
# Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 11.3 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24
# --2024-08-02 22:48:44--  https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin
# Resolving huggingface.co (huggingface.co)... 13.33.30.23, 13.33.30.49, 13.33.30.114, ...
# Connecting to huggingface.co (huggingface.co)|13.33.30.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/7f920b29a2c3861a475f296d397ff679528b064dbb51debf33568ae5f4f7e088?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin%3B+filename%3D%22w2v_OA_CR_100d.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1722898124&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=iAbiyHZABFQEQhPY7Xaq99f1m%7E1LREqsuE-BbTVp2mkU6AzrQu5Hw-XYtSZoobmbr%7EXesRPXykg6CBtPy0CkQylmUi8eNt-HyTqrud3Rungg6qnmhqKLQ7ErfC1XfCEpdViHrA00apZDoCsEjgLxHLDSuuc8g31Ro888A1SpBNzTbhLNDI5TvfROj28d2Mc86T5N5xvOv7iyNVI-o%7EXrptdoYeoXk5cGUmTukK7cO2qSLev4ZbHYVuzFEB8JJAjAfJkqHuGBxaXqHDe3yb3jOl8r0A9R0JbDn03w9cDMRs-tZGW14CPjAOQSIf1m9RjUWYW89SnwvSIGqu-IT-mPPA__&Key-Pair-Id=K3ESJI6DHPFC7 [following]
# --2024-08-02 22:48:44--  https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/7f920b29a2c3861a475f296d397ff679528b064dbb51debf33568ae5f4f7e088?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin%3B+filename%3D%22w2v_OA_CR_100d.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1722898124&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=iAbiyHZABFQEQhPY7Xaq99f1m%7E1LREqsuE-BbTVp2mkU6AzrQu5Hw-XYtSZoobmbr%7EXesRPXykg6CBtPy0CkQylmUi8eNt-HyTqrud3Rungg6qnmhqKLQ7ErfC1XfCEpdViHrA00apZDoCsEjgLxHLDSuuc8g31Ro888A1SpBNzTbhLNDI5TvfROj28d2Mc86T5N5xvOv7iyNVI-o%7EXrptdoYeoXk5cGUmTukK7cO2qSLev4ZbHYVuzFEB8JJAjAfJkqHuGBxaXqHDe3yb3jOl8r0A9R0JbDn03w9cDMRs-tZGW14CPjAOQSIf1m9RjUWYW89SnwvSIGqu-IT-mPPA__&Key-Pair-Id=K3ESJI6DHPFC7
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.161.180.68, 18.161.180.7, 18.161.180.53, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.161.180.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24237857 (23M) [application/octet-stream]
# Saving to: ‘w2v_OA_CR_100d.bin’
#
# w2v_OA_CR_100d.bin  100%[===================>]  23.11M   104MB/s    in 0.2s
#
# 2024-08-02 22:48:45 (104 MB/s) - ‘w2v_OA_CR_100d.bin’ saved [24237857/24237857]
#
# --2024-08-02 22:48:45--  https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin.wv.vectors.npy
# Resolving huggingface.co (huggingface.co)... 18.67.181.126, 18.67.181.124, 18.67.181.100, ...
# Connecting to huggingface.co (huggingface.co)|18.67.181.126|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/72926d774155dfaef4763802927a53fa6315afc5ada32b5c797c4c8db9066bf4?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin.wv.vectors.npy%3B+filename%3D%22w2v_OA_CR_100d.bin.wv.vectors.npy%22%3B&Expires=1722898125&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=ZncqOuRa%7ETzbbJepGZJzzPixyovFJihwa6FveEkRn%7EzBcdvHG0Vih478XuL7FVnk3-xj7WruCOANarwOCQ4pwF%7E9U-ztskLtlrQdP7QMffRWeeovSRIWTS6UXJYO-J7B7FM3SNLc4ytgraVho7eGZfL9-y5bYa%7EHDm8YSsPvpu87BOX41YXYLgm79UDX3g3uAINvhK-AiAKPUdzMwCvCiuwA1TLmxkORBdAvScuSNm6e%7Ep2B8HXQBGc6MWHjx8bH%7EK9L8FzfXrwycsHaIkjcHeSUTQGUeVG%7EG5mPv0owryMs9MC14ndEdWSfNTd6%7EvKXGql9Ht2FR0oBUbKKsn0haA__&Key-Pair-Id=K3ESJI6DHPFC7 [following]
# --2024-08-02 22:48:45--  https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/72926d774155dfaef4763802927a53fa6315afc5ada32b5c797c4c8db9066bf4?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin.wv.vectors.npy%3B+filename%3D%22w2v_OA_CR_100d.bin.wv.vectors.npy%22%3B&Expires=1722898125&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=ZncqOuRa%7ETzbbJepGZJzzPixyovFJihwa6FveEkRn%7EzBcdvHG0Vih478XuL7FVnk3-xj7WruCOANarwOCQ4pwF%7E9U-ztskLtlrQdP7QMffRWeeovSRIWTS6UXJYO-J7B7FM3SNLc4ytgraVho7eGZfL9-y5bYa%7EHDm8YSsPvpu87BOX41YXYLgm79UDX3g3uAINvhK-AiAKPUdzMwCvCiuwA1TLmxkORBdAvScuSNm6e%7Ep2B8HXQBGc6MWHjx8bH%7EK9L8FzfXrwycsHaIkjcHeSUTQGUeVG%7EG5mPv0owryMs9MC14ndEdWSfNTd6%7EvKXGql9Ht2FR0oBUbKKsn0haA__&Key-Pair-Id=K3ESJI6DHPFC7
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.156.133.103, 108.156.133.109, 108.156.133.68, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.156.133.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133344128 (127M) [binary/octet-stream]
# Saving to: ‘w2v_OA_CR_100d.bin.wv.vectors.npy’
#
# w2v_OA_CR_100d.bin. 100%[===================>] 127.17M   218MB/s    in 0.6s
#
# 2024-08-02 22:48:47 (218 MB/s) - ‘w2v_OA_CR_100d.bin.wv.vectors.npy’ saved [133344128/133344128]
#
# --2024-08-02 22:48:47--  https://huggingface.co/garyw/clinical-embeddings-100d-w2v-cr/resolve/main/w2v_OA_CR_100d.bin.trainables.syn1neg.npy
# Resolving huggingface.co (huggingface.co)... 13.33.30.76, 13.33.30.23, 13.33.30.114, ...
# Connecting to huggingface.co (huggingface.co)|13.33.30.76|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/db1819eafe7cc01a478aaf2fb7e3fc11bfeca24efafdff879a527e7f34e046e2?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin.trainables.syn1neg.npy%3B+filename%3D%22w2v_OA_CR_100d.bin.trainables.syn1neg.npy%22%3B&Expires=1722898127&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=GnANPS64j-lL%7EWsW2vkXhZhDj6U588pKtD4Pgm7c%7EGV4gkOHKm4BOGHScipPe9YmMMLLWx4%7EXczkyTGT15xYUiaZGOD17RaMHWbvdiq1PAC0kuHV52OJgIcJj-UjSZxbPBLpKLW-jvVYQxL0rzS6FlMbmLvR96w8l-htxUQwfWINfQrFIIU8uC6B7HSxfu6nuE9CSztaIC-Ugbby-q%7ExwyZJ2QhO-XzszQxGTqeQCwI9OgN97vhTaBDpHtekLKQG1%7Erc%7E6U6RVxp0IcHS2WV1wFN9MeN%7EvmMLaxvjsHi5qxvohg2DU3KsTk%7EXp4RIgjTUD5NtBGjvg6XAVMAhrvc3Q__&Key-Pair-Id=K3ESJI6DHPFC7 [following]
# --2024-08-02 22:48:47--  https://cdn-lfs.huggingface.co/repos/e8/72/e872abef7b2278b5cf6a4f41d1455f5d309cdbd6310b2da0a6e9aecc840217e7/db1819eafe7cc01a478aaf2fb7e3fc11bfeca24efafdff879a527e7f34e046e2?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27w2v_OA_CR_100d.bin.trainables.syn1neg.npy%3B+filename%3D%22w2v_OA_CR_100d.bin.trainables.syn1neg.npy%22%3B&Expires=1722898127&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=GnANPS64j-lL%7EWsW2vkXhZhDj6U588pKtD4Pgm7c%7EGV4gkOHKm4BOGHScipPe9YmMMLLWx4%7EXczkyTGT15xYUiaZGOD17RaMHWbvdiq1PAC0kuHV52OJgIcJj-UjSZxbPBLpKLW-jvVYQxL0rzS6FlMbmLvR96w8l-htxUQwfWINfQrFIIU8uC6B7HSxfu6nuE9CSztaIC-Ugbby-q%7ExwyZJ2QhO-XzszQxGTqeQCwI9OgN97vhTaBDpHtekLKQG1%7Erc%7E6U6RVxp0IcHS2WV1wFN9MeN%7EvmMLaxvjsHi5qxvohg2DU3KsTk%7EXp4RIgjTUD5NtBGjvg6XAVMAhrvc3Q__&Key-Pair-Id=K3ESJI6DHPFC7
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.156.133.68, 108.156.133.109, 108.156.133.103, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.156.133.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133344128 (127M) [binary/octet-stream]
# Saving to: ‘w2v_OA_CR_100d.bin.trainables.syn1neg.npy’
#
# w2v_OA_CR_100d.bin. 100%[===================>] 127.17M   269MB/s    in 0.5s
#
# 2024-08-02 22:48:49 (269 MB/s) - ‘w2v_OA_CR_100d.bin.trainables.syn1neg.npy’ saved [133344128/133344128]

# %%
# @title imports
from transformers import AutoTokenizer, AutoModel
import pandas as pd
import stanza
import shutil
import numpy as np
from numpy.linalg import norm
import string
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from gensim.models import FastText, Word2Vec, KeyedVectors
from torch.utils.data import Dataset,DataLoader
from sklearn.metrics import accuracy_score
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')
import medialpy
from stanza import Pipeline
import contractions
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# @title CODES
def find_pre_and_hyp(query):
    start_pre = query.find("[PRE]") + len("[PRE]")
    end_pre = query.find("[HYP]")
    start_hyp = query.find("[HYP]") + len("[HYP]")
    end_hyp = query.find("OUTPUT:")
    premise = query[start_pre:end_pre].strip()
    hypothesis = query[start_hyp:end_hyp].strip()

    return premise,hypothesis


class CustomDataset(Dataset):
    def __init__(self, x_list, y_list):
        self.samples = []
        for x,y in zip(x_list,y_list):
            #x_tensor = torch.tensor(x,dtype = torch.float32)
            y_tensor = torch.tensor(y,dtype = torch.float32)
            self.samples.append((x[0],x[1],y_tensor))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]


def get_lists(data):
    x_list = []
    y_list = []
    i =0
    for query,answer in zip(data['query'],data['answer']):
        i = i + 1
        if answer == 'entailment':
           y = [1,0,0]
        elif answer == 'neutral':
           y = [0,1,0]
        elif answer == 'contradiction':
           y = [0,0,1]
        else:
           print('should not get here')

        premise,hypothesis = find_pre_and_hyp(query)
        x_list.append((premise,hypothesis))
        y_list.append(y)
    return x_list,y_list


class embedding_layer(nn.Module):
  def __init__(self,bert_model,tokenizer):
    super(embedding_layer, self).__init__()
    self.bert_model = bert_model
    self.tokenizer = tokenizer

  def forward(self, x):
    with torch.no_grad():
         s = tokenizer(x,return_tensors="pt",padding=True).to(device)
         vec = bert_model(**s)['last_hidden_state'].to(device)
    return vec

class PositionalEncoding(nn.Module):
    def __init__(self, seq_len,embedding_size):
        super().__init__()
        self.dropout = nn.Dropout(0.1)
        self.embedding_size = embedding_size
        self.seq_len = seq_len

    def forward(self, x):
        pe = torch.zeros(x.size(0), x.size(1), self.embedding_size).to(device)
        div_term = torch.zeros(x.size(0), 1, self.embedding_size).to(device)
        ks = torch.arange(self.embedding_size).float().to(device)
        values = torch.exp(-torch.log(torch.tensor(1000.0)) * 2 * ks / self.embedding_size).to(device)
        values = values.view(1, 1, -1).to(device)
        div_term = div_term + values
        x = x.reshape([x.shape[0],x.shape[1],1]).to(device)
        pe[:, :, ::2] = torch.sin(x * div_term)[:, :, ::2].to(device)
        pe[:, :, 1::2] = torch.cos(x * div_term)[:, :, 1::2].to(device)
        return self.dropout(pe)

class MultiHeadAttention(nn.Module):
    def __init__(self, embedding_size, heads):
        super().__init__()
        self.embedding_size = embedding_size
        self.heads = heads
        self.head_dim = embedding_size // heads
        assert(self.heads * self.head_dim == self.embedding_size), "Invalid number of heads"
        self.fc_values = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_keys = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_queries = nn.Linear(self.head_dim, self.head_dim, bias=False).to(device)
        self.fc_out = nn.Linear(heads * self.head_dim, embedding_size).to(device)

    def forward(self, values, keys, queries, mask):
        N = queries.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], queries.shape[1]
        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = queries.reshape(N, query_len, self.heads, self.head_dim)
        values = self.fc_values(values).to(device)
        keys = self.fc_keys(keys).to(device)
        queries = self.fc_queries(queries).to(device)
        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys]).to(device)
        if mask is not None:
            energy = energy.masked_fill(mask.to(device) == 0, float("-1e20")).to(device)
        energy = torch.softmax(energy / (self.embedding_size ** 0.5), dim=3).to(device)
        attention = torch.einsum("nhql,nlhd->nqhd", [energy, values]).to(device)
        attention = attention.reshape(N, query_len, self.heads * self.head_dim).to(device)
        out = self.fc_out(attention)
        return out

class TransformerBlock(nn.Module):
    def __init__(self, embedding_size, heads, forward_expansion, p):
        super().__init__()
        self.attention = MultiHeadAttention(embedding_size, heads)
        self.norm1 = nn.LayerNorm(embedding_size)
        self.feed_forward = nn.Sequential(nn.Linear(embedding_size, forward_expansion * embedding_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion * embedding_size, embedding_size))
        self.norm2 = nn.LayerNorm(embedding_size)
        self.dropout = nn.Dropout(p)
    def forward(self, values, keys, queries, mask):
        attention_out = self.attention(values, keys, queries, mask)
        x = self.norm1(attention_out + queries)
        x = self.dropout(x)
        ff_out = self.feed_forward(x)
        out = self.norm2(ff_out + x)
        out = self.dropout(out)
        return out

class Encoder(nn.Module):
    def __init__(self, src_vocab_size, embedding_size, num_layers, heads,
                 forward_expansion, max_length, p, device):
        super().__init__()
        self.device = device
        self.word_embedding = embedding_layer(bert_model,tokenizer)
        self.positional_embedding = PositionalEncoding(max_length, embedding_size)
        self.layers = nn.ModuleList([TransformerBlock(embedding_size, heads, forward_expansion, p) for _ in range(num_layers)])
        self.dropout = nn.Dropout(p)

    def forward(self, x, mask):
        mask = None
        pe = self.word_embedding(x)
        N = pe.size(0)
        seq_len = pe.size(1)
        positions = torch.arange(0, seq_len).expand(N, seq_len).to(self.device)
        out = self.dropout((pe + self.positional_embedding(positions)))
        for layer in self.layers:
            out = layer(out, out, out ,mask)
        return out


class Transformer(nn.Module):
    def __init__(self, src_vocab_size, src_pad_idx, embedding_size=768,
                 num_layers=1, forward_expansion=8, heads=8, max_length=100, p=0.1):
        super().__init__()
        self.src_pad_idx = src_pad_idx
        self.encoder = Encoder(src_vocab_size, embedding_size, num_layers, heads,
                               forward_expansion, max_length, p, device)

    def get_src_mask(self, src):
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2).to(device)
        return src_mask

    def forward(self, src):
        src_mask = None
        enc_out = self.encoder(src, src_mask).to(device)
        return enc_out


class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.transformer1 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.transformer2 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.fc1 = nn.Linear(768*2, 256).to(device)
        self.fc2 = nn.Linear(256, 3).to(device)

    def forward(self, x_pre,x_hyp):
        out1 = self.transformer1(x_pre)
        out2 = self.transformer2(x_hyp)
        out1 = torch.mean(out1,1)
        out2 = torch.mean(out2,1)
        x = torch.cat((out1,out2),1)
        x = F.relu(self.fc1(self.dropout1(x)))
        x = nn.functional.softmax(self.fc2(self.dropout2(x)),dim=1)
        return x

def get_model_acc(model,data_loader):
    #model.eval()
    #with torch.no_grad():
    predictions = []
    true_labels = []
    for x_pre, x_hyp, y in data_loader:
             outputs = model(x_pre,x_hyp)
             predicted_labels = torch.argmax(outputs, dim=1).cpu().numpy()
             predictions.extend(predicted_labels)
             l1 = torch.argmax(y, dim=1).cpu().numpy()
             true_labels.extend(l1)
    #model.train()
    return accuracy_score(true_labels, predictions)


def get_inf_from_num(num):
    if num == 0:
       return 'entailment'
    elif num == 1:
       return 'neutral'
    elif num == 2:
       return 'contradiction'

class NNN(nn.Module):
    def __init__(self):
        super(NNN, self).__init__()
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.transformer1 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.transformer2 = Transformer(src_vocab_size, src_pad_idx).to(device)
        self.fc1 = nn.Linear(768*2, 256).to(device)
        self.fc2 = nn.Linear(256, 2).to(device)

    def forward(self, x_pre,x_hyp):
        out1 = self.transformer1(x_pre)
        out2 = self.transformer2(x_hyp)
        out1 = torch.mean(out1,1)
        out2 = torch.mean(out2,1)
        x = torch.cat((out1,out2),1)
        x = F.relu(self.fc1(self.dropout1(x)))
        x = nn.functional.softmax(self.fc2(self.dropout2(x)),dim=1)
        return x

def get_inference_from_tns(tns):
    infr = np.argmax(tns.cpu().detach().numpy())
    if infr == 0:
       return 'entailment'
    elif infr == 1:
       return 'neutral'
    elif infr == 2:
       return 'contradiction'
    else:
       return 'shouldnt get here'


def get_trustworthy_from_tns(tns):
    infr = np.argmax(tns.cpu().detach().numpy())
    if infr == 0:
       return 'trustworthy'
    elif infr == 1:
       return 'untrustworthy'
    else:
       return 'shouldnt get here'

def get_trust_untrust_dataset(trustmodel,data_loader):
    trustmodel.eval()
    model.eval()
    trust_x_list = []
    untrust_x_list = []
    trust_y_list = []
    untrust_y_list = []
    for x_pre,x_hyp,y in data_loader:
        outputs = model(x_pre,x_hyp)
        outputs_tw = trustmodel(x_pre,x_hyp)
        y = y.to(device)
        for i in range(len(outputs)):
                 p = get_inference_from_tns(outputs[i])
                 t = get_inference_from_tns(y[i])
                 tw = get_trustworthy_from_tns(outputs_tw[i])
                 if tw == 'trustworthy':
                    trust_x_list.append((x_pre[i],x_hyp[i]))
                    trust_y_list.append(y[i].tolist())
                 elif tw == 'untrustworthy':
                    untrust_x_list.append((x_pre[i],x_hyp[i]))
                    untrust_y_list.append(y[i].tolist())
                 else:
                    print('shouldnt get here')
    trust_dataset = CustomDataset(trust_x_list,trust_y_list)
    untrust_dataset = CustomDataset(untrust_x_list,untrust_y_list)
    trust_data_loader = torch.utils.data.DataLoader(trust_dataset, batch_size=32, shuffle=True)
    untrust_data_loader = torch.utils.data.DataLoader(untrust_dataset, batch_size=32, shuffle=True)
    #print('trust num: ' + str(len(trust_y_list)))
    #print('untrust num: ' + str(len(untrust_y_list)))
    #print('trust acc: ' + str(get_model_acc(model,trust_data_loader)))
    #print('untrust acc: ' + str(get_model_acc(model,untrust_data_loader)))
    return trust_dataset,untrust_dataset

# %%
test_data = pd.read_parquet('MedNLI_dataset/test-00000-of-00001-47685aa42db61e77.parquet', engine='fastparquet')
train_data = pd.read_parquet('MedNLI_dataset/train-00000-of-00001-210cfe9263b99806.parquet', engine='fastparquet')
valid_data = pd.read_parquet('MedNLI_dataset/valid-00000-of-00001-cc552de6d1a6fa4b.parquet', engine='fastparquet')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("gsarti/biobert-nli")
bert_model = AutoModel.from_pretrained("gsarti/biobert-nli").to(device)
src_pad_idx = 0
src_vocab_size = bert_model.config.vocab_size
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
train_x_list,train_y_list = get_lists(train_data)
test_x_list,test_y_list = get_lists(test_data)
val_x_list,val_y_list = get_lists(valid_data)

# %%
train_dataset = CustomDataset(train_x_list,train_y_list)
test_dataset = CustomDataset(test_x_list,test_y_list)
val_dataset = CustomDataset(val_x_list,val_y_list)

# %%
bsize = 32
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=bsize, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=bsize, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %%
with torch.no_grad():
     model = torch.load('modelw.pth')
     newmodel = torch.load('TrustModelw5.pth')
     print(get_model_acc(model,test_loader))
# Out:
# 0.7334739803094233

# %%
w2v = Word2Vec.load('w2v_OA_CR_100d.bin')
stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading these customized packages for language: en (English)...
# ====================================
# | Processor       | Package        |
# ------------------------------------
# | tokenize        | mimic          |
# | pos             | mimic_charlm   |
# | lemma           | mimic_nocharlm |
# | depparse        | mimic_charlm   |
# | ner             | i2b2           |
# | pretrain        | mimic          |
# | forward_charlm  | mimic          |
# | backward_charlm | mimic          |
# ====================================
#
# INFO:stanza:File exists: /root/stanza_resources/en/tokenize/mimic.pt
# INFO:stanza:File exists: /root/stanza_resources/en/pos/mimic_charlm.pt
# INFO:stanza:File exists: /root/stanza_resources/en/lemma/mimic_nocharlm.pt
# INFO:stanza:File exists: /root/stanza_resources/en/depparse/mimic_charlm.pt
# INFO:stanza:File exists: /root/stanza_resources/en/ner/i2b2.pt
# INFO:stanza:File exists: /root/stanza_resources/en/pretrain/mimic.pt
# INFO:stanza:File exists: /root/stanza_resources/en/forward_charlm/mimic.pt
# INFO:stanza:File exists: /root/stanza_resources/en/backward_charlm/mimic.pt
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# ==============================
# | Processor | Package        |
# ------------------------------
# | tokenize  | mimic          |
# | pos       | mimic_charlm   |
# | lemma     | mimic_nocharlm |
# | depparse  | mimic_charlm   |
# | ner       | i2b2           |
# ==============================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
def extract_svo_rest(sentence):
    doc = nlp(sentence)
    subject = '-'
    verb = '-'
    rest_of_sentence = '-'
    tobe_verbs = ['be','am','is','are','were','was']
    for sent in doc.sentences:
        for word in sent.words:
            if 'subj' in word.deprel:
                subject = word.text
            if word.deprel == 'root':
               if word.upos == 'ADJ':
                  verb = 'is'
               elif word.upos == 'VERB':
                  verb = word.text
        rest_of_sentence = ' '.join([word.text for word in sent.words if word.text != subject and word.text != verb])
    return subject, verb, rest_of_sentence

def get_svos(text):
    sentences = text.split('. ')
    svo_results = []
    for sentence in sentences:
        sentence = sentence.strip()
        if sentence:
            subject, verb, rest_of_sentence = extract_svo_rest(sentence)
            svo_results.append((sentence, subject, verb, rest_of_sentence))
    return svo_results

# %%
def get_cos_similarity(prem,hypt):
    try:
      a = w2v.wv.get_vector(prem)
      b = w2v.wv.get_vector(hypt)
      return (a@b)/(norm(a)*norm(b))
    except:
      return 0

# %%
get_cos_similarity('extubated','intubated')
# Out:
# 0.860444

# %%
def deabbreviation(text):
    try:
       return medialpy.find(text).meaning[0]
    except:
       return text

# %%
def preprocess_text(text):
    text = contractions.fix(text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    ntokens = []
    for token in tokens:
        ntokens.append(deabbreviation(token).lower())
    stop_words = set(stopwords.words('english'))
    stop_words.remove('no')
    stop_words.remove('not')
    filtered_tokens = [word for word in ntokens if word not in stop_words]
    processed_text = ' '.join(filtered_tokens)
    return processed_text

# %%
def check_subject_verb_match(prem_svos,hypt_svos):
    r = False
    for prems, psubjects, pverbs, prests in prem_svos:
        for hypts, hsubjects, hverbs, hrests in hypt_svos:
            if psubjects == hsubjects and pverbs == hverbs:
               r = True
    return r

# %%
def check_verb_match(prem_svos,hypt_svos):
    r = False
    for prems, psubjects, pverbs, prests in prem_svos:
        for hypts, hsubjects, hverbs, hrests in hypt_svos:
            if pverbs == hverbs:
               r = True
    return r

# %%
def similarity(prem,hypt):
    count = 0
    l = len(word_tokenize(prem)) if len(word_tokenize(prem)) < len(word_tokenize(hypt)) else len(word_tokenize(hypt))
    for hypword in hypt.split():
        for preword in prem.split():
                    if get_cos_similarity(hypword,preword)>=0.8:
                       count +=1
    return count/l

# %%
def get_hybrid_answer_sv_match(prem,hypt,dp_answer,sim_score):
    print(sim_score)
    if sim_score > 0.7:
      if (detect_negation(prem) and not detect_negation(hypt)) or (not detect_negation(prem) and detect_negation(hypt)):
          return 'contradiction'
      else:
          return 'entailment'
    else:
      print('default')
      return dp_answer

# %%
def is_verb_negated(verb):
    return (get_verb_sentiment(verb)['neg']>=0.9)

# %%
def is_s_match_contradiction(a,b,c,d):
    x1 = (not a and b and c and d)
    x2 = (a and not b and c and d)
    x3 = (a and b and not c and d)
    x4 = (a and b and c and not d)
    x5 = (a and not b and not c and not d)
    x6 = (not a and b and not c and not d)
    x7 = (not a and not b and c and not d)
    x8 = (not a and not b and not c and d)
    x9 = ( a and not b and c and not d)
    xx = ( not a and b and not c and d)
    return x1 or x2 or x3 or x4 or x5 or x6 or x7 or x8 or x9 or xx

# %%
def get_hybrid_answer_v_match(prem,hypt,dp_answer,sim_score):
    print(sim_score)
    if sim_score > 0.66:
      if (detect_negation(prem) and not detect_negation(hypt)) or (not detect_negation(prem) and detect_negation(hypt)):
          return 'contradiction'
      else:
          return 'entailment'
    else:
      print('default')
      return dp_answer

# %%
def get_hybrid_answer_non_match(prem,hypt,prem_verb,hypt_verb,dp_answer,sim_score):
    print(sim_score)
    if sim_score > 0.66:
      a = detect_negation(prem)
      b = detect_negation(hypt)
      c = is_verb_negated(prem_verb)
      d = is_verb_negated(hypt_verb)
      print('prem cx: '+str(a))
      print('hypt cx: '+str(b))
      print('prem verb: '+prem_verb+' '+str(c))
      print('hypt verb: '+hypt_verb+' '+str(d))
      if is_s_match_contradiction(a,b,c,d):
          return 'contradiction'
      else:
          return 'entailment'
    else:
      print('default')
      return dp_answer

# %%
def get_reliability_from_num(num):
    if num == 0:
       return 'reliable'
    elif num == 1:
       return 'unreliable'
    else:
       return None

# %%
def detect_negation(sentence):
    sentence = contractions.fix(sentence)
    doc = nlp(sentence)
    negations = []
    r = False
    for sentence in doc.sentences:
        for word in sentence.words:
            if (word.text.lower() == "not" or word.text.lower() == "no" or word.text.lower() == "never" or word.text.lower() == "non" or word.text.lower() == "loss" or word.text.lower() == "absence" or word.text.lower() == "low") and word.head > 0:
                head_word = sentence.words[word.head - 1]
                negations.append(head_word.text)
                r = True
    return r

# %%
def print_inf(count,wrong_label,corrected_label,uncorrected_label,prem,hypt,hy_answer,dp_answer,ground_truth):
    print('num: '+str(count))
    print('wrong label: '+str(wrong_label))
    print('corrected label: '+str(corrected_label))
    print('uncorrected label: '+str(uncorrected_label))
    print('premise: '+prem)
    print('hypothesis: '+hypt)
    print('hy: '+ hy_answer)
    print('dp: '+ dp_answer)
    print('ground_truth: '+ ground_truth)
    print('=====================================================================================================')

# %%
sia = SentimentIntensityAnalyzer()
def get_verb_sentiment(verb):
    return  sia.polarity_scores(verb)

# %%
model.eval()
newmodel.eval()
count = 0
wrong_label = 0
corrected_label = 0
uncorrected_label = 0
for x_pre,x_hyp,y in test_loader:
  for i in range(len(x_pre)):
      with torch.no_grad():
          dp_answer = get_inf_from_num(np.argmax(model(x_pre[i],x_hyp[i]).cpu().detach().numpy()))
          ground_truth = get_inf_from_num(np.argmax(y[i].cpu().detach().numpy()))
          dp_trust = get_reliability_from_num(np.argmax(newmodel(x_pre[i],x_hyp[i]).cpu().detach().numpy()))
      if dp_trust == 'unreliable':
          prem = x_pre[i]
          hypt = x_hyp[i]
          prem_svos = get_svos(prem)
          hypt_svos = get_svos(hypt)

          if check_subject_verb_match(prem_svos,hypt_svos):
             sim_score = similarity(preprocess_text(prem),preprocess_text(hypt))
             hy_answer = get_hybrid_answer_sv_match(prem,hypt,dp_answer,sim_score)
             count +=1
             if ground_truth != dp_answer:
                wrong_label += 1
             if ground_truth != dp_answer and hy_answer == ground_truth:
                corrected_label += 1
             if ground_truth == dp_answer and hy_answer != ground_truth:
                uncorrected_label += 1
             print_inf(count,wrong_label,corrected_label,uncorrected_label,prem,hypt,hy_answer,dp_answer,ground_truth)

          elif check_verb_match(prem_svos,hypt_svos):
             sim_score = similarity(preprocess_text(prem),preprocess_text(hypt))
             hy_answer = get_hybrid_answer_v_match(prem,hypt,dp_answer,sim_score)
             count +=1
             if ground_truth != dp_answer:
                wrong_label += 1
             if ground_truth != dp_answer and hy_answer == ground_truth:
                corrected_label += 1
             if ground_truth == dp_answer and hy_answer != ground_truth:
                uncorrected_label += 1
             print_inf(count,wrong_label,corrected_label,uncorrected_label,prem,hypt,hy_answer,dp_answer,ground_truth)
          else:
             sim_score = similarity(preprocess_text(prem),preprocess_text(hypt))
             hy_answer = get_hybrid_answer_non_match(prem,hypt,prem_svos[0][2],hypt_svos[0][2],dp_answer,sim_score)
             count +=1
             if ground_truth != dp_answer:
                wrong_label += 1
             if ground_truth != dp_answer and hy_answer == ground_truth:
                corrected_label += 1
             if ground_truth == dp_answer and hy_answer != ground_truth:
                uncorrected_label += 1
             print_inf(count,wrong_label,corrected_label,uncorrected_label,prem,hypt,hy_answer,dp_answer,ground_truth)
# Out:
# Streaming output truncated to the last 5000 lines.
# hypothesis: the patient underwent an EGD
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 360
# wrong label: 128
# corrected label: 15
# uncorrected label: 4
# premise: He had no nausea or vomiting prior the EGD.
# hypothesis: the patient has chronic abdominal pain
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 361
# wrong label: 129
# corrected label: 15
# uncorrected label: 4
# premise: Labs notable for WBC 10.5 without bands, Hct 32.2 (prior baseline mid to upper 20s), Cr 0.9, CE neg X 1, and lactate 1.5.
# hypothesis: The patient does not have anemia.
# hy: contradiction
# dp: contradiction
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 362
# wrong label: 130
# corrected label: 15
# uncorrected label: 4
# premise: Labs notable for WBC 10.5 without bands, Hct 32.2 (prior baseline mid to upper 20s), Cr 0.9, CE neg X 1, and lactate 1.5.
# hypothesis: The patient is in renal failure.
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 363
# wrong label: 131
# corrected label: 15
# uncorrected label: 4
# premise: Labs notable for WBC 10.5 without bands, Hct 32.2 (prior baseline mid to upper 20s), Cr 0.9, CE neg X 1, and lactate 1.5.
# hypothesis: The patient does not have an infection.
# hy: contradiction
# dp: contradiction
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 364
# wrong label: 132
# corrected label: 15
# uncorrected label: 4
# premise: Vitals prior to transfer to the MICU were: afebrile, HR 92, BP 123/74, 96% on 6L.
# hypothesis: Patient has no fever
# hy: contradiction
# dp: contradiction
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 365
# wrong label: 133
# corrected label: 15
# uncorrected label: 4
# premise: Vitals prior to transfer to the MICU were: afebrile, HR 92, BP 123/74, 96% on 6L.
# hypothesis: Patient has no infection
# hy: contradiction
# dp: contradiction
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 366
# wrong label: 133
# corrected label: 15
# uncorrected label: 4
# premise: She placed him back on O2.
# hypothesis: the patient is on oxygen
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 367
# wrong label: 133
# corrected label: 15
# uncorrected label: 4
# premise: She placed him back on O2.
# hypothesis: the patient has chest pain
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 368
# wrong label: 133
# corrected label: 15
# uncorrected label: 4
# premise: His wife witnessed shaking and frothing activities for about 2-3 minutes.
# hypothesis: The patient had symptoms of a seizure.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 369
# wrong label: 133
# corrected label: 15
# uncorrected label: 4
# premise: His wife witnessed shaking and frothing activities for about 2-3 minutes.
# hypothesis: The patient had a seizure.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.25
# default
# num: 370
# wrong label: 133
# corrected label: 15
# uncorrected label: 4
# premise: She was given all options for treatment and wished to proceed with a left radical nephrectomy with regional lymphadenectomy
# hypothesis: patient has a left renal malignancy
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 371
# wrong label: 133
# corrected label: 15
# uncorrected label: 4
# premise: An emergent Hematology consultation was obtained.
# hypothesis: the patient had an emergent hematology consult
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 372
# wrong label: 134
# corrected label: 15
# uncorrected label: 4
# premise: An emergent Hematology consultation was obtained.
# hypothesis: the patient has heparin induced thrombocytopenia
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 373
# wrong label: 134
# corrected label: 15
# uncorrected label: 4
# premise: He was transferred to [**Hospital1 22**] for further management.
# hypothesis: The patient was treated at a different hospital.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 374
# wrong label: 134
# corrected label: 15
# uncorrected label: 4
# premise: He was transferred to [**Hospital1 22**] for further management.
# hypothesis: The patient was not treated at a hospital.
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 375
# wrong label: 135
# corrected label: 15
# uncorrected label: 4
# premise: He was transferred to [**Hospital1 22**] for further management.
# hypothesis: The patient required a higher level of care.
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 376
# wrong label: 136
# corrected label: 15
# uncorrected label: 4
# premise: Status post Bankart repair of his right shoulder in [**3354**].
# hypothesis: He had a shoulder dislocation
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 377
# wrong label: 136
# corrected label: 15
# uncorrected label: 4
# premise: Status post Bankart repair of his right shoulder in [**3354**].
# hypothesis: He had a recent fall
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 378
# wrong label: 137
# corrected label: 15
# uncorrected label: 4
# premise: Head circumference 30.5 cm, 25th-50th percentile.
# hypothesis: the patient has normal head circumference
# hy: contradiction
# dp: contradiction
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 379
# wrong label: 138
# corrected label: 15
# uncorrected label: 4
# premise: Head circumference 30.5 cm, 25th-50th percentile.
# hypothesis: the patient has macrocephaly
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 380
# wrong label: 138
# corrected label: 15
# uncorrected label: 4
# premise: Head circumference 30.5 cm, 25th-50th percentile.
# hypothesis: the patient has a normal weight
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 381
# wrong label: 138
# corrected label: 15
# uncorrected label: 4
# premise: In the ED, initial VS were HR 77, BP 145/82, RR 22, Sat 98% RA, BG critically high.
# hypothesis: The patient has hyperglycemia.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.75
# prem cx: False
# hypt cx: False
# prem verb: - False
# hypt verb: has False
# num: 382
# wrong label: 138
# corrected label: 15
# uncorrected label: 5
# premise: In the ED, initial VS were HR 77, BP 145/82, RR 22, Sat 98% RA, BG critically high.
# hypothesis: The patient has a normal blood glucose.
# hy: entailment
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.6666666666666666
# num: 383
# wrong label: 139
# corrected label: 16
# uncorrected label: 5
# premise: Family found her about 3 AM on the floor.
# hypothesis: the patient was found on the floor
# hy: entailment
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 384
# wrong label: 140
# corrected label: 16
# uncorrected label: 5
# premise: Type 1 diabetes mellitus since age 9.
# hypothesis: Patient has had diabetic ketoacidosis
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.25
# default
# num: 385
# wrong label: 140
# corrected label: 16
# uncorrected label: 5
# premise: Transferred to CCU for further management. .
# hypothesis: The patient required intensive care
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 386
# wrong label: 140
# corrected label: 16
# uncorrected label: 5
# premise: Transferred to CCU for further management. .
# hypothesis: The patient was discharged home
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 387
# wrong label: 140
# corrected label: 16
# uncorrected label: 5
# premise: Transferred to CCU for further management. .
# hypothesis: The patient had elevated troponin levels
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.75
# num: 388
# wrong label: 140
# corrected label: 16
# uncorrected label: 5
# premise: She denies any abdominal discomfort or dyspepsia now or in the past.
# hypothesis: the patient denies abdominal pain
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.6666666666666666
# prem cx: False
# hypt cx: False
# prem verb: denies True
# hypt verb: has False
# num: 389
# wrong label: 140
# corrected label: 16
# uncorrected label: 5
# premise: She denies any abdominal discomfort or dyspepsia now or in the past.
# hypothesis: the patient has abdominal pain
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.5
# default
# num: 390
# wrong label: 141
# corrected label: 16
# uncorrected label: 5
# premise: She denies any abdominal discomfort or dyspepsia now or in the past.
# hypothesis: the patient denies chest pain
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.3333333333333333
# default
# num: 391
# wrong label: 142
# corrected label: 16
# uncorrected label: 5
# premise: No abscess noted; no s[** Location **] or portal vein thrombosis.
# hypothesis: The patient does not have a clot within the portal vein.
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 392
# wrong label: 143
# corrected label: 16
# uncorrected label: 5
# premise: No abscess noted; no s[** Location **] or portal vein thrombosis.
# hypothesis: The patient does note have any hepatic lesions.
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 393
# wrong label: 143
# corrected label: 16
# uncorrected label: 5
# premise: About three weeks ago, patient reported an episode of chest "pressure" and "aching" spreading like a band across his upper chest and throat and slight radiation to both upper arms.
# hypothesis: The patient had angina
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 394
# wrong label: 144
# corrected label: 16
# uncorrected label: 5
# premise: The patient denies alcohol use.
# hypothesis: The patient does not drink alcohol
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 1.0
# prem cx: False
# hypt cx: False
# prem verb: denies True
# hypt verb: abuses True
# num: 395
# wrong label: 144
# corrected label: 16
# uncorrected label: 6
# premise: The patient denies alcohol use.
# hypothesis: The patient abuses alcohol
# hy: entailment
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.25
# default
# num: 396
# wrong label: 144
# corrected label: 16
# uncorrected label: 6
# premise: The patient denies alcohol use.
# hypothesis: The patient has no history of drug abuse
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 397
# wrong label: 144
# corrected label: 16
# uncorrected label: 6
# premise: His wife states he was falling to the left while trying to ambulate, and he was taken to [**Hospital1 52**] for further evaluation.
# hypothesis: He has a history of atrial fibrillation and hypertension
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 398
# wrong label: 144
# corrected label: 16
# uncorrected label: 6
# premise: Of note he was discharged from [**Hospital1 68**] [**9-23**] for URI/COPD exacerbation.
# hypothesis: The patient has a pulmonary condition.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 399
# wrong label: 144
# corrected label: 16
# uncorrected label: 6
# premise: Of note he was discharged from [**Hospital1 68**] [**9-23**] for URI/COPD exacerbation.
# hypothesis: The patient has normal lung function.
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 400
# wrong label: 144
# corrected label: 16
# uncorrected label: 6
# premise: Of note he was discharged from [**Hospital1 68**] [**9-23**] for URI/COPD exacerbation.
# hypothesis: The patient has a history of smoking.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 401
# wrong label: 145
# corrected label: 16
# uncorrected label: 6
# premise: Labor was induced with Pitocin.
# hypothesis: Patient is in labor
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 402
# wrong label: 146
# corrected label: 16
# uncorrected label: 6
# premise: Labor was induced with Pitocin.
# hypothesis: Patient was given a C-section
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# 0.3333333333333333
# default
# num: 403
# wrong label: 147
# corrected label: 16
# uncorrected label: 6
# premise: Labor was induced with Pitocin.
# hypothesis: Patient labor is not progressing
# hy: contradiction
# dp: contradiction
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 404
# wrong label: 147
# corrected label: 16
# uncorrected label: 6
# premise: Seizure disorder, in the setting of renal failure.
# hypothesis: kidney dysfunction
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 405
# wrong label: 147
# corrected label: 16
# uncorrected label: 6
# premise: Seizure disorder, in the setting of renal failure.
# hypothesis: Patient is on dialysis
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 406
# wrong label: 147
# corrected label: 16
# uncorrected label: 6
# premise: Alzheimer's dementia 3.
# hypothesis: Patient has abnormal brain MRI
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 407
# wrong label: 147
# corrected label: 16
# uncorrected label: 6
# premise: Alzheimer's dementia 3.
# hypothesis: the patient has dementia
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.3333333333333333
# default
# num: 408
# wrong label: 148
# corrected label: 16
# uncorrected label: 6
# premise: The patient usually walks without any assistance.
# hypothesis: The patient is at baseline ambulatory
# hy: contradiction
# dp: contradiction
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 409
# wrong label: 149
# corrected label: 16
# uncorrected label: 6
# premise: The patient usually walks without any assistance.
# hypothesis: The patient is wheelchair-bound
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# 0.2
# default
# num: 410
# wrong label: 149
# corrected label: 16
# uncorrected label: 6
# premise: The patient usually walks without any assistance.
# hypothesis: The patient performs activities of daily living independently
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.3333333333333333
# default
# num: 411
# wrong label: 150
# corrected label: 16
# uncorrected label: 6
# premise: His chest x-ray on [**5-16**] demonstrated enlarged heart with worsening pulmonary edema, as well as left lower lobe consolidation and pleural effusion.
# hypothesis: Patient has heart failure.
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 412
# wrong label: 150
# corrected label: 16
# uncorrected label: 6
# premise: His chest x-ray on [**5-16**] demonstrated enlarged heart with worsening pulmonary edema, as well as left lower lobe consolidation and pleural effusion.
# hypothesis: Patient has pneumonia.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 413
# wrong label: 150
# corrected label: 16
# uncorrected label: 6
# premise: Next was in [**3079**] with severe left sided weakness.
# hypothesis: Patient has signs of stroke
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 414
# wrong label: 150
# corrected label: 16
# uncorrected label: 6
# premise: Next was in [**3079**] with severe left sided weakness.
# hypothesis: Patient has a TIA
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 415
# wrong label: 150
# corrected label: 16
# uncorrected label: 6
# premise: On arrival to the floor, he still complains of dizziness-- "like everything is off kilter"-- and HA.
# hypothesis: The patient has vestibular symptoms.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 416
# wrong label: 151
# corrected label: 16
# uncorrected label: 6
# premise: Patient also on coumadin for h/o DVT.
# hypothesis: The patient is being anticoagulated.
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.3333333333333333
# default
# num: 417
# wrong label: 151
# corrected label: 16
# uncorrected label: 6
# premise: Patient also on coumadin for h/o DVT.
# hypothesis: The patient has a hypercoaguable condition.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 418
# wrong label: 152
# corrected label: 16
# uncorrected label: 6
# premise: The heart demonstrates mild to moderate enlargement, not significantly changed.
# hypothesis: The patient has cardiomegaly.
# hy: contradiction
# dp: contradiction
# ground_truth: entailment
# =====================================================================================================
# 0.3333333333333333
# default
# num: 419
# wrong label: 153
# corrected label: 16
# uncorrected label: 6
# premise: The heart demonstrates mild to moderate enlargement, not significantly changed.
# hypothesis: The patient has a small heart.
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 420
# wrong label: 153
# corrected label: 16
# uncorrected label: 6
# premise: The heart demonstrates mild to moderate enlargement, not significantly changed.
# hypothesis: The patient is hypertensive.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 421
# wrong label: 154
# corrected label: 16
# uncorrected label: 6
# premise: He was admitted to the Neonatal Intensive Care Unit for a sepsis evaluation with less than four hours of treatment prior to delivery.
# hypothesis: patient is infected
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 422
# wrong label: 154
# corrected label: 16
# uncorrected label: 6
# premise: BPH w h/o obstruction requiring foley placement.
# hypothesis: Prostate enlargement
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 423
# wrong label: 155
# corrected label: 16
# uncorrected label: 6
# premise: BPH w h/o obstruction requiring foley placement.
# hypothesis: High levels of PSA
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 424
# wrong label: 156
# corrected label: 16
# uncorrected label: 6
# premise: Insulin dependent diabetes mellitus, diagnosed age    thirteen.
# hypothesis: Patient has elevated serum glucose
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 425
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: The patient's Plavix was scheduled to run for thirty days ending on [**2564-5-31**].
# hypothesis: The patient is on an antiplatelet medication.
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 426
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: The patient's Plavix was scheduled to run for thirty days ending on [**2564-5-31**].
# hypothesis: The patient had a recent stroke.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 427
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: Her BP fell to 97/52, then later rose to 197/92 (very labile).
# hypothesis: Patient has intermittent hypotension
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 428
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: Her BP fell to 97/52, then later rose to 197/92 (very labile).
# hypothesis: Patient has stable blood pressure
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.25
# default
# num: 429
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: Mild aortic stenosis on echo- history of syncope 9.
# hypothesis: Echo showed narrowing of the aorta
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 430
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: Routine drying, suctioning and stimulated.
# hypothesis: The infant was recently born.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 431
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: Routine drying, suctioning and stimulated.
# hypothesis: The mother has not delivered the patient yet.
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 432
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: Routine drying, suctioning and stimulated.
# hypothesis: The delivery was a normal spontaneous vaginal delivery.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 433
# wrong label: 157
# corrected label: 16
# uncorrected label: 6
# premise: Watermelon stomach with gastric varices, without bleed in more than 2 years.
# hypothesis: Patient has cirrhosis
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 434
# wrong label: 158
# corrected label: 16
# uncorrected label: 6
# premise: He complained of SOB at the nursing home today and was found to be hypoxic to the 80s on RA, and satting 90% on 6L, was noted to have a bandemia on his WBC, and set to the ED. .
# hypothesis: His oxygen saturation level is low
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 435
# wrong label: 158
# corrected label: 16
# uncorrected label: 6
# premise: He complained of SOB at the nursing home today and was found to be hypoxic to the 80s on RA, and satting 90% on 6L, was noted to have a bandemia on his WBC, and set to the ED. .
# hypothesis: He has a history of COPD
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 436
# wrong label: 158
# corrected label: 16
# uncorrected label: 6
# premise: He was restarted on lasix 40mg, with plans to have follow up labs drawn in 1 week.
# hypothesis: He restarted on his diuretic
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 437
# wrong label: 158
# corrected label: 16
# uncorrected label: 6
# premise: He was restarted on lasix 40mg, with plans to have follow up labs drawn in 1 week.
# hypothesis: He has a history of renal disease
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 438
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Patient has abnormal EKG
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 439
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Patient has NSR
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 440
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Patient has angina
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 441
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Patient has occasional abnormal cardiac rhythms
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 442
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Patient has normal EKG
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 443
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Patient has palpitations
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 444
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Arrhythmia
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 445
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: The patient is on a beta blocker
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 446
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: Paroxysmal atrial fibrillation.
# hypothesis: Arrhythmia
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 1.3333333333333333
# num: 447
# wrong label: 159
# corrected label: 16
# uncorrected label: 6
# premise: S/he denies recent fevers, chills or rigors.
# hypothesis: the patient denies fevers.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.25
# default
# num: 448
# wrong label: 160
# corrected label: 16
# uncorrected label: 6
# premise: S/he denies recent fevers, chills or rigors.
# hypothesis: the patient denies weight loss.
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 449
# wrong label: 160
# corrected label: 16
# uncorrected label: 6
# premise: She denies chest pain, shortness of breath, fever, chills, nausea and vomiting.
# hypothesis: The patient does not have symptoms of pneumonia.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 450
# wrong label: 160
# corrected label: 16
# uncorrected label: 6
# premise: She denies chest pain, shortness of breath, fever, chills, nausea and vomiting.
# hypothesis: The patient does not have pneumonia.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.75
# prem cx: True
# hypt cx: True
# prem verb: - False
# hypt verb: has False
# num: 451
# wrong label: 160
# corrected label: 16
# uncorrected label: 6
# premise: No abdominal pain or diarrhea.
# hypothesis: the patient has no abdominal pain.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 452
# wrong label: 160
# corrected label: 16
# uncorrected label: 6
# premise: No abdominal pain or diarrhea.
# hypothesis: the patient has diarrhea.
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.5
# default
# num: 453
# wrong label: 161
# corrected label: 16
# uncorrected label: 6
# premise: No abdominal pain or diarrhea.
# hypothesis: the patient has no chest pain.
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 454
# wrong label: 161
# corrected label: 16
# uncorrected label: 6
# premise: Duodenal ulcer/melena, [**2608-10-28**], H. pylori negative.
# hypothesis: the patient has a normal duodenum
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 455
# wrong label: 161
# corrected label: 16
# uncorrected label: 6
# premise: HTN A fib Hyperthyroidism DM recurrent pleural effusion (drained 6 weeks ago at [**Hospital **] Hosp)  s/p appy at age 8
# hypothesis: The patient has had prior surgery.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 456
# wrong label: 162
# corrected label: 16
# uncorrected label: 6
# premise: HTN A fib Hyperthyroidism DM recurrent pleural effusion (drained 6 weeks ago at [**Hospital **] Hosp)  s/p appy at age 8
# hypothesis: The has elevated blood sugars.
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 457
# wrong label: 162
# corrected label: 16
# uncorrected label: 6
# premise: Status post appendectomy 11.
# hypothesis: No surgical history
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 458
# wrong label: 163
# corrected label: 16
# uncorrected label: 6
# premise: Status post appendectomy 11.
# hypothesis: The patient has a history of  obstructing fecaliths in the appendix
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 459
# wrong label: 163
# corrected label: 16
# uncorrected label: 6
# premise: Autoimmune hemolytic anemia.
# hypothesis: A disease that causes red blood cells to lyse.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.3333333333333333
# default
# num: 460
# wrong label: 163
# corrected label: 16
# uncorrected label: 6
# premise: Autoimmune hemolytic anemia.
# hypothesis: Patients with this disease also have other autoimmune diseases.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 461
# wrong label: 163
# corrected label: 16
# uncorrected label: 6
# premise: She was discharged on bed rest and treated with terbutaline.
# hypothesis: Patient is no longer inpatient
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 462
# wrong label: 163
# corrected label: 16
# uncorrected label: 6
# premise: She was discharged on bed rest and treated with terbutaline.
# hypothesis: Patient is no longer taking medications
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 463
# wrong label: 164
# corrected label: 16
# uncorrected label: 6
# premise: She was discharged on bed rest and treated with terbutaline.
# hypothesis: Patient has a follow up appointment
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 464
# wrong label: 164
# corrected label: 16
# uncorrected label: 6
# premise: Currently, she feels fatigued, continues to have some chest discomfort with coughing, not short of breath. .
# hypothesis: Patient has positive ROS findings
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 465
# wrong label: 165
# corrected label: 16
# uncorrected label: 6
# premise: Currently, she feels fatigued, continues to have some chest discomfort with coughing, not short of breath. .
# hypothesis: Patient has dyspnea
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# 0.2
# default
# num: 466
# wrong label: 165
# corrected label: 16
# uncorrected label: 6
# premise: Pt had normal physical exam and reported "melena" in the rectal vault.
# hypothesis: The patient has blood found within the rectum.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.25
# default
# num: 467
# wrong label: 165
# corrected label: 16
# uncorrected label: 6
# premise: Pt had normal physical exam and reported "melena" in the rectal vault.
# hypothesis: The patient does not have a GI bleed.
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.3333333333333333
# default
# num: 468
# wrong label: 165
# corrected label: 16
# uncorrected label: 6
# premise: Pt had normal physical exam and reported "melena" in the rectal vault.
# hypothesis: The patient has a GI bleed.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.75
# prem cx: False
# hypt cx: False
# prem verb: started False
# hypt verb: has False
# num: 469
# wrong label: 165
# corrected label: 16
# uncorrected label: 6
# premise: The patient recently started developing similar symptoms of chest pressure and discomfort at rest.
# hypothesis: The patient has recent chest pain
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 470
# wrong label: 165
# corrected label: 16
# uncorrected label: 6
# premise: Chronic left subdural hematoma.
# hypothesis: there is midline shift
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 471
# wrong label: 165
# corrected label: 16
# uncorrected label: 6
# premise: His amiodarone dose has been increased (200-->300).
# hypothesis: Patient has a cardiac arrhythmia
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 472
# wrong label: 165
# corrected label: 16
# uncorrected label: 6
# premise: His amiodarone dose has been increased (200-->300).
# hypothesis: Patient has CAD
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.3333333333333333
# default
# num: 473
# wrong label: 166
# corrected label: 16
# uncorrected label: 6
# premise: The patient is a 57 yo woman with a negative [** Location **]us medical history, obesity, who presents [**3259-12-9**] after being found in the parking lot with R hemiparesis.
# hypothesis: Patient has signs of stroke
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 474
# wrong label: 166
# corrected label: 16
# uncorrected label: 6
# premise: Over the past couple of weeks, he has also had difficulty passing stool; he typically has one bowel movement daily, but he last had a BM four days ago.
# hypothesis: He has constipation
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 475
# wrong label: 167
# corrected label: 16
# uncorrected label: 6
# premise: Over the past couple of weeks, he has also had difficulty passing stool; he typically has one bowel movement daily, but he last had a BM four days ago.
# hypothesis: He has diarrhea
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 476
# wrong label: 168
# corrected label: 16
# uncorrected label: 6
# premise: He was found to have a pleural effusion as well as a pericardial effusion that was identified by transesophageal echocardiogram without evidence of tamponade.
# hypothesis: The heart is being compressed
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 477
# wrong label: 168
# corrected label: 16
# uncorrected label: 6
# premise: He was found to have a pleural effusion as well as a pericardial effusion that was identified by transesophageal echocardiogram without evidence of tamponade.
# hypothesis: He has a history of congestive heart failure
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.3333333333333333
# default
# num: 478
# wrong label: 169
# corrected label: 16
# uncorrected label: 6
# premise: She had no cramping, pain, nausea, or other symptoms at the time.
# hypothesis: Patient has abdominal pain
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 479
# wrong label: 169
# corrected label: 16
# uncorrected label: 6
# premise: She had no cramping, pain, nausea, or other symptoms at the time.
# hypothesis: Patient has normal physical examination
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 480
# wrong label: 170
# corrected label: 16
# uncorrected label: 6
# premise: ﻿He was transferred to the floor on the morning of [**3354-10-12**] for monitoring and evaluation.
# hypothesis: His vitals were stable
# hy: contradiction
# dp: contradiction
# ground_truth: neutral
# =====================================================================================================
# 0.6666666666666666
# prem cx: False
# hypt cx: False
# prem verb: complained True
# hypt verb: had False
# num: 481
# wrong label: 170
# corrected label: 16
# uncorrected label: 6
# premise: Several hours post intervention, patient complained of pain in LLE and was unable to move her foot.
# hypothesis: The patient had full movement in the left lower extremity.
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.3333333333333333
# default
# num: 482
# wrong label: 170
# corrected label: 16
# uncorrected label: 6
# premise: Several hours post intervention, patient complained of pain in LLE and was unable to move her foot.
# hypothesis: The patient had a recent stroke.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 483
# wrong label: 170
# corrected label: 16
# uncorrected label: 6
# premise: Had mild nausea on Sunday and on the day of her presentation.
# hypothesis: The patient has symptoms of a GI condition.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 484
# wrong label: 170
# corrected label: 16
# uncorrected label: 6
# premise: Pt was shocked x 1.
# hypothesis: The patient was being coded.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.25
# default
# num: 485
# wrong label: 171
# corrected label: 16
# uncorrected label: 6
# premise: Pt was shocked x 1.
# hypothesis: The patient was in PEA arrest.
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# 0.3333333333333333
# default
# num: 486
# wrong label: 172
# corrected label: 16
# uncorrected label: 6
# premise: Pt was shocked x 1.
# hypothesis: The patient was in ventricular tachycardia.
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 487
# wrong label: 172
# corrected label: 16
# uncorrected label: 6
# premise: In the ED initial vitals were: 96.8 72 97/68 20 93% 3L.
# hypothesis: The patient is hypertensive
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.8
# prem cx: False
# hypt cx: False
# prem verb: is False
# hypt verb: had False
# num: 488
# wrong label: 172
# corrected label: 16
# uncorrected label: 6
# premise: Prior to the onset of symptoms, the patient was able to walk several blocks with minimal difficulty.
# hypothesis: Prior of the onset of symptoms, the patient had mobility
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 489
# wrong label: 172
# corrected label: 16
# uncorrected label: 6
# premise: He was apneic with poor color.
# hypothesis: the patient was apneic
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 490
# wrong label: 172
# corrected label: 16
# uncorrected label: 6
# premise: He was apneic with poor color.
# hypothesis: the patient had head trauma
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.6666666666666666
# prem cx: False
# hypt cx: False
# prem verb: checked False
# hypt verb: is False
# num: 491
# wrong label: 172
# corrected label: 16
# uncorrected label: 6
# premise: The patient checked his blood pressure at home and it was 69/51.
# hypothesis: His blood pressure was low
# hy: entailment
# ...
# corrected label: 23
# uncorrected label: 7
# premise: The patient was sent to the HD unit prior to coming to the floor for workup of fever.
# hypothesis: The patient has elevated temperature
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 728
# wrong label: 252
# corrected label: 23
# uncorrected label: 7
# premise: The patient was sent to the HD unit prior to coming to the floor for workup of fever.
# hypothesis: The patient has an infection
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 729
# wrong label: 253
# corrected label: 23
# uncorrected label: 7
# premise: CVA in [**2987**] with residual left-sided weakness 8.
# hypothesis: Patient has had prior stroke
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 730
# wrong label: 253
# corrected label: 23
# uncorrected label: 7
# premise: CVA in [**2987**] with residual left-sided weakness 8.
# hypothesis: The patient has athersclerotic disease in the carotid arteries.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 731
# wrong label: 253
# corrected label: 23
# uncorrected label: 7
# premise: History of peripheral neuropathy.
# hypothesis: The patient has decreased sensation at the extremities.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 732
# wrong label: 253
# corrected label: 23
# uncorrected label: 7
# premise: History of peripheral neuropathy.
# hypothesis: The patient has diabetes.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.3333333333333333
# default
# num: 733
# wrong label: 253
# corrected label: 23
# uncorrected label: 7
# premise: 52 y/o with history of hep c and ESLD was admitted to [**Hospital3 36130**] center for increase in abdominal distension.
# hypothesis: History of alcohol abuse
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 734
# wrong label: 254
# corrected label: 23
# uncorrected label: 7
# premise: She had CT abdomen which was negative.
# hypothesis: patient has normal ct abdomen
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 735
# wrong label: 255
# corrected label: 23
# uncorrected label: 7
# premise: She had CT abdomen which was negative.
# hypothesis: patient has kidney stones
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 736
# wrong label: 255
# corrected label: 23
# uncorrected label: 7
# premise: She had CT abdomen which was negative.
# hypothesis: patient has abdominal pain
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.3333333333333333
# default
# num: 737
# wrong label: 256
# corrected label: 23
# uncorrected label: 7
# premise: The patient's valve area was calculated at 0.8 cm2 with a mean gradient across the aortic valve of 35 mmHg.
# hypothesis: the patient has aortic stenosis
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 738
# wrong label: 256
# corrected label: 23
# uncorrected label: 7
# premise: The patient's valve area was calculated at 0.8 cm2 with a mean gradient across the aortic valve of 35 mmHg.
# hypothesis: the patient will undergo TAVR
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 739
# wrong label: 256
# corrected label: 23
# uncorrected label: 7
# premise: He had a 500 cc blood loss, after which he was transferred 2 units of packed red blood cells and 2 units of fresh frozen plasma.
# hypothesis: The patient is actively hemorrhaging.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.6666666666666666
# prem cx: False
# hypt cx: False
# prem verb: denies True
# hypt verb: has False
# num: 740
# wrong label: 257
# corrected label: 24
# uncorrected label: 7
# premise: He denies lightheadedness, chest pain, palpitations, shortness of breath, or dyspnea on exertion, though it should be said, he rarely exerts himself, spending most time in bed, sitting, or in a wheelchair secondary to extensive deconditioning during multiple hospitalizations.
# hypothesis: the patient has chest pain
# hy: contradiction
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 741
# wrong label: 257
# corrected label: 24
# uncorrected label: 7
# premise: He denies lightheadedness, chest pain, palpitations, shortness of breath, or dyspnea on exertion, though it should be said, he rarely exerts himself, spending most time in bed, sitting, or in a wheelchair secondary to extensive deconditioning during multiple hospitalizations.
# hypothesis: the patient is obese
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 742
# wrong label: 258
# corrected label: 24
# uncorrected label: 7
# premise: Restrictive lung disease.
# hypothesis: Patient has decreased FEV1
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 743
# wrong label: 259
# corrected label: 24
# uncorrected label: 7
# premise: Restrictive lung disease.
# hypothesis: Patient has normal PFTs
# hy: neutral
# dp: neutral
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 744
# wrong label: 260
# corrected label: 24
# uncorrected label: 7
# premise: Restrictive lung disease.
# hypothesis: Patient has abnormal chest CT
# hy: contradiction
# dp: contradiction
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 745
# wrong label: 260
# corrected label: 24
# uncorrected label: 7
# premise: She was recently discharged from [**Hospital3 2026**] ([**Date range (1) 18811**]) after an episode of dysarthria; she was found to have negative carotid u/s, EEG w/o seizure activity, old hemorrhagic stroke in the medial posterior parietal lobe on MRI, mitral valve leaflet thickening (cannot r/o vascular vegetation) on ECHO.
# hypothesis: the patient had dysarthria
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.25
# default
# num: 746
# wrong label: 260
# corrected label: 24
# uncorrected label: 7
# premise: She was recently discharged from [**Hospital3 2026**] ([**Date range (1) 18811**]) after an episode of dysarthria; she was found to have negative carotid u/s, EEG w/o seizure activity, old hemorrhagic stroke in the medial posterior parietal lobe on MRI, mitral valve leaflet thickening (cannot r/o vascular vegetation) on ECHO.
# hypothesis: the patient had a TIA
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.3333333333333333
# default
# num: 747
# wrong label: 260
# corrected label: 24
# uncorrected label: 7
# premise: Post intubation, hypotensive and started on dopamine and transitioned to levophed.
# hypothesis: the patient is hypotensive on pressors
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 748
# wrong label: 260
# corrected label: 24
# uncorrected label: 7
# premise: Post intubation, hypotensive and started on dopamine and transitioned to levophed.
# hypothesis: the patient is hypertensive
# hy: contradiction
# dp: contradiction
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 749
# wrong label: 261
# corrected label: 24
# uncorrected label: 7
# premise: He developed tachycardia again the morning of [**4-18**] (which was treated with 5 mg IV metoprolol) and po diltiazem was also started.
# hypothesis: Patient has VTach
# hy: contradiction
# dp: contradiction
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 750
# wrong label: 262
# corrected label: 24
# uncorrected label: 7
# premise: He denies recent fevers, chills or rigors.
# hypothesis: The patient is not febrile.
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 751
# wrong label: 263
# corrected label: 24
# uncorrected label: 7
# premise: He denies recent fevers, chills or rigors.
# hypothesis: The patient does not have symptoms of an infection.
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.75
# prem cx: False
# hypt cx: True
# prem verb: denies True
# hypt verb: has False
# num: 752
# wrong label: 263
# corrected label: 24
# uncorrected label: 7
# premise: He denies recent fevers, chills or rigors.
# hypothesis: The patient has no symptoms of a fever.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 753
# wrong label: 263
# corrected label: 24
# uncorrected label: 7
# premise: He denies recent fevers, chills or rigors.
# hypothesis: The patient does not have an infection.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 754
# wrong label: 263
# corrected label: 24
# uncorrected label: 7
# premise: He denies recent fevers, chills or rigors.
# hypothesis: He is afebrile
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.5
# default
# num: 755
# wrong label: 264
# corrected label: 24
# uncorrected label: 7
# premise: He denies recent fevers, chills or rigors.
# hypothesis: He denies pain
# hy: entailment
# dp: entailment
# ground_truth: neutral
# =====================================================================================================
# 0.6666666666666666
# prem cx: False
# hypt cx: False
# prem verb: c/o False
# hypt verb: experiences False
# num: 756
# wrong label: 264
# corrected label: 24
# uncorrected label: 7
# premise: Of note, patient does c/o progressive shortness of breath over the past year.
# hypothesis: The patient experiences dyspnea
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 757
# wrong label: 264
# corrected label: 24
# uncorrected label: 7
# premise: Started on levophed for BP support despite 8LNS.
# hypothesis: The patient is in the ICU
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 758
# wrong label: 264
# corrected label: 24
# uncorrected label: 7
# premise: He was admitted to the Neonatal Intensive Care Unit because of prematurity.
# hypothesis: The patient was born before 37 weeks of gestation.
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 759
# wrong label: 264
# corrected label: 24
# uncorrected label: 7
# premise: This twin emerged with a spontaneous cry and received free-flow oxygen with Apgar scores were 8 at one minute and 9 at five minutes.
# hypothesis: Patient is a newborn
# hy: entailment
# dp: entailment
# ground_truth: entailment
# =====================================================================================================
# 0.25
# default
# num: 760
# wrong label: 265
# corrected label: 24
# uncorrected label: 7
# premise: This twin emerged with a spontaneous cry and received free-flow oxygen with Apgar scores were 8 at one minute and 9 at five minutes.
# hypothesis: Patient has poor Apgar’s
# hy: entailment
# dp: entailment
# ground_truth: contradiction
# =====================================================================================================
# 0.0
# default
# num: 761
# wrong label: 265
# corrected label: 24
# uncorrected label: 7
# premise: This twin emerged with a spontaneous cry and received free-flow oxygen with Apgar scores were 8 at one minute and 9 at five minutes.
# hypothesis: Patient is a male
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.25
# default
# num: 762
# wrong label: 266
# corrected label: 24
# uncorrected label: 7
# premise: Although he reports having heart attacks in the past, he is not sure if his current symptoms are similar to his prior events.
# hypothesis: Patient has has prior MI
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.0
# default
# num: 763
# wrong label: 266
# corrected label: 24
# uncorrected label: 7
# premise: Although he reports having heart attacks in the past, he is not sure if his current symptoms are similar to his prior events.
# hypothesis: Patient has acute STEMP
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 764
# wrong label: 266
# corrected label: 24
# uncorrected label: 7
# premise: 64 yom with history of congenital heart disease s/p porcine MV replacement, difficulty to control atrial fibrillation, diabetes and CHF presented with a one day history of fever and malaise.
# hypothesis: Patient has nausea
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.5
# default
# num: 765
# wrong label: 267
# corrected label: 24
# uncorrected label: 7
# premise: During that admission the patient became volume overloaded and was admitted to the MICU for initiation of HD.
# hypothesis: The patient is volume overloaded and in acute renal failure.
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
# 0.25
# default
# num: 766
# wrong label: 267
# corrected label: 24
# uncorrected label: 7
# premise: During that admission the patient became volume overloaded and was admitted to the MICU for initiation of HD.
# hypothesis: The patient has congestive heart failure.
# hy: neutral
# dp: neutral
# ground_truth: neutral
# =====================================================================================================
# 0.0
# default
# num: 767
# wrong label: 268
# corrected label: 24
# uncorrected label: 7
# premise: Papillary peritoneal serous carcinoma, metastatic.
# hypothesis: Patient has stage IV cancer
# hy: neutral
# dp: neutral
# ground_truth: entailment
# =====================================================================================================
